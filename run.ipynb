# %% [markdown]
# ##### **CUSUM Paper Experiments - Roland Bolboaca**

# %% [markdown]
# #### CUSUM Experiments Notebook
#
# This notebook contains the code for the experiments in the CUSUM paper [1].

# %% [markdown]
# ### **----------------------------- Info -----------------------------**

# %% [markdown]
# ##### **Datasets**
#
# - TEP - Tennessee Eastman Process [[9]](https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/6C3JR1)
# - LBNL Fault Detection and Diagnostics Data Sets [[10]](https://faultdetection.lbl.gov/data/)
# - SKAB - Skoltech Anomaly Benchmark [[11]](https://www.kaggle.com/datasets/yuriykatser/skoltech-anomaly-benchmark-skab)
# - RMFD - Rotating Machine Fault Detection Dataset [[12]](https://www.kaggle.com/datasets/sumairaziz/vibration-faults-dataset-for-rotating-machines)
# - VSD - Voltage Signal Dataset [[13]](https://www.kaggle.com/datasets/neuralsorcerer/voltage-signal-dataset)
# ---
#
# #### **TEP Dataset**
# - Variables: 55
#     - C1: Fault Number
#     - C2: Simulation
#     - C3: sample
#     - C4-55 process variables
# - Clean: 500 simulations of 500 points, 250,000 samples
# - Anomaly: 500 simulations of 960 points, 480,000 samples
#     - 146 clean + 800 fault
#     - 20 Fault files
# - Sample rate = 3 minutes
#
# - Variables: *[Link 1](https://keepfloyding.github.io/posts/data-explor-TEP-1/)* and *[Link 2](https://www.sciencedirect.com/science/article/pii/S0098135414000969?via%3Dihub)*
# ---
#
# #### **LBNL Dataset**
# - Variables: 23
#     - C1: Time
#     - C2-23 process variables
# - Clean: 365 continuous days, 525,500 observations.
# - Anomaly: 365 continuous days, 525,500 observations.
#     - 16 Fault files
# - Sample rate = 1 minute
# - Variables: *[Link 1](https://fdddata.lbl.gov/data/Simulated_LBNL_FDD_Data_Sets_Boiler_Plant/LBNL_FDD_Data_Sets_Boiler_Plant.pdf)*
# ---
#
# ### **SKAB Dataset**
# - Variables: 11
#     - C1: Time
#     - C2-11 process variables
# - Clean : 9406 observations
# - Anomaly: 3 typess, 10 files each, ~1100 observations
#     - 10 Fault files per directory
# - Sample rate = 1 second
# - Variables: *[Link 1](https://www.kaggle.com/datasets/yuriykatser/skoltech-anomaly-benchmark-skab)*
# ---
#
# #### **RMFD Dataset**
# - Varobles: 2 (Beanscape tri-axis wireless accelerometer)
#     - C1: Time, C2 - process variable
# - Clean: 5000 observations, 103 files
# - Anomaly: 5000 observations, 117 files
#     - 100 Fault files
# - Sample rate = 1000 Hz
# - Variables: *[Link 1](https://www.kaggle.com/datasets/sumairaziz/vibration-faults-dataset-for-rotating-machines)*
# ---
#
# ##### **CUSUM Papers**
#
# - Classical CUSUM (Page's Test) [[2]](https://doi.org/10.1093/biomet/41.1-2.100) (1st order 2 side CUSUM)
# - The 1-CUSUM Scheme [[3]](https://www.tandfonline.com/doi/abs/10.1080/00207540600792267)  (1st and 2nd order 1 side CUSUM)
# - ACUSUM Humpel control chart [[4]](https://onlinelibrary.wiley.com/doi/pdf/10.1002/qre.3463)
# - High Order CUSUM [[5]](http://www.mit.bme.hu/system/files/oktatas/targyak/9132/Nonlinear_Input_Output_Modeling.pdf) (3rd order (Skewness) and 4th order (Kurtosis))
# - UCUSUM mean shift [[6]](https://www.mdpi.com/2079-9292/10/24/3161)  (1st order 1 side CUSUM)
# - Variance Shift CUSUM [[7]](https://ieeexplore.ieee.org/document/8959745) (2nd order 1 side CUSUM)
# ---
#
# #### **Metrics**
#
# - FAR - False Alarm Rate (False positive rate) on normal data.
# - TPR - True Positive Rate (True positive rate) on anomalies.
# - DD - Detection Delay (Time to detect the first anomaly).
# - Robustness:
#     - FAR_N: false alarm rate under noise  +  outliers
#     - Stability Index (SI): number of oscilations or sign changes in the decision statistic
# - Ressilience:
#     - Recovery Time (RT): time to recover from an anomaly
#     - Stability Time (ST): time until the decision statistic is stable for N consecutive samples
#
# ##### **Setup**
#
# ```bash
# pip install -r requirements.txt
# ```
#
# ##### **Run**
#
# -   Execute Setup Functions Blocks
# -   First time loading the data takes time.
#     - However, they are stored first in a dictionary for access to file names and everything.
#     -   Secondly in np arrays (this is way faster).
#
# -   If you dont have the datasets:
#     1.   You can download them from the links in the dataset section
#     2.   You can load them from the pickle file!
#     3.   You can generate them from the code in the dataset section
#     4.   You can use the pkl files: np_all_data_..._.pkl.
#         - They are already converted to np arrays (recommended). Place them in the dataset dir.
#
# -   I recommend skipping to 4. Download np pkls and use that.
# -   Play arround with the parameters in the Setup Functions Blocks
# -   Play arround with the parameters in the lower blocks:
#     -   Robustness and Resilience Experiments
#     -   Dataset Params
#     -   CUSUM Params
#     -   Model Params
# -   Execute CUSUM Experiments
# -   Execute Robustness and Resilience Experiments
# -   Execute Anomaly Detection Experiments
# -   Execute Hyperparameter Optimizations
# -   Execute Comparissons
# -   Execute Parameter Tuning and Analysis
# -   Execute Plotting
# -   **Due to the enormity of the datasets and experiments, running times might be high!**
# -   Be patient or feel free to further optimize the code!
#
# ##### **References**
#
# [1] Bolboaca R., Authors. Cumulative Sums Resilience and Robustness in the Context of Time Series Anomaly Detection., Venue, Publisher., 2025 *[Link N.A. (yet)](www.scholar.google.com)*
#
# [2] Page ES. Continuous inspection schemes. Biometrika, 1954; 41(1–2): 100–115. https://doi.org/10.1093/biomet/41.1-2.100.
#
# [3] Z. Wu and Q. Wang, “A single cusum chart using a single observation to monitor a variable,” International Journal of Production Research, vol. 45, no. 3, pp. 719–741, 2007.
#
# [4] Akhtar, Noureen, Muhammad Abid, Babar Zaman, and Muhammad Riaz. "A new adaptive CUSUM control chart based on Hampel function to monitor location parameter." Quality and Reliability Engineering International 40, no. 3 (2024): 1246-1278. *[Link](https://onlinelibrary.wiley.com/doi/pdf/10.1002/qre.3463)*
#
# [5] Ronald K. Pearson. Nonlinear Input/Output Modeling Journal of the American Statistical Association. 1976. *[Link](http://www.mit.bme.hu/system/files/oktatas/targyak/9132/Nonlinear_Input_Output_Modeling.pdf)*
#
# [6] A.-S. Roman, B. Genge, A.-V. Duka, and P. Haller, Privacy-preserving tampering detection in automotive systems, Electronics, vol. 10, no. 24, 2021. *[Link](https://www.mdpi.com/2079-9292/10/24/3161)*
#
# [7] Bolboacă, Roland, Béla Genge, and Piroska Haller. "Using Side-Channels to Detect Abnormal Behavior in Industrial Control Systems." In 2019 IEEE 15th International Conference on Intelligent Computer Communication and Processing (ICCP), pp. 435-441. IEEE, 2019. *[Link](https://ieeexplore.ieee.org/document/8959745)*
#
# [8] J. J. Pignatiello Jr and G. C. Runger, Comparisons of multivariate cusum charts, Journal of quality technology, vol. 22, no. 3, pp. 173–186, 1990. *[Link](https://courses.washington.edu/ie599/MCUSUM.pdf)*
#
#
# **Datasets**
#
# [9] Rieth, C., Amsel, B., Tran, R., Cook, M.: Additional tennessee eastman process simulation data for anomaly detection evaluation. Harvard Dataverse 1, 2017
# (2017), https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/6C3JR1
#
# [10] Granderson, J., Lin, G., Chen, Y., Casillas, A., Im, P., Jung, S., Benne, K., Ling, J., Gorthala, R., Wen, J., Chen, Z., Huang, S., Vrabie, D.: Lbnl fault detection and diagnostics datasets (2022) https://doi.org/10.25984/1881324, https://faultdetection.lbl.gov/data/
#
# [11] Iurii D. Katser and Vyacheslav O. Kozitsin, “Skoltech Anomaly Benchmark (SKAB).” Kaggle, 2020, doi: 10.34740/KAGGLE/DSV/1693952. https://www.kaggle.com/datasets/yuriykatser/skoltech-anomaly-benchmark-skab
#
# [12] Kafeel A, Aziz S, Awais M, Khan MA, Afaq K, Idris SA, Alshazly H, Mostafa SM. An Expert System for Rotating Machine Fault Detection Using Vibration Signal Analysis. Sensors. 2021; 21(22):7587. https://doi.org/10.3390/s21227587. https://www.kaggle.com/datasets/sumairaziz/vibration-faults-dataset-for-rotating-machines
#
# [13] Soumyadip Sarkar. Voltage Signal Dataset. Kaggle, 2025. https://www.kaggle.com/datasets/neuralsorcerer/voltage-signal-dataset

# %% [markdown]
# ### **--------------- Setup ---------------**

# %% [markdown]
# #### **Imports, Environments, Parameters, and Loaders**

# %%
# Modules Imports

import os
# Disables GPUs or use GPUS
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

import time
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

import gc
import keras
import pickle
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from functools import partial

from sklearn.metrics import average_precision_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from concurrent.futures import ThreadPoolExecutor
from scipy.stats import skew, kurtosis

from statsmodels.tsa.arima.model import ARIMA
import stumpy
from statsmodels.tsa.ar_model import AutoReg

# %%
# Parameters and Hyperparameters
# Feel free to change as needed
program_parameters = {
    'data_path': 'datasets/',
    'plot_path': 'plots/',
    'dataset' : ['TEP','LBNL','SKAB','RMFD','VSD'],
    'multivariate': False
}

# Plotting Parameters, you can reuse it before the experiment block
# Font sizes
font_main = 16
font_title = 18
font_legend = 14
linewidth = 3

plt.rcParams.update({
    # Font sizes
    'font.size': font_main,
    'axes.labelsize': font_main,
    'xtick.labelsize': font_main,
    'ytick.labelsize': font_main,
    'legend.fontsize': font_legend,
    'axes.titlesize': font_title,
    'figure.titlesize': font_main,
    
    # Axis & grid styling
    'axes.grid': True,
    'axes.grid.which': 'major',
    'axes.linewidth': 0.8, 

    # Line widths
    'lines.linewidth': linewidth
})

# CUSUM, Dataset, and ML Model parameters (examples).
# Feel free to reuse it before the experiment block!
# These parameters are reused in the EXPERIMENT BLOCK!
# Use this template as an example!!!

# Portion of the clean dataset used for parameter estimation
PARAM_ESTIMATION_SIZE = 3000

# The maximum length of the dataset
MAX_LENGTH = 10000

cusums_parameters = {
    'classical': {
        'h': 3, 
        'shift_size': 1
    },
    'one_cusum_scheme': {
        'h': 3,
        'lamb': 0.5,  # Smoothing factor
        'shift_size': 1
    },
    'hampel_acusum': {
        'a': 3,
        'b': 3.5, 
        'r': 3, 
        'gamma': 4.5, 
        'h': 3,
        'shift_size': 1
    },  
    'UCUSUM': {
        'h': 3, 
        'window': 30, 
        'target_mean': 0,  # Expected mean under normal conditions
    },
    'variance_cusum': {
        'h': 3,
        'window': 20,
        'target_var': 1,  # Expected variance under normal conditions
        'k': 1,  # Reference value
        'shift_size': 1
    },
    'high_order': {
        'h':3,  
        'alpha': 0.5,
        'window': 30, 
        'shift_size': 1
    }
}

datasets_parameters = {
    'TEP': {
        'variable': 6, 
        'param_estimation_size': PARAM_ESTIMATION_SIZE, 
        'max_length': MAX_LENGTH,
        'inputs': [0, 1, 2, 6, 9, 33],
        'outputs': [6],
        'default_clean_file': 'clean',
        'default_fault_file': 'FaultyTest_13.csv',
        'files': "all",
        'dropped_columns': [0, 1, 2],
        'simulation': True,
        'sim_length': 960,
        'clean_sim_length': 500,
        'RESILIENCE_CLEAN_DATA_MULTIPLIER':5
    },
    
    'LBNL': {
        'variable': 12, #8, 
        'param_estimation_size': PARAM_ESTIMATION_SIZE, 
        'max_length': MAX_LENGTH,   
        'inputs': [0, 1, 2, 3, 17, 18],
        'outputs': [12], # [8],
        'default_clean_file': 'clean',
        'default_fault_file': 'BoilerPlant_boiler_foul_095.csv',
        'files': "all",
        'dropped_columns': [0],
        'simulation': False
    },
    'SKAB': {
        'variable': 2, 
        'param_estimation_size': PARAM_ESTIMATION_SIZE, 
        'max_length': MAX_LENGTH,
        'inputs': [0, 1, 2, 4],
        'outputs': [2],
        'default_clean_file': 'clean',
        'default_fault_file': '1.csv',
        'files': "all",
        'dropped_columns': [0],
        'simulation': False
    },
    'RMFD': {
        'variable': 2, 
        'param_estimation_size': PARAM_ESTIMATION_SIZE, 
        'max_length': MAX_LENGTH,
        'inputs': [0, 1],
        'outputs': [2],
        'default_clean_file': 'H1.mat',
        'default_fault_file': 'F1.mat',
        'files': "all",
        'dropped_columns': None,
        'simulation': False
    },
    'VSD': {
        'variable': 0, 
        'param_estimation_size': PARAM_ESTIMATION_SIZE, 
        'max_length': MAX_LENGTH,
        'inputs': [0],
        'outputs': [0],
        'default_clean_file': 0,
        'default_fault_file': 0,
        'files': "all",
        'dropped_columns': None,
        'simulation': False
    }
}

models_parameters = {
        'models': 'LSTM',
        'seq_len': 40,
        'num_layers': 1,
        'hidden_size': [32],
        'LR': 0.01,
        'batch_size': 16,
        'epochs': 100,
        'train_ratio': 0.5,
        'optimizer': 'Adam',
        'loss': 'MSE',
        'metrics': ['accuracy'],
        'seed': 42,
        'TF': True,
        'stateful': True
}

# %%
# Read Files by Type
def read_file_auto(fp):
    """Read .csv, .mat, or .txt file and return (filename, DataFrame)
        Runs with the following separators: , ;
    """
    
    fname = os.path.basename(fp)
    if fp.endswith('.csv'):
        df = pd.read_csv(fp, sep = ';' if ';' in open(fp).readline() else ',')
        
    elif fp.endswith('.mat'):
        from scipy.io import loadmat
        mat = loadmat(fp)
        data_key = next(k for k in mat.keys() if not k.startswith('__'))
        df = pd.DataFrame(mat[data_key])

    elif fp.endswith('.txt'):
        df = pd.read_csv(fp, header=None, sep='\s+')

    else:
        raise ValueError(f"Unsupported file type: {fp}")
    
    return fname, df

# %%
# Data Loader Functions
def read_files_threaded(filepaths):
    """ 
        Read files in parallel using ThreadPoolExecutor
        Note: Only supports .csv, .mat, and .txt
    """
    with ThreadPoolExecutor() as executor:
        results = executor.map(read_file_auto, filepaths)

    return dict(results)

# %%
# Data Loader Standard
def load_data(data_path, dataset=None, multivariate=False):
    """ Load data from file path
        Note: Only supports TEP, LBNL, SKAB, RMFD and VSD (for now)
        To make it easier for you without the need to reorganize the downloaded data.
        You need to: rename the clean files to clean.csv
        Results:
            - For TEP and LBNL:
                - 'clean': A dictionary with one DataFrame (or two TEP)
                - 'fault': A dictionary mapping filenames to DataFrames

            - For RMFD:
                - 'clean': A dictionary containing dictionaries {filename: DataFrame, ...}
                - 'fault': A dictionary containing dictionaries {filename: DataFrame, ...}

            - For SKAB:
                - 'clean': A dictionary with one DataFrame
                - 'fault': A dictionary containing dictionaries, each mapping fault folder name to another dictionary {filename: DataFrame, ...}

            - For VSD:
                - 'clean': A dictionary containing dictionaries {filename: DataFrame, ...}, one per case folder
                - 'fault': A dictionary containing dictionaries {filename: DataFrame, ...}, one per case folder

        File structure (as downloaded from the given sources and very little manipulation):
            data/
                TEP/
                    clean.csv
                    clean_test.csv
                    fault/
                        file1.csv
                        file2.csv
                        ...
                LBNL/
                    clean.csv
                    fault/
                        file1.csv
                        file2.csv
                        ...
                RMFD/
                    clean/
                        file1.mat
                        file2.mat
                        ...
                    fault/
                        file1.mat
                        file2.mat
                        ...
                SKAB/
                    clean.csv
                    fault1/
                        file1.csv
                        file2.csv
                        ...
                    fault2/
                        file1.csv
                        file2.csv
                        ...
                VSD/
                    clean/
                        case1/
                            file1.txt
                            file2.txt
                        ...
                    fault/
                        case1/
                            file1.txt
                            file2.txt
                        ...

        Results structure:
            - TEP and LBNL:
                clean: {DataFrame
                fault: {filename: DataFrame, ...}
            
            - RMFD:
                clean: { {filename: DataFrame, ...} }
                fault: { {filename: DataFrame, ...} }
            
            - SKAB:
                clean: {DataFrame}
                fault: { {fault_folder: {filename: DataFrame, ...}}, ... }
            
            - VSD:
                clean: { folder: {filename: DataFrame, ...}, ... }
                fault: { folder: {filename: DataFrame, ...}, ... }
    """
    results = {
        'clean': {},
        'fault': {}
    }

    dataset_path = os.path.join(data_path, dataset)
    
    # Also drop columns from the datasets. Columns are numerically given
    if dataset in ['TEP', 'LBNL']:
        
        if dataset == 'TEP':
            df_clean = pd.read_csv(os.path.join(dataset_path, 'clean.csv'))
            df_clean_test = pd.read_csv(os.path.join(dataset_path, 'clean_test.csv'))
            results['clean']['clean'] = df_clean
            results['clean']['clean_test'] = df_clean_test
        else:
            df_clean = pd.read_csv(os.path.join(dataset_path, 'clean.csv'))
            results['clean'] = df_clean
        
        fault_dir = os.path.join(dataset_path, 'fault')
        fault_files = [os.path.join(fault_dir, f) for f in sorted(os.listdir(fault_dir))]
        results['fault'] = read_files_threaded(fault_files)

    elif dataset == 'RMFD':
        clean_dir = os.path.join(dataset_path, 'clean')
        fault_dir = os.path.join(dataset_path, 'fault')

        clean_files = [os.path.join(clean_dir, f) for f in sorted(os.listdir(clean_dir)) if f.endswith(('.csv', '.mat'))]
        fault_files = [os.path.join(fault_dir, f) for f in sorted(os.listdir(fault_dir)) if f.endswith(('.csv', '.mat'))]

        results['clean'] = read_files_threaded(clean_files)
        results['fault'] = read_files_threaded(fault_files)

    elif dataset == 'SKAB':
        clean_path = os.path.join(dataset_path, 'clean.csv')
        df_clean = pd.read_csv(clean_path, sep=';')

        results['clean'] = df_clean

        for fault_dir in sorted(os.listdir(dataset_path)):
            fault_path = os.path.join(dataset_path, fault_dir)
            if os.path.isdir(fault_path) and fault_dir != 'clean.csv':
                fault_files = [os.path.join(fault_path, f) for f in sorted(os.listdir(fault_path)) if f.endswith('.csv')]
                results['fault'][fault_dir] =  read_files_threaded(fault_files)

    elif dataset == 'VSD':
        clean_root = os.path.join(dataset_path, 'clean')
        fault_root = os.path.join(dataset_path, 'fault')

        for case in sorted(os.listdir(clean_root)):
            case_path = os.path.join(clean_root, case)
            if os.path.isdir(case_path):
                clean_files = [os.path.join(case_path, f) for f in sorted(os.listdir(case_path)) if f.endswith('.txt')]
                results['clean'][case]= read_files_threaded(clean_files)

        for case in sorted(os.listdir(fault_root)):
            case_path = os.path.join(fault_root, case)
            if os.path.isdir(case_path):
                fault_files = [os.path.join(case_path, f) for f in sorted(os.listdir(case_path)) if f.endswith('.txt')]
                results['fault'][case] = read_files_threaded(fault_files)

    else:
        raise ValueError(f"Unsupported dataset: {dataset}")

    return results

# %%
# Saving Loading
def save_pickle(data, data_path):
    """ Save data to a pickle file """
    
    with open(data_path, 'wb') as f:
        pickle.dump(data, f)

# %%
# Loading Pickles
def load_pickle(data_path):
    """ Load data from file path"""
    
    with open(data_path, 'rb') as f:
        df = pickle.load(f)
    
    return df

# %%
# Checkers
def is_list_of_arrays(lst):
    return isinstance(lst, list) and all(isinstance(i, np.ndarray) for i in lst)

def is_flat_list(lst):
    return isinstance(lst, list) and all(not isinstance(i, (list, np.ndarray)) for i in lst)

def is_flat_ndarray(x):
    return isinstance(x, np.ndarray) and x.ndim == 1

def is_2d_ndarray(x):
    return isinstance(x, np.ndarray) and x.ndim == 2

def is_list_of_lists(lst):
    return isinstance(lst, list) and all(isinstance(i, list) for i in lst)

# %% [markdown]
# #### **Plotting Functions**

# %%
# Plotting - CUSUM Statistic

def plot_cusum_stat(stat, detections=None, h=None, title="CUSUM Statistic"):
    """
    Plot CUSUM statistic over time with optional detections and threshold.
    
    Parameters:
        stat: CUSUM statistic array
        detections: binary array, same length as stat
        h: threshold value
    """
    plt.figure(figsize=(12, 4))
    plt.plot(stat, label="CUSUM statistic", color="blue")
    if h is not None:
        plt.axhline(h, color="red", linestyle="--", label=f"Threshold h={h}")
    if detections is not None:
        anomaly_points = np.where(detections == 1)[0]
        plt.scatter(anomaly_points, stat[anomaly_points], color="orange", label="Detections", zorder=5)
    plt.title(title)
    plt.xlabel("Time")
    plt.ylabel("CUSUM Statistic")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(program_parameters["plot_path"] + title + "_stat.pdf", format='pdf')
    plt.show()

# %%
# Plotting - for debugging
def plot_time_series(x, labels=None, title="Time Series", dataset = ""):
    """ 
        Plot a time series with optional labels for anomalies
    """
    plt.figure(figsize=(12, 5))
    
    plt.plot(x, label="Time Series", color="gray")
    plt.fill_between(range(len(labels)), x.min(), x.max(), where=labels == 1, 
                     color='red', alpha=0.2, label="True Anomaly")
    plt.title(dataset)
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.savefig(program_parameters["plot_path"] + dataset + "_time_series.pdf", format='pdf')
    plt.show()

# %%
# Plotting - for debugging
def plot_with_ground_truth(x, stat = None, 
                           pos = None, neg = None, 
                           detections = None, 
                           labels = None, 
                           h=None, 
                           dataset = "", 
                           title="CUSUM Detection with Ground Truth"):
    """ 
        Plot a time series with optional labels for anomalies
        Plots threshold and detections
    """

    plt.figure(figsize=(12, 5))
    plt.title(str(title) + " " + str(dataset))

    if stat is None:
        if pos is not None:
            plt.plot(pos, label="CUSUM+", color="green")

        if neg is not None:
            plt.plot(neg, label="CUSUM-", color="blue")
    else:
        plt.plot(stat, label="CUSUM Stat")

    if h is not None:
        plt.axhline(h, color="red", linestyle="--", label=f"Threshold h={round(h, 2)}" if h is not None else f"Upper Threshold h={h}")
        plt.axhline(-h, color="red", linestyle="--", label=f"Threshold h={round(-h, 2)}" if h is not None else f"Lower Threshold h={-h}")
    
    if detections is not None:
        anomaly_points = np.where(detections == 1)[0]

        if labels is not None:
            if stat is not None:
                plt.scatter(anomaly_points, stat[anomaly_points], color="#ff7f0e", label="Detected", zorder=5, s=50, alpha=0.7)
                plt.fill_between(range(len(labels)), 0, stat.max(), where=labels == 1, color='red', alpha=0.1)
            else:
                plt.scatter(anomaly_points, pos[anomaly_points], color="#ff7f0e", label="Detected", zorder=5, s=50, alpha=0.7)
                plt.scatter(anomaly_points, neg[anomaly_points], color="#ff7f0e", label="Detected", zorder=5, s=50, alpha=0.7)
                plt.fill_between(range(len(labels)), 0, max(pos.max(), neg.max()), where=labels == 1, color='red', alpha=0.1)
        
            # Add vertical transparent line at first non-zero index


            nonzero_indices = np.where(detections > 0)[0]
            if len(nonzero_indices) > 0:
                start_idx = pos[nonzero_indices[0]]
                plt.axvline(x=start_idx, color='orange', linestyle=':', alpha=0.8, label=f'Start change')

    plt.xlabel("Time")

    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.savefig(program_parameters["plot_path"] + title + "_detection.pdf", format='pdf')

# %%
# Extra Plots for CUSUMs, Data, and windowed statistics (errors between clean anomalous)
def plot_sliding_stats_compare(clean, plot_labels, anomaly, window, dataset=""):
    """ 
    Plot sliding statistics (mean, std, skew, kurtosis) 
    for clean and anomalous data.
    """
    def sliding_stats(data):
        means, stds, skews, kurts, positions = [], [], [], [], []
        for i in range(len(data) - window + 1):
            w = data[i:i+window]
            means.append(np.mean(w))
            stds.append(np.std(w, ddof=1))
            skews.append(skew(w))
            kurts.append(kurtosis(w))
            positions.append(i + window // 2)
        return positions, means, stds, skews, kurts
    
    pos_clean, mean_clean, std_clean, skew_clean, kurt_clean = sliding_stats(clean)
    pos_anom, mean_anom, std_anom, skew_anom, kurt_anom = sliding_stats(anomaly)
    
    fig, axs = plt.subplots(4, 1, figsize=(12, 10), sharex=True)
    
    label1 = plot_labels[0] if len(plot_labels) > 0 else 'Clean'
    label2 = plot_labels[1] if len(plot_labels) > 1 else 'Anomaly'

    axs[0].plot(pos_clean, mean_clean, label=label1, color='blue')
    axs[0].plot(pos_anom, mean_anom, label=label2, color='red')
    axs[0].set_ylabel('Mean')
    axs[0].grid(True)
    axs[0].legend()

    axs[1].plot(pos_clean, std_clean, label=label1, color='blue')
    axs[1].plot(pos_anom, std_anom, label=label2, color='red')
    axs[1].set_ylabel('Std Dev')
    axs[1].grid(True)
    axs[1].legend()
    
    axs[2].plot(pos_clean, skew_clean, label=label1, color='blue')
    axs[2].plot(pos_anom, skew_anom, label=label2, color='red')
    axs[2].set_ylabel('Skewness')
    axs[2].grid(True)
    axs[2].legend()

    axs[3].plot(pos_clean, kurt_clean, label=label1, color='blue')
    axs[3].plot(pos_anom, kurt_anom, label=label2, color='red')
    axs[3].set_ylabel('Kurtosis')
    axs[3].set_xlabel('Time (index)')
    axs[3].grid(True)
    axs[3].legend()
    
    plt.suptitle(f"Sliding Statistics Comparison {dataset}")
    plt.tight_layout()
    plt.show()

    
    # plt.plot(skew_fault_1, label='Skewness Clean 1', color='red')
    # plt.plot(skew_fault_2, label='Skewness Faulty 1', color='orange')
    # plt.legend()
    # plt.show()

    # plt.plot(kurt_fault_1, label='Kurtosis Clean 2', color='red')
    # plt.plot(kurt_fault_2, label='Kurtosis Faulty 2', color='orange')
    # plt.legend()
    # plt.show()

    return pos_clean, mean_clean, std_clean, skew_clean, kurt_clean

def plot_sliding_stats_error(clean, anomaly, window, dataset="", plot_labels=None):
    def sliding_stats(data):
        means, stds, skews, kurts, positions = [], [], [], [], []
        for i in range(len(data) - window + 1):
            w = data[i:i+window]
            means.append(np.mean(w))
            stds.append(np.std(w, ddof=1))
            skews.append(skew(w))
            kurts.append(kurtosis(w))
            positions.append(i + window // 2)

        return positions, means, stds, skews, kurts

    pos_clean, mean_clean, std_clean, skew_clean, kurt_clean = sliding_stats(clean)
    pos_anom, mean_anom, std_anom, skew_anom, kurt_anom = sliding_stats(anomaly)

    error_mean = np.abs(np.array(mean_clean) - np.array(mean_anom))
    error_std = np.abs(np.array(std_clean) - np.array(std_anom))
    error_skew = np.abs(np.array(skew_clean) - np.array(skew_anom))
    error_kurt = np.abs(np.array(kurt_clean) - np.array(kurt_anom))

    error_list = [error_mean, error_std, error_skew, error_kurt]
    labels = ['Mean Error', 'Std Dev Error', 'Skewness Error', 'Kurtosis Error']

    fig, axs = plt.subplots(4, 1, figsize=(12, 10), sharex=True)

    # Unified Y-axis range
    all_errors = np.concatenate(error_list)
    y_min, y_max = all_errors.min(), all_errors.max()

    for i, (ax, err, label) in enumerate(zip(axs, error_list, labels)):
        ax.plot(pos_clean, err, color='purple')
        ax.set_ylabel(label)
        ax.set_ylim(y_min, y_max + 0.1 * y_max)
        ax.grid(True)

        # Add horizontal line at max value
        max_val = np.max(err)
        ax.axhline(y=max_val, color='red', linestyle='--', alpha=0.8, label=f'Max: {max_val:.2f}, Mean: {np.mean(err):.2f} , Std: {np.std(err):.2f}')

        # Add vertical transparent line at first non-zero index
        # nonzero_indices = np.where(err > 0)[0]
        # if len(nonzero_indices) > 0:
        #     start_idx = pos_clean[nonzero_indices[0]]
        #     ax.axvline(x=start_idx, color='orange', linestyle=':', alpha=0.8, label=f'Start change')

        ax.legend(loc='upper right')

    axs[-1].set_xlabel('Time (index)')
    plt.suptitle(f"Sliding Statistics Error Comparison {dataset}")
    plt.tight_layout()
    plt.show()

    return skew_clean, kurt_clean, skew_anom, kurt_anom

def plot_data_comparison(clean, anomaly, labels=None, dataset="", plot_labels=None):
    """
    Plot a comparison of clean and anomalous data.
    
    Parameters:
        clean: clean time series (1D array)
        anomaly: anomalous time series (1D array)
        labels: optional binary array indicating anomalies in the clean data
        dataset: name of the dataset for title
    """
    plt.figure(figsize=(12, 5))
    
    label1 = plot_labels[0] if len(plot_labels) > 0 else 'Clean'
    label2 = plot_labels[1] if len(plot_labels) > 1 else 'Anomaly'

    plt.plot(clean, label=label1, color="blue", alpha=0.5)
    plt.plot(anomaly, label=label2, color="red", alpha=0.5)

    if labels is not None:
        anomaly_points = np.where(labels == 1)[0]
        plt.scatter(anomaly_points, anomaly[anomaly_points], color="orange", label="Anomalies", zorder=5)

    plt.title(f"Data Comparison {dataset}")
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

    # Also draw histogram of the data
    plt.figure(figsize=(12, 5))
    plt.hist(clean, bins=100, alpha=0.5, label=label1, color="blue")
    plt.hist(anomaly, bins=100, alpha=0.5, label=label2, color="red")
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.title(f"Histogram Comparison {dataset}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def logistic_map(r, x0, n):
    x = np.zeros(n)
    x[0] = x0
    for i in range(1, n):
        x[i] = r * x[i-1] * (1 - x[i-1])
    return x

def generate_ar1(phi, n, sigma=1):
    x = np.zeros(n)
    noise = np.random.normal(0, sigma, n)
    for t in range(1, n):
        x[t] = phi * x[t-1] + noise[t]
    return x

def plot_time_series(x, labels=None, title="Time Series", dataset = ""):
    # Plot Histogram of time series with optional labels for anomalies
    # Plot a time series with optional labels for anomalies

    plt.hist(x, bins='auto', label='Histogram')
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.title(title + " " + dataset)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()


    plt.figure(figsize=(12, 5))
    
    plt.title(str(title) + " " + str(dataset))
    plt.plot(x, label="Time Series", color="gray")

    plt.title(dataset)
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### **Metrics Functions**

# %%
# Metrics - TPR, FPR, DD
def tpr_fpr_dd(labels, detections):
    """
    Arguments
    ---------
    labels: binary array indicating anomalies in the clean data
    detections: binary array indicating anomalies in the clean data

    Returns
    -------
    Dictionary of metrics:
        True Positive Rate (TPR), 
        False Positive Rate (FPR),
        Detection Delay (DD).
    """
    tpr = np.sum(detections[labels == 1]) / np.sum(labels == 1)

    # Detection Delay, first detection after anomaly, without for loop
    # first_anomaly = np.where(labels == 1)
    # dd = np.where(detections == 1)[0][0]
    first_anomaly = np.where(labels == 1)[0][0] if np.any(labels == 1) else 0
    
    dd = 0
    for i in range(first_anomaly,  len(detections)):
        if detections[i] == 1 and i >  first_anomaly:
            dd = i
            break
    
    if dd == 0:
        dd = -1  # If no detection after first anomaly, set to -1
    else:
        dd = dd - first_anomaly
    
    results = {
        'TPR': tpr,
        'DD': dd
    }
    return results

# %%
# Metrics - Robustness

def robustness_metric(stat = None, threshold = 0, shift_amplitudide=0):
    """
    Calculate the robustness metric 
        for a given CUSUM statistic and threshold.

    - Noise experiments (low amplitude noise.)
    - Micro shifts (micro shifts in the time series, 0.1 to 2 sigma)
    - Stability Index (SI): number of oscilations or sign changes in the decision statistic
    - On clean data.
    
    Arguments
    ---------
    stat: CUSUM statistic array (CUSUM computed values over a time series)
    threshold: threshold value
    shift_amplitudide: amplitude of the shift (noise!)

    Returns
    -------
    FAR_N: False Alarme Rate Under Noise
    SI: Stability Index
    
    """

    if stat is None:
        raise ValueError("CUSUM statistic is None")
    if threshold is None:
        raise ValueError("Threshold is None")

    # FAR_N (False Alarme Rate Under Noise or Outliers)
    FAR_N = np.sum(stat) / len(stat)

    # Number of oscilations in the cusum stat not based on threshold
    # oscilations not only sign changes

    diffs = np.diff(stat)
    oscillations = np.sum((np.diff(np.sign(diffs)) != 0).astype(int))

    # SI (Stability Index)
    SI = oscillations / len(stat)

    return FAR_N, SI

# %%
# Metrics - Resilience

def compute_stability_time(stat_pos = None, 
                          stat_neg = None, 
                          threshold = 0, 
                          last_anomaly = 0,
                           N=10):
    """
    Computes stability time: 
         The time until the CUSUM stats stay within threshold for N consecutive steps.
    """

    if stat_pos is None:
        raise ValueError("CUSUM statistic is None")
    
    if threshold is None:
        raise ValueError("Threshold is None")
    
    if last_anomaly is None:
        raise ValueError("Last anomaly in data is None")
    
    data_length = len(stat_pos)

    if stat_neg is not None:
        for i in range(last_anomaly + 1, data_length - N):
            stable = True
            for j in range(N):
                if stat_pos[i + j] >= threshold or stat_neg[i + j] <= -threshold:
                    stable = False
                    break
            if stable:
                return i - last_anomaly 
    else:
        for i in range(last_anomaly + 1, data_length - N):
            stable = True
            for j in range(N):
                if stat_pos[i + j] >= threshold:
                    stable = False
                    break
            if stable:
                return i - last_anomaly
            
    return -1

# %%
# Metrics - Resilience

def compute_recovery_time(stat_pos = None, 
                          stat_neg = None, 
                          threshold = 0, 
                          last_anomaly_in_data = 0):
    """
    Compute the recovery time for a given anomaly.
    # After the last anomaly in data (last_anomaly_in_data),
    #  the time needed to recover below the threshold.
    """
    if stat_pos is None:
        raise ValueError("CUSUM statistic is None")
    
    if threshold is None:
        raise ValueError("Threshold is None")
    
    if last_anomaly_in_data is None:
        raise ValueError("Last anomaly in data is None")
    
    last_anomaly_in_cusum = 0

    if stat_neg is not None:
        for i in range(last_anomaly_in_data + 1, len(stat_pos)):
            if  (stat_pos[i] < threshold and stat_neg[i] > - threshold):
                last_anomaly_in_cusum = i
                break
        # for i in range(len(stat_pos) - 1, -1, -1):
        #     if (stat_pos[i] < threshold and stat_neg[i] > - threshold) and i > last_anomaly_in_data:
        #         last_anomaly_in_cusum = i
        #         break
    else:
        for i in range(last_anomaly_in_data + 1, len(stat_pos)):
            if  (stat_pos[i] < threshold):
                last_anomaly_in_cusum = i
                break
        # for i in range(len(stat_pos) - 1, -1, -1):
        #     if (stat_pos[i] < threshold) and i > last_anomaly_in_data:
        #         last_anomaly_in_cusum = i
        #         break

    recovery_time = last_anomaly_in_cusum - last_anomaly_in_data
    
    rec_time = -1 if last_anomaly_in_cusum == 0 else recovery_time

    return rec_time

# %%
# Metrics - Resilience

def resilience_metric(stat_pos = None, 
                      stat_neg = None,
                      threshold = 0, 
                      last_anomaly_in_data = 100, 
                      simulation = False,
                      sim_length = 1000,
                      N = 10):

    """
    Calculate the resilience metric for a given CUSUM statistic and threshold.

    After the last anomaly, the time needed to recover and return below the threshold.

    Recovery Time: 
    The time it takes for the CUSUM statistic to recover below the threshold 
                after the last anomaly.

    Stability time:
        The time until the CUSUM stats stay within threshold for N consecutive steps.
    
    Arguments
    ---------
    stat: CUSUM statistic array (CUSUM computed values over a time series)
    threshold: threshold value
    last_anomaly_in_data: index of the last anomaly in the data
    alpha: parameter for the resilience score

    returns
    -------
    recovery_time: the time it takes for the CUSUM statistic to recover below the threshold 
                after the last anomaly.
    resilience_score: the resilience score
    """

    if stat_pos is None or len(stat_pos) == 0:
        raise ValueError("CUSUM statistic is None or empty")

    if last_anomaly_in_data is None:
        raise ValueError("Last anomaly in data is None")
    
    if threshold is None:
        raise ValueError("Threshold is None")
    
    if last_anomaly_in_data is None:
        raise ValueError("Last anomaly in data is None")
    

    # if we are working with simulations we need to compute for each sim
    
    if simulation:       
        
        recovery_times = []
        stability_times = []
        num_sims = len(stat_pos) // sim_length 

        # Trim the data to the number of sims
        stat_pos = stat_pos[:num_sims * sim_length]
        stat_pos_2D = stat_pos.reshape((num_sims, sim_length))
        
        if stat_neg is not None:
            stat_neg = stat_neg[:num_sims * sim_length] 
            stat_neg_2D = stat_neg.reshape((num_sims, sim_length))

            # Compute for each sim
            idx = 0
            for sim_pos_row, sim_neg_row in zip(stat_pos_2D, stat_neg_2D):
                r_time = compute_recovery_time(sim_pos_row, 
                                            sim_neg_row, 
                                            threshold, 
                                            last_anomaly_in_data)
                
                s_time = compute_stability_time(sim_pos_row, 
                                                sim_neg_row, 
                                                threshold, 
                                                last_anomaly_in_data, 
                                                N=N)
                idx += 1

                recovery_times.append(r_time)
                stability_times.append(s_time)
        else:
            # Compute for each sim
            idx = 0
            for sim_pos_row in stat_pos_2D:
                r_time = compute_recovery_time(sim_pos_row, 
                                            None, 
                                            threshold, 
                                            last_anomaly_in_data)
                
                s_time = compute_stability_time(sim_pos_row, 
                                                None, 
                                                threshold, 
                                                last_anomaly_in_data, 
                                                N=10)
                idx += 1

                recovery_times.append(r_time)
                stability_times.append(s_time)

        recovery_time = np.mean(recovery_times)
        stability_time = np.mean(stability_times)

    else:

        recovery_time = compute_recovery_time(stat_pos, stat_neg, threshold, last_anomaly_in_data)
        stability_time = compute_stability_time(stat_pos, stat_neg, threshold, last_anomaly_in_data, N=10)

    return recovery_time, stability_time

# %% [markdown]
# #### **Cumulative Sums Functions - CUSUM**

# %%
# CUSUM - Hampel Function
def hampel(e, a, b, r, gamma):
    """ 
    Hampel function as it appears in [4] 
    See also: Huber function.
    
    arguments
    ---------
    e: error
    a, b, r, gamma: hampel function parameters

    returns
    -------
    Hampel function value
    """
    
    c = (a/2) * (b - a + r)

    if abs(e) <= a:
        return (e**2)/(2*c)
    
    elif abs(e) > a and abs(e) <= b:
        return ((1/2)*(a**2) + a*(abs(e) - a))/c
    
    elif abs(e) > b and abs(e) <= gamma:
        return (a/2)*(2*b - a + (abs(e) - b)*(1 + (r - abs(e)/(c-b)))) / c
    
    elif (abs(e) > gamma):
        return 1

# %%
# CUSUM - Classical Page's CUSUM (The father of CUSUMs)
def classical_cusum(x, 
                    target_mean = 0, 
                    std_dev = 0, 
                    k=0.5, 
                    h=5,
                    simulation = False,
                    sim_length = 960,
                    resilience = False):
    """
        Input:
            x: input time series
            target_mean: expected mean under normal conditions
            std_dev: standard deviation under normal conditions
            k: reference value (usually 0.5 * shift)
            h: threshold
        Returns: 
            pos: positive CUSUM statistic
            neg: negative CUSUM statistic
            detections: binary vector
    """
    pos, neg = [0], [0]

    detections = [0]
    for i in range(1, len(x)):
        
        if not resilience and simulation and i > 0 and i % sim_length == 0:
            pos.append(0)
            neg.append(0)
            detections.append(0)
            continue

        s_pos = max(0, pos[-1] + x[i] - target_mean - k)
        s_neg = min(0, neg[-1] + x[i] - target_mean + k)

        pos.append(s_pos)
        neg.append(s_neg)

        detections.append(1 if s_pos > h or s_neg < -h else 0)

    return np.array(pos), np.array(neg), np.array(detections)

# %%
# CUSUM - One-sided CUSUM (upper or lower)
def one_sided_cusum(x, target_mean, std_dev, direction="upper", k = 0.5, h = 5):
    """
        Same as classical CUSUM but only one-sided (selectable direction)
        Input:
            x: input time series
            target_mean: expected mean under normal conditions
            std_dev: standard deviation under normal conditions
            k: reference value (usually 0.5 * shift)
            h: threshold
        Returns: 
            s: positive or negative  CUSUM statistic
            detections: binary vector
    """
    s = [0]
    detections = [0]
    for i in range(1, len(x)):
        if direction == "upper":
            val =  max(0, s[-1] + x[i] - target_mean - k)
        else:
            val = max(0, s[-1] - x[i] + target_mean - k)

        s.append(val)

        detections.append(1 if val > h else 0)
        
    return np.array(s), np.array(detections)

# %%
# CUSUM - 1-CUSUM Scheme
def one_cusum_scheme(x, 
                     target_mean, 
                     lamb = 0.5,
                     k = 0.5, 
                     h = 5,
                     simulation = False,
                     sim_length = 960,
                     resilience = False):
    """
        Input:
            x: input time series
            target_mean: expected mean under normal conditions
            lamb: smoothing factor
            k: reference value (usually 0.5 * shift)
            h: threshold
        Returns: 
            s: CUSUM statistic
            detections: binary vector
    """

    detections = [0]
    
    y = (x - target_mean)
    y_square = y ** 2

    s = [0]

    for i in range(1, len(x)):
        if not resilience  and simulation and i > 0 and i % sim_length == 0:
            s.append(0)
            detections.append(0)
            continue
        if s[-1] > 0 or (s[-1] == 0 and y[i] > 0):
            val = max(0, s[-1] + lamb * y[i] + (1 - lamb) * y_square[i] - k)
        else:
            val = min(0, s[-1] - lamb * y[i] + (1 - lamb) * y_square[i] + k)

        s.append(val)

        detections.append(1 if val > h else 0 or 1 if val < -h else 0)

    return np.array(s), np.array(detections)

# %%
# CUSUM - ACUSUM Hampel control chart
def hampel_acusum(x, a, b, r, 
                  gamma, h=5, 
                  k_plus = 0.5, 
                  k_minus = 0.5,
                  simulation = False,
                  sim_length = 960,
                  resilience = False):
    """ As it appears in [4].
        Input:
            x: input time series
            a, b, r, gamma: hampel parameters
            k +/- : reference values
            h: threshold
        Returns: 
            pos, neg: CUSUM positive and negative statistics
            detections: binary vector

    *** 
    If someone accidentally reads this:
    Please for the love of all that is holy, when you describe an algorithm
    in your paper, describe it clearly enough so that a person can implement it.
    Authors in [4], I'm looking at you ...

    P.S. r parameter is forgotten in the paper, freestyling it...
    Equation 9 also mentions a "d" parameter (ghost parameter).
    The referenced source of the Hampel function is non existent.
    """    
    pos, neg = [0], [0]

    detections = [0]

    for i in range(1, len(x)):
        if not resilience and simulation and i > 0 and i % sim_length == 0:
            pos.append(0)
            neg.append(0)
            detections.append(0)
            continue
        
        eip = (x[i] - pos[-1])
        
        wip = hampel(eip, a, b, r, gamma) / eip
        delta_plus = max(wip, k_plus)

        pos.append(max(0, pos[-1] + delta_plus*(x[i] - delta_plus/2)))

        eim = (x[i] - neg[-1])
        wim = hampel(eim, a, b, r, gamma) / eim
        delta_minus = min(wim, k_minus)
        neg.append(min(0, neg[-1] - delta_minus*(x[i] - delta_minus/2)))

        if pos[-1] > h or neg[-1] < -h:
            detections.append(1)
        else:
            detections.append(0)

    return np.array(pos[1:]), np.array(neg[1:]), np.array(detections)

# %%
# CUSUM - High Order CUSUM based on Skewness and Kurtosis
def high_order_cusum(x, 
                     window = 30, 
                     alpha = 0.5, 
                     exp_x = 0, 
                     k = 0, 
                     h = 5,
                     simulation = False,
                     sim_length = 960,
                     resilience = False):
    """
        High Order CUSUM based on Skewness and Kurtosis
        Input:
            x: input time series
            k: reference value (usually 0.5 * shift)
            h: threshold
        Returns: 
            s: CUSUM statistic
            detections: binary vector
    """
    pos, neg = [0], [0]
    detections = [0]
    s = [0]

    for i in range(1, len(x)):
        if i < window:
            pos.append(0)
            neg.append(0)
            s.append(0)
            detections.append(0)
            continue
        
        # If sim based, reset CUSUM after each simulation
        if not resilience and simulation and i > 0 and i % sim_length == 0:
            pos.append(0)
            neg.append(0)
            s.append(0)
            detections.append(0)
            continue    
            
        window_data = x[i - window: i]
        
        if np.std(window_data) > 1e-10:
            skewness_w = skew(window_data, nan_policy='omit')
        else:
            skewness_w = 0

        if np.std(window_data) > 1e-10:
            kurtosis_w = kurtosis(window_data, nan_policy='omit')
        else:
            kurtosis_w = 0

        #skewness_w = skew(window_data, nan_policy='omit')
        #kurtosis_w = kurtosis(window_data, nan_policy='omit')

        z = alpha * skewness_w + (1-alpha)*kurtosis_w

        val_pos = max(0, pos[-1] + z - exp_x - k)
        val_neg = min(0, neg[-1] - z + exp_x + k)

        pos.append(val_pos)
        neg.append(val_neg)

        s.append(max(abs(val_pos), abs(val_neg)))
        
        detections.append(1 if val_pos > h or val_neg < - h else 0)

    return np.array(pos), np.array(neg), np.array(s), np.array(detections)
    return np.array(s), np.array(detections)

# %%
# CUSUM - UCUSUM mean shift
def UCUSUM(x, 
           window = 30, 
           target_mean = 0,
           h=5,
           simulation = False,
           sim_length = 960,
           resilience = False):
    """ UCUSUM as defined in [6] 
        Input:
            x: input time series
            window: window size
            h: threshold
            target_mean: expected mean under normal conditions
        Returns: 
            pos, neg: CUSUM positive and negative statistics
            detections: binary vector
    """
    s = [0]
    detections = [0]

    for i in range(1, len(x)):
        if i < window:
            s.append(0)
            detections.append(0)
            continue

        if not resilience and simulation and i > 0 and i % sim_length == 0:
            s.append(0)
            detections.append(0)
            continue
        
        local_mean = np.mean(x[i-window:i])
        val = local_mean - target_mean

        s.append(val)
        detections.append(1 if val > h else 0)

    return np.array(s), np.array(detections)

# %%
# CUSUM - Variance-change CUSUM 
def variance_cusum(x, 
                   target_var, 
                   window = 20,
                   k = 0.5, 
                   h = 5,
                   simulation = False,
                   sim_length = 960,
                   resilience = False):
    """
        Input:
            x: input time series
            window: window size
            h: threshold
            k: reference value
            target_var: expected variance under normal conditions
        Returns: 
            pos, neg, s: CUSUM positive, negative and total statistics
            detections: binary vector
    """
    pos, neg = [0], [0]
    s = [0]
    detections = [0]

    for i in range(1, len(x)):
        
        if i < window:
            pos.append(0)
            neg.append(0)
            detections.append(0)
            continue
        
        if not resilience and simulation and i > 0 and i % sim_length == 0:
            pos.append(0)
            neg.append(0)
            detections.append(0)
            continue

        local_var = np.var(x[i-window:i])

        z = (local_var - target_var)
        pos.append(max(0, pos[-1] + z - k))
        neg.append(max(0, neg[-1] + z + k))

        detections.append(1 if pos[-1] > h or neg[-1] < -h else 0)
        
    return np.array(pos), np.array(neg), np.array(detections)

# %%
# CUSUM Utilities - Threshold Estimation

def estimate_cusum_threshold(cusum_stats_pos = None, 
                             cusum_stats_neg = None,
                             clean_data = None, 
                             h = 5,
                             false_alarm_rate = 0.01,
                             csm_type = "classical",
                             window = 30,
                             alpha  = 0.5,
                             max_threshold = False):
    """
    Estimate threshold h from normal data CUSUM stats.
    
    Input:
        cusum_stats: array of CUSUM statistics under normal data
        clean_data: array of clean data (optional)
        h: threshold constant
        
    Returns:
        finial threshold value
    """
    if cusum_stats_pos is not None and cusum_stats_neg is not None:
        cusum_stats = abs(np.concatenate((cusum_stats_pos, cusum_stats_neg)))
    else:
        cusum_stats = cusum_stats_pos
        
    if clean_data is None:
        if max_threshold:
            return max(cusum_stats)
        return np.mean(cusum_stats) + h * np.std(cusum_stats)
    else:
        if max_threshold:
            return max(clean_data)
        return h * np.std(clean_data)

# %%
# CUSUM Utilities - Estimate target mean from cusum over normal data
def estimate_target_mean(x):
    return np.mean(x)

# %%
# CUSUM Utilities - Reference Value Estimation

def estimate_k_from_shift(std_dev, shift_size=1.0):
    """
    Choose the k (reference value) for CUSUM as a fraction of std deviation.
    
    std_dev: baseline standard deviation if either clean data or CUSUM on clean data
    shift_size: expected shift in mean, in units of std_dev (e.g., 1 sigma)
        
    """
    return shift_size * std_dev * 0.5

# %%
# CUSUM Utilities - Reference Value Estimation
def estimate_k_from_stats(data, alpha = 0.5, shift_size = 1.0, window = 30):
    """ 
        Estimate k (reference value) from statistics.
    """
    skews, kurts = [], []

    for i in range(len(data) - window + 1):
        w = data[i:i+window]
        skews.append(skew(w))
        kurts.append(kurtosis(w))

    k_estimated = np.array(alpha) * skews + np.array(1 - alpha) * kurts
    k_estimated = np.std(k_estimated) * shift_size * 0.5

    exp_x = np.mean(np.array(alpha) * skews + np.array(1 - alpha) * kurts)

    return exp_x, k_estimated

# %%
# CUSUM Utilities - Inject Anomalies (for testing purposes)

def inject_anomalies(x, anomaly_indices, anomaly_type="mean", magnitude=3.0, duration=10):
    """
    Inject anomalies into a 1D time series.

    Parameters:
        x: original time series (1D array)
        anomaly_indices: list of start indices for anomalies
        anomaly_type: "mean_shift", "variance_spike", or "step"
        magnitude: severity of the anomaly
        duration: how many points the anomaly lasts

    Returns:
        x_perturbed: modified time series
        labels: binary array (1=anomaly, 0=normal)
    """
    x_perturbed = x.copy()
    labels = np.zeros_like(x)

    for start in anomaly_indices:
        end = min(start + duration, len(x))
        labels[start:end] = 1

        if anomaly_type == "mean": 
            x_perturbed[start:end] += magnitude

        elif anomaly_type == "var":
            x_perturbed[start:end] += np.random.normal(0, magnitude, end - start)
            
        elif anomaly_type == "step":
            x_perturbed[end:] += magnitude  

        elif anomaly_type == "noise":
            x_perturbed[start:end] += np.random.normal(0, magnitude, end - start)

    return x_perturbed, labels

# %% [markdown]
# #### **Anomaly Detection Models (Comparissons)**

# %%
# Local Outlier Factor (LOF) - Anomaly Detection    

def run_lof(data, n_neighbors = 20, contamination = 0.1):
    """
    Parameters:
    - data: np.ndarray or pd.DataFrame, shape (n_samples, n_features)
    - n_neighbors: int, number of neighbors to use.
    - contamination: float, proportion of outliers in the data.

    Returns:
    - labels: 0 for inliers, 1 for outliers
    - scores: anomaly scores (higher = more anomalous)
    """
    lof = LocalOutlierFactor(n_neighbors=n_neighbors, contamination=contamination, novelty=False)
    
    labels = lof.fit_predict(data)
    scores = -lof.negative_outlier_factor_
    
    binary_labels = (labels == -1).astype(int)

    return binary_labels, scores

# %%
# Isolation Forest - Anomaly Detection
def run_isolation_forest(data, contamination=0.1, random_state=42):
    """
    Parameters:
    - data: np.ndarray or pd.DataFrame, shape (n_samples, n_features)
    - contamination: float, proportion of outliers in the data.
    - random_state: int, for reproducibility

    Returns:
    - labels: 0 for inliers, 1 for outliers
    - scores: anomaly scores (higher = more anomalous)
    """

    iso = IsolationForest(contamination=contamination, random_state=random_state)
    
    iso.fit(data)
    
    scores = -iso.decision_function(data)
    labels = iso.predict(data)

    binary_labels = (labels == -1).astype(int)
    
    return binary_labels, scores

# %%
# Reshape data into sliding windows

def create_sliding_windows(data, window_size = 30):
    
    """
    Parameters:
    - data: np.ndarray, shape (n_samples,) or (n_samples, n_features)
    - window_size: int, size of each window

    Returns:
    - windows: np.ndarray, shape (n_windows, window_size * n_features)
    """

    if data.ndim == 1:
        data = data.reshape(-1, 1)
    
    n_samples, n_features = data.shape
    windows = []

    for i in range(n_samples - window_size + 1):
        window = data[i:i+window_size].flatten()
        windows.append(window)

    return np.array(windows)

# %% [markdown]
# #### **ML Models**

# %%
# Create ML Models
def create_model(model_parameters = None, 
                 number_inputs = 1, 
                 number_outputs = 1):
    """
        Create a keras recurrent neural object from a dictionary of parameters.
    """

    if model_parameters is None:
        raise ValueError("Model parameters must be provided.")
    if number_inputs is None or number_inputs == 0:
        raise ValueError("Number of inputs must be provided.")
    if number_outputs is None or number_outputs == 0:
        raise ValueError("Number of outputs must be provided.")
    
    # TF for LSTMTF
    if model_parameters['TF'] == True:
        number_inputs = number_inputs + 1
        
    # Set random seed
    keras.utils.set_random_seed(model_parameters['seed'])

    # In newer versions of Keras, for stateful LSTM, you need to specify the batch_input_shape as the first layer (input layer)
    model = keras.Sequential()

    
    model.add(keras.layers.InputLayer(batch_input_shape=(model_parameters['batch_size'], 
                                                        model_parameters['seq_len'], 
                                                        number_inputs)))
    
    for i in range(model_parameters['num_layers']): 
        if model_parameters['models'] == 'RNN':
            model.add(keras.layers.SimpleRNN(units=model_parameters['hidden_size'][i], 
                                             return_sequences=True,
                                             stateful=model_parameters['stateful']))

        if model_parameters['models'] == 'LSTM':
            model.add(keras.layers.LSTM(units = model_parameters['hidden_size'][i],
                                            return_sequences=True, 
                                            stateful=model_parameters['stateful']))

        if model_parameters['models'] == 'GRU':
            model.add(keras.layers.GRU(units = model_parameters['hidden_size'][i],
                                            return_sequences=True,
                                            stateful=model_parameters['stateful']))

    model.add(keras.layers.Dense(number_outputs))

    model.compile(optimizer=model_parameters['optimizer'], 
                  loss=model_parameters['loss'], 
                  metrics=model_parameters['metrics'])

    # https://keras.io/api/optimizers/

    return model

# %% [markdown]
# #### **Create Dirs, Save or Load Data from Pickle**

# %%
# Load Datasets

# If the files with the names np_all_data exist, you might skip this step.

if not os.path.exists(program_parameters['data_path']):
    os.makedirs(program_parameters['data_path'])

if not os.path.exists(program_parameters['plot_path']):
    os.makedirs(program_parameters['plot_path'])

if not os.path.exists('data.pkl'):
    data = {}
    for dataset in program_parameters['dataset']:
        data[dataset] = load_data(program_parameters['data_path'], 
                                  dataset, 
                                  program_parameters['multivariate'])
    save_pickle(data, 'data.pkl')
else:
    data = load_pickle('data.pkl')

# %%
# Get Data From Loaded Pikles
def get_clean_fault_data(dataset = None, 
                         data = None, 
                         param_estimation_size = 1000, 
                         max_length = 0,
                         files = None,
                         dropped_columns = None,
                         start = 0
                         ):
    """
        Get Clean and Fault Data from the data dictionary

        Arguments
        ----------
        dataset: dataset to get data from
        data: dictionary of data
        param_estimation_size: size of data to use for CUSUM parameter estimation
        max_length: maximum length of data to use
        files: list of files to use
        dropped_columns: list of columns to drop (e.g., time, label, etc.)

        Returns
        -------
        List of np arrays: clean and fault labels, clean and fault data
    """
    # if data is None:
    #     data = load_pickle('data.pkl')

    if dataset is None:
        dataset = program_parameters['dataset']
        
    datafile = "datasets/np_all_data_" + str(dataset) + "_" + str(max_length) + ".pkl"

    if os.path.exists(datafile):
        temp_data = load_pickle(datafile)
        
        clean = temp_data['clean']
        fault = temp_data['fault']
        labels_clean = temp_data['labels_clean']
        labels_fault = temp_data['labels_fault']

        return clean, fault, labels_clean, labels_fault

    else:
        temp_data = {"clean": None, 
                "fault": None,
                "labels_clean": None,
                "labels_fault": None}

        # Create Labels (Clean / Fault) for each dataset
        labels_clean = np.zeros(max_length - param_estimation_size, dtype=int)
        labels_fault = np.ones(max_length , dtype=int)
        
        # Create DATA for each dataset
        if dataset == "TEP":

            labels_fault = np.zeros(max_length, dtype=int)
            block = 160 + 800  # total cycle length

            for i in range(0, max_length + 1, block):
                anomaly_start = i + 160
                anomaly_end = min(anomaly_start + 800, max_length)
                labels_fault[anomaly_start:anomaly_end] = 1
        
            # If all flag is selected, return all data from all dictionaries
            # It will be returned as a list of dataframes
            if files == 'all':
                fault = []
                clean = data['TEP']['clean']['clean'].values
                for key in data['TEP']['fault'].keys():
                    fault.append(data['TEP']['fault'][key].values)
            else:
                clean = data['TEP']['clean']['clean'].values
                if files is None:
                    fault = data['TEP']['fault']['FaultyTest_13.csv'].values
                else:
                    fault = data['TEP']['fault'][files[1]].values


        elif dataset == "LBNL":

            if files == 'all':
                fault = []
                clean = data['LBNL']['clean'].values
                for key in data['LBNL']['fault'].keys():
                    fault.append(data['LBNL']['fault'][key].values)
            else:
                clean = data['LBNL']['clean'].values
                if files is None:
                    fault = data['LBNL']['fault']['BoilerPlant_boiler_foul_095.csv'].values
                else:
                    fault = data['LBNL']['fault'][files[1]].values
                
        elif dataset == "SKAB":

            if files == "all":
                fault = []
                clean = data['SKAB']['clean'].values
                for key in data['SKAB']['fault'].keys():
                    for key2 in data['SKAB']['fault'][key].keys():
                        fault.append(data['SKAB']['fault'][key][key2].values)
                
                labels_fault = []


                for i in range(len(fault)):
                    labels = fault[i][:, -2]
                    labels_fault.append(np.int32(labels[:max_length]))
                    fault[i] = fault[i][:max_length, :-2]
            else:
                clean = data['SKAB']['clean'].values
                if files is None:
                    fault = data['SKAB']['fault']['fault_1']['0.csv'].values
                else:
                    fault = data['SKAB']['fault']['fault_1'][files[1]].values
            
                labels = fault[:, -2]
                labels_fault = labels
                labels_fault = np.int32(labels_fault[:max_length])
                fault = fault[:max_length, :-2]

        elif dataset == "RMFD":

            if files == "all":
                fault = []
                clean = []
                for key in data['RMFD']['clean'].keys():
                    clean.append(data['RMFD']['clean'][key].values)
                
                clean = np.vstack(clean)
                
                for key in data['RMFD']['fault'].keys():
                    fault.append(data['RMFD']['fault'][key].values)

                

            elif files is None:
                clean = data['RMFD']['clean']['H1.mat'].values
                fault = data['RMFD']['fault']['F1.mat'].values
            else:
                clean = data['RMFD']['clean'][files[0]].values
                fault = data['RMFD']['fault'][files[1]].values
            
        elif dataset == "VSD":

            if files == "all":

                fault = []
                clean = []

                for key in data['VSD']['clean'].keys():
                    for key2 in data['VSD']['clean'][key].keys():
                        clean.extend(data['VSD']['clean'][key][key2].values)

                for key in data['VSD']['fault'].keys():
                    for key2 in data['VSD']['fault'][key].keys():
                        fault.append(data['VSD']['fault'][key][key2].values)

            elif files is None:
                clean = data['VSD']['clean']['vdata1B1.txt'].values
                fault = data['VSD']['fault']['vdata1B1.txt'].values
            else:
                clean = data['VSD']['clean'][files[0]]['vdata1B1.txt'].values
                fault = data['VSD']['fault'][files[1]]['vdata1B1.txt'].values

        # Drop Selected Columns
        if dropped_columns is not None:
            if files != 'all':
                clean = np.delete(clean, dropped_columns, axis=1)
                fault = np.delete(fault, dropped_columns, axis=1)
            else:
                clean = np.delete(clean, dropped_columns, axis=1)
                for i in range(len(fault)):
                    fault[i] = np.delete(fault[i], dropped_columns, axis=1)

        #Truncate Data
        if max_length != 0:
            if type(clean) != list and clean.ndim != 1:
                clean = np.array(clean[0: start + max_length, :],dtype=float) 
            elif type(clean) != list and clean.ndim == 1:
                clean = np.array(clean[0: start + max_length],dtype=float)
            elif type(clean) == list:
                for i in range(len(clean)):
                    clean[i] = np.array(clean[i][0: start + max_length, :],dtype=float)

            for i in range(len(fault)):
                # Fault Data
                fault[i] = np.array(fault[i][0:  max_length, :], dtype=float)

        # Save Data
        temp_data['clean'] = clean
        temp_data['fault'] = fault
        temp_data['labels_clean'] = labels_clean
        temp_data['labels_fault'] = labels_fault
        
        save_pickle(temp_data, datafile)
        
    return clean, fault, labels_clean, labels_fault

# %%
# Get Clean and Fault Data Residuals
def get_clean_fault_residuals_data(dataset = None, 
                                   data = None, 
                                   datasets_parameters = None,
                                   plots = False,
                                   model = None,
                                   models_parameters = None,
                                   start = 0):
    
    """
        Load datasets, normalize data, train model and get residuals
        Arguments
        ----------
        dataset: dataset to get data from
        data: dictionary of data
        datasets_parameters: dictionary of datasets parameters
        plots: whether to plot the results
        model: keras model to use for training
        models_parameters: dictionary of model parameters
        start: start index for data slicing
        
        Returns
        -------
        residuals_clean: residuals for clean data
        residuals_fault: list of residuals for fault data
        labels_clean: labels for clean data
        labels_fault: labels for fault data
        time_measure: time taken for model training and prediction
    """
    
    # if data is None:
    #     data = load_pickle('data.pkl')

    if dataset is None:
        dataset = program_parameters['dataset']
    

    param_estimation_size = datasets_parameters['param_estimation_size']
    max_length = datasets_parameters['max_length']

    if datasets_parameters['files'] is None:
        files = [datasets_parameters['default_clean_file'], 
                                         datasets_parameters['default_fault_file']]
    else:
        files = datasets_parameters['files']


    results_time_measure = { }
    results_time_measure_fault_data = []

    # Get Clean and Fault Data
    clean_data, fault_data, labels_clean, labels_fault = \
                get_clean_fault_data(dataset = dataset, 
                                    data = data, 
                                    param_estimation_size = param_estimation_size, 
                                    max_length = max_length,
                                    files = files,
                                    dropped_columns = datasets_parameters['dropped_columns'],
                                    start = start)

    # Normalize
    scaler = MinMaxScaler()
    scaler.fit(clean_data)
    clean_data = scaler.transform(clean_data)

    # Clean Data Experiments
    X_clean, y_clean = clean_data[:,datasets_parameters['inputs']], clean_data[:,datasets_parameters['outputs']]
    
    if models_parameters['TF']:
        # Add TF as the previous output, as a column to the input
        X_clean = np.hstack((X_clean[1:, :], y_clean[0:-1]))
        y_clean = y_clean[1:, :]

    seq_len = models_parameters['seq_len']
    
    if models_parameters['TF']:
        num_feats = len(datasets_parameters['inputs']) + 1
    else:
        num_feats = len(datasets_parameters['inputs'])
        
    num_outputs = len(datasets_parameters['outputs'])

    valid_rows_clean = X_clean.shape[0] // seq_len * seq_len

    if len(y_clean.shape) == 1:
        X_clean = X_clean[:valid_rows_clean]
        y_clean = y_clean[:valid_rows_clean]
    else:
        X_clean = X_clean[:valid_rows_clean, :]
        y_clean = y_clean[:valid_rows_clean, :]

    num_sequences_clean = X_clean.shape[0] // seq_len

    X_clean = X_clean.reshape(num_sequences_clean, seq_len, num_feats)
    y_clean = y_clean.reshape(num_sequences_clean, seq_len, num_outputs)

    train_size = int(X_clean.shape[0] * models_parameters['train_ratio'])

    X_train_clean = X_clean[0: train_size]
    y_train_clean = y_clean[0: train_size]

    X_test_clean = X_clean[train_size: X_clean.shape[0]]
    y_test_clean = y_clean[train_size: y_clean.shape[0]]

    # If the model is statefull, trim to the maximum multiples of batch size
    if models_parameters['stateful']:
        maximum_sequences = X_train_clean.shape[0] - X_train_clean.shape[0] % models_parameters['batch_size']
        X_train_clean = X_train_clean[:maximum_sequences]
        X_test_clean = X_test_clean[:maximum_sequences]
        y_train_clean = y_train_clean[:maximum_sequences]
        y_test_clean = y_test_clean[:maximum_sequences]

    # Measure time for model training

    start_time_train = time.process_time()

    model.fit(X_train_clean, 
              y_train_clean, 
              epochs = models_parameters['epochs'], 
              batch_size = models_parameters['batch_size'],
              verbose = 0, 
              shuffle = False)
    
    end_time_train = time.process_time()
    results_time_measure['train'] = end_time_train - start_time_train

    y_hat_clean = model.predict(X_test_clean, batch_size = models_parameters['batch_size'], verbose = 0)

    residuals_clean = (y_test_clean.flatten() - y_hat_clean.flatten())**2

    if datasets_parameters['files'] != 'all':
        fault_data = [fault_data]
    
    residuals_fault = []
    
    for i in range(len(fault_data)):
        # Fault Data Experiments
        fault_data[i] = scaler.transform(fault_data[i])
        
        fd = fault_data[i]

        X_fault, y_fault = fd[:,datasets_parameters['inputs']], fd[:,datasets_parameters['outputs']]

        if models_parameters['TF']:
            # Add TF as the previous output, as a column to the input
            X_fault = np.hstack((X_fault[1:, :], y_fault[0:-1]))
            y_fault = y_fault[1:, :]

        valid_rows_fault = X_fault.shape[0] // seq_len * seq_len

        if len(y_fault.shape) == 1:
            X_fault = X_fault[:valid_rows_fault]
            y_fault = y_fault[:valid_rows_fault]
        else:
            X_fault = X_fault[:valid_rows_fault, :]
            y_fault = y_fault[:valid_rows_fault, :]
        
        num_sequences_fault = X_fault.shape[0] // seq_len
        
        X_fault = X_fault.reshape(num_sequences_fault, seq_len, num_feats)
        y_fault = y_fault.reshape(num_sequences_fault, seq_len, num_outputs)

        if models_parameters['stateful']:
            maximum_sequences = X_fault.shape[0] - X_fault.shape[0] % models_parameters['batch_size']
            X_fault = X_fault[:maximum_sequences]
            y_fault = y_fault[:maximum_sequences]
        
        start_time_predict = time.process_time()

        y_hat_fault = model.predict(X_fault, batch_size = models_parameters['batch_size'], verbose = 0)
        
        end_time_predict = time.process_time()

        results_time_measure_fault_data.append(end_time_predict - start_time_predict)

        residuals_fault.append((y_fault.flatten() - y_hat_fault.flatten())**2)

    results_time_measure['test'] = results_time_measure_fault_data

    return residuals_clean, residuals_fault, labels_clean, labels_fault,  results_time_measure

# %% [markdown]
# ### **---------------  Experiments ---------------**

# %% [markdown]
# #### **Helper Functions for the Experiments**

# %%
# Estimate CUSUMs parameters function
def estimate_cusums_parameters(param_estimation,
                               classic_threshold = False,
                               cusums_parameters = None):
    
    """ 
        Estimate CUSUMs parameters
        Arguments:
        ---------
        param_estimation: Data used to estimate the parameters
        classic_threshold: True to use the classic threshold
        cusums_parameters: Dictionary with CUSUMs parameters
        
        Returns:
        --------
        estimated_hs: Estimated thresholds
        estimated_ks: Estimated reference parameters
        target_mean_std: Target mean and std for either data or CUSUM
    """
    
    if cusums_parameters is None:
        raise ValueError("cusums_parameters is None")

    estimated_hs = {}
    estimated_ks = {}
    target_mean_std = {}    

    # Mean and STD of the Param Estimation Data
    target_mean = estimate_target_mean(param_estimation)
    target_std = np.std(param_estimation)
    
    target_mean_std['all'] = (target_mean, target_std)
    
    # High Order CUSUMs
    exp_x, k_estimated_ho = np.abs(estimate_k_from_stats(data = param_estimation, 
                                                         shift_size=cusums_parameters['high_order']['shift_size'],
                                                         alpha=cusums_parameters['high_order']['alpha']))
    

    if classic_threshold:
        cusum_stat_pos, cusum_stat_neg, _, _ = high_order_cusum(param_estimation, 
                                            window = cusums_parameters['high_order']['window'], 
                                            alpha = cusums_parameters['high_order']['alpha'],
                                            exp_x=exp_x,
                                            k=k_estimated_ho)

        h_estimated_ho = estimate_cusum_threshold(cusum_stats_pos=cusum_stat_pos, 
                                                cusum_stats_neg=cusum_stat_neg,
                                                clean_data=param_estimation, 
                                                h=cusums_parameters['high_order']['h'], 
                                                csm_type="high_order",
                                                window=cusums_parameters['high_order']['window'],
                                                alpha=cusums_parameters['high_order']['alpha'])
    
    else:
        h_estimated_ho = estimate_cusum_threshold(clean_data=param_estimation, 
                            h = cusums_parameters['high_order']['h'])

    estimated_hs['high_order'] = h_estimated_ho
    estimated_ks['high_order'] = k_estimated_ho
    target_mean_std['high_order'] = exp_x

    # Classical CUSUMs
    k_estimated_classical = estimate_k_from_shift(std_dev=target_std, 
                                                  shift_size=cusums_parameters['classical']['shift_size'])

    if classic_threshold:
        h_estimated_classical = estimate_cusum_threshold(clean_data=param_estimation, 
                                        h= cusums_parameters['classical']['h'])
    else:
        pos_clean, neg_clean, _ = classical_cusum(param_estimation, 
                                        target_mean=target_mean, 
                                        std_dev=target_std, 
                                        k=k_estimated_classical, 
                                        h=0)
    
        pos_clean = np.maximum(abs(pos_clean), abs(neg_clean))

        h_estimated_classical = estimate_cusum_threshold(clean_data=pos_clean, 
                                        h = cusums_parameters['classical']['h'])
    

    estimated_hs['classical'] = h_estimated_classical
    estimated_ks['classical'] = k_estimated_classical


    # One CUSUM Scheme
    k_estimated_one = estimate_k_from_shift(std_dev=target_std, 
                                            shift_size=cusums_parameters['one_cusum_scheme']['shift_size'])

    if classic_threshold:
        h_estimated_one = estimate_cusum_threshold(clean_data=param_estimation, 
                                        h=cusums_parameters['one_cusum_scheme']['h'])
    else:
        cusum_stat_clean, _ = one_cusum_scheme(param_estimation, 
                                        target_mean=target_mean, 
                                        k=k_estimated_one, 
                                        h=0, 
                                        lamb=cusums_parameters['one_cusum_scheme']['lamb']) 

        h_estimated_one = estimate_cusum_threshold(clean_data=cusum_stat_clean, 
                                        h=cusums_parameters['one_cusum_scheme']['h'])
    

    estimated_hs['one_cusum_scheme'] = h_estimated_one
    estimated_ks['one_cusum_scheme'] = k_estimated_one

    # Hampel CUSUMs
    k_estimated_hampel = estimate_k_from_shift(std_dev=target_std, 
                                               shift_size=cusums_parameters['hampel_acusum']['shift_size'])

    if classic_threshold:
        h_estimated_hampel = estimate_cusum_threshold(clean_data=param_estimation, 
                                        h=cusums_parameters['hampel_acusum']['h'],
                                        csm_type="hampel_acusum")
    else:
        cusum_stat_pos_clean, cusum_stat_neg_clean, _ = \
                                    hampel_acusum(param_estimation, 
                                       a=cusums_parameters['hampel_acusum']['a'], 
                                       b=cusums_parameters['hampel_acusum']['b'], 
                                       r=cusums_parameters['hampel_acusum']['r'], 
                                       gamma=cusums_parameters['hampel_acusum']['gamma'], 
                                       h=0, 
                                       k_plus=k_estimated_hampel, 
                                       k_minus=k_estimated_hampel)
        
        cusum_stat_pos_clean = np.maximum(abs(cusum_stat_pos_clean), abs(cusum_stat_neg_clean))
        
        h_estimated_hampel = estimate_cusum_threshold(clean_data=cusum_stat_pos_clean, 
                                        h=cusums_parameters['hampel_acusum']['h'],
                                        csm_type="hampel_acusum")



    estimated_hs['hampel_acusum'] = h_estimated_hampel
    estimated_ks['hampel_acusum'] = k_estimated_hampel

    # UCUSUM
    if classic_threshold:
        h_estimated_ucusum = estimate_cusum_threshold(clean_data=param_estimation, 
                                                    h=cusums_parameters['UCUSUM']['h'],
                                                    csm_type="UCUSUM")  
    else:
        cusum_stat_clean, _ = UCUSUM(param_estimation, 
                                     window=cusums_parameters['UCUSUM']['window'],
                                    target_mean=target_mean, 
                                    h=0)
        h_estimated_ucusum = estimate_cusum_threshold(clean_data=cusum_stat_clean, 
                                                    h=cusums_parameters['UCUSUM']['h'],
                                                    csm_type="UCUSUM")  


    estimated_hs['UCUSUM'] = h_estimated_ucusum

    # Variance CUSUM
    k_estimated_variance = estimate_k_from_shift(std_dev=target_std, 
                                                 shift_size=cusums_parameters['variance_cusum']['shift_size'])
    
    if classic_threshold:
        h_estimated_variance = estimate_cusum_threshold(clean_data=param_estimation, 
                                            h=cusums_parameters['variance_cusum']['h'],
                                            csm_type="variance_cusum")
    else:
        cusum_stat_clean_pos, cusum_stat_clean_neg, _ = variance_cusum(param_estimation, 
                                            target_var=target_std, 
                                            window=cusums_parameters['variance_cusum']['window'], 
                                            k=k_estimated_variance,
                                            h=0)
        cusum_stat_clean_pos = np.maximum(abs(cusum_stat_clean_pos), abs(cusum_stat_clean_neg))
        
        h_estimated_variance = estimate_cusum_threshold(clean_data=cusum_stat_clean_pos, 
                                            h=cusums_parameters['variance_cusum']['h'],
                                            csm_type="variance_cusum")
        

    estimated_hs['variance_cusum'] = h_estimated_variance
    estimated_ks['variance_cusum'] = k_estimated_variance

    return estimated_hs, estimated_ks, target_mean_std

# %%
# Function to run all CUSUMs
def run_all_cusums2(data,
                    dataset="", 
                    datasets_parameters = {},
                    models_parameters = {},
                    cusums_parameters = {},
                    plots = False,
                    model = None,
                    run_on_residuals = False,
                    classic_threshold = False,
                    start = 0,
                    measure_time = False):
    """
        Function to run all CUSUMs
        - Set the parameters in the cusums_parameters dictionary
        - Set the parameters in the datasets_parameters dictionary
        - Set the parameters in the models_parameters dictionary
        - Feel free to add remove datasets, CUSUMs and parameters
        Arguments:
            data: data dictionary
            dataset: dataset name
            datasets_parameters: datasets parameters dictionary
            plots: True to plot the results
            run_on_residuals: True to run the CUSUMs on the residuals
            cusums_parameters: CUSUMs parameters dictionary
            model: model object (keras)
            models_parameters: model parameters dictionary
            classic_threshold: True to use the classic threshold
        Returns:
            cusum_detection_results: CUSUMs detection results dict
                contains: labels, detections on clean and fault data
            dataset: dataset name
    """
    # Params.
    param_estimation_size = datasets_parameters['param_estimation_size']
    max_length = datasets_parameters['max_length']
    variable = datasets_parameters['variable']
    dropped_columns = datasets_parameters['dropped_columns']
    simulation = datasets_parameters['simulation']
    
    sim_length = datasets_parameters['sim_length'] if datasets_parameters['simulation'] is True else 0
    clean_sim_length = datasets_parameters['clean_sim_length'] if datasets_parameters['simulation'] is True else 0

    # Get Clean and Fault Data
    if run_on_residuals == False:
        if datasets_parameters['files'] is None:
            files = [datasets_parameters['default_clean_file'], 
                                                 datasets_parameters['default_fault_file']]
        else:
            files = datasets_parameters['files']
        
        clean, fault, labels_clean, labels_fault = \
                        get_clean_fault_data(dataset = dataset, 
                                            data = data, 
                                            param_estimation_size = param_estimation_size, 
                                            max_length = max_length,
                                            files = files,
                                            dropped_columns = dropped_columns,
                                            start = start)
    else:
        clean, fault, labels_clean, labels_fault, _ = \
                        get_clean_fault_residuals_data(dataset = dataset, 
                                            data = data, 
                                            datasets_parameters = datasets_parameters,
                                            model = model,
                                            models_parameters = models_parameters,
                                            start = start)
        start = 0

    # The Clean Data and Param Estimation Data
    if isinstance(clean, list):
        clean_data = [np.array(c[start:, variable], dtype=float) for c in clean]
    else:
        clean = np.array(clean)
        if clean.ndim == 1:
            clean_data = clean[start:].astype(float)
        else:
            clean_data = clean[start:, variable].astype(float)
       
    param_estimation = np.array(clean_data[:param_estimation_size])
    clean = np.array(clean_data[param_estimation_size:])

    if not run_on_residuals:
        fault = [np.array(f[:, variable], dtype=float) for f in fault]

    #######################################################################################
    # Estimate Parameters for CUSUMs
    
    estimated_hs, estimated_ks, target_mean_std = \
                    estimate_cusums_parameters(param_estimation,
                                            classic_threshold = classic_threshold,
                                            cusums_parameters = cusums_parameters)
    
    target_mean = target_mean_std['all'][0]
    target_std = target_mean_std['all'][1]

    #######################################################################################
    # CUSUMS Detections on Clean Data and Faulty Data

    # Detection Results    
    cusum_detection_results = { }
    
    # High Order CUSUMs
    h_estimated_ho = estimated_hs['high_order']
    k_estimated_ho = estimated_ks['high_order']
    exp_x = target_mean_std['high_order']

    detections_faults = []
    cusum_stat_pos, cusum_stat_neg, cusum_stat, detections_clean = high_order_cusum(clean, 
                                            window = cusums_parameters['high_order']['window'], 
                                            alpha = cusums_parameters['high_order']['alpha'],
                                            exp_x=exp_x,
                                            k=k_estimated_ho, 
                                            h=h_estimated_ho,
                                            simulation=simulation,
                                            sim_length=clean_sim_length)
    for f in fault:
        cusum_stat_pos, cusum_stat_neg, cusum_stat, detections_fault = high_order_cusum(f, 
                                                window = cusums_parameters['high_order']['window'],
                                                alpha = cusums_parameters['high_order']['alpha'],
                                                exp_x=exp_x,
                                                k=k_estimated_ho, 
                                                h=h_estimated_ho,
                                                simulation=simulation,
                                                sim_length=sim_length
                                                )
        
        detections_faults.append(detections_fault)


    cusum_detection_results['high_order'] = {
                        'labels_clean': labels_clean,
                        'detections_clean': detections_clean,
                        'labels_fault': labels_fault,
                        'detections_fault': detections_faults,
                        'threshold': h_estimated_ho
                    }

    # cleanup
    gc.collect()
    del detections_clean, detections_fault, detections_faults


    # Classical CUSUMs
    h_estimated_classical = estimated_hs['classical']
    k_estimated_classical = estimated_ks['classical']

    detections_faults = []
    pos_clean, neg_clean, detections_clean = classical_cusum(clean, 
                                       target_mean=target_mean, 
                                       std_dev=target_std, 
                                       k=k_estimated_classical, 
                                       h=h_estimated_classical,
                                       simulation=simulation,
                                       sim_length=clean_sim_length)

    for f in fault:
        _, _, detections_fault = classical_cusum(f, 
                                                target_mean=target_mean, 
                                                std_dev=target_std, 
                                                k=k_estimated_classical, 
                                                h=h_estimated_classical,
                                                simulation=simulation,
                                                sim_length=sim_length)
        
        detections_faults.append(detections_fault)

    cusum_detection_results['classical'] = {
                        'labels_clean': labels_clean,
                        'detections_clean': detections_clean,
                        'labels_fault': labels_fault,
                        'detections_fault': detections_faults,
                        'threshold': h_estimated_classical
                    }

    # cleanup
    gc.collect()
    del detections_clean, detections_fault, detections_faults

    # One CUSUM Scheme
    h_estimated_one = estimated_hs['one_cusum_scheme']
    k_estimated_one = estimated_ks['one_cusum_scheme']

    detections_faults = []
    cusum_stat_clean, detections_clean = one_cusum_scheme(clean, 
                                          target_mean=target_mean, 
                                          k=k_estimated_one, 
                                          h=h_estimated_one, 
                                          lamb=cusums_parameters['one_cusum_scheme']['lamb'], 
                                          simulation=simulation, 
                                          sim_length=clean_sim_length) 

    for f in fault:
        _, detections_fault = one_cusum_scheme(f, 
                                              target_mean=target_mean, 
                                              k=k_estimated_one, 
                                              h=h_estimated_one, 
                                              lamb=cusums_parameters['one_cusum_scheme']['lamb'],
                                              simulation=simulation,
                                              sim_length=sim_length) 
        
        detections_faults.append(detections_fault)

    cusum_detection_results['one_cusum_scheme'] = {
                        'labels_clean': labels_clean,
                        'detections_clean': detections_clean,
                        'labels_fault': labels_fault,
                        'detections_fault': detections_faults,
                        'threshold': h_estimated_one
                    }

    # cleanup
    gc.collect()
    del  detections_clean,  detections_fault, detections_faults

    # Hampel CUSUMs
    h_estimated_hampel = estimated_hs['hampel_acusum']
    k_estimated_hampel = estimated_ks['hampel_acusum']

    detections_faults = []
    cusum_stat_pos_clean, cusum_stat_neg_clean, detections_clean = \
                                    hampel_acusum(clean, 
                                       a=cusums_parameters['hampel_acusum']['a'], 
                                       b=cusums_parameters['hampel_acusum']['b'], 
                                       r=cusums_parameters['hampel_acusum']['r'], 
                                       gamma=cusums_parameters['hampel_acusum']['gamma'], 
                                       h=h_estimated_hampel, 
                                       k_plus=k_estimated_hampel, 
                                       k_minus=k_estimated_hampel,
                                       simulation=simulation,
                                       sim_length=clean_sim_length)

    for f in fault:
        cusum_stat_pos_fault, cusum_stat_neg_fault, detections_fault = \
                                        hampel_acusum(f, 
                                            a=cusums_parameters['hampel_acusum']['a'], 
                                            b=cusums_parameters['hampel_acusum']['b'], 
                                            r=cusums_parameters['hampel_acusum']['r'], 
                                            gamma=cusums_parameters['hampel_acusum']['gamma'], 
                                            h=h_estimated_hampel, 
                                            k_plus=k_estimated_hampel, 
                                            k_minus=k_estimated_hampel,
                                            simulation=simulation,
                                            sim_length=sim_length)
        
        detections_faults.append(detections_fault)

    cusum_detection_results['hampel'] = {
                        'labels_clean': labels_clean,
                        'detections_clean': detections_clean,
                        'labels_fault': labels_fault,
                        'detections_fault': detections_faults,
                        'threshold': h_estimated_hampel}
    # cleanup
    gc.collect()
    del detections_clean, detections_fault, detections_faults

    # UCUSUM Mean Shift
    detections_faults = []

    h_estimated_ucusum = estimated_hs['UCUSUM']
    k_estimated_ucusum = estimated_ks['UCUSUM']

    cusum_stat_clean, detections_clean = UCUSUM(clean, 
                                        target_mean=target_mean, 
                                        h=h_estimated_ucusum,
                                        simulation=simulation,
                                        sim_length=clean_sim_length)
    
    for f in fault:
        cusum_stat_fault, detections_fault = UCUSUM(f,
                                            target_mean=target_mean, 
                                            h=h_estimated_ucusum,
                                            simulation=simulation,
                                            sim_length=sim_length)
        
        detections_faults.append(detections_fault)


    cusum_detection_results['UCUSUM'] = {
                        'labels_clean': labels_clean,
                        'detections_clean': detections_clean,
                        'labels_fault': labels_fault,
                        'detections_fault': detections_faults,
                        'threshold': h_estimated_ucusum
                    }

    # cleanup
    gc.collect()
    del detections_clean, detections_fault, detections_faults

    # Variance CUSUM
    detections_faults = []

    h_estimated_variance = estimated_hs['variance_cusum']
    k_estimated_variance = estimated_ks['variance_cusum']

    cusum_stat_pos_clean, cusum_stat_neg_clean, detections_clean = variance_cusum(clean, 
                                        target_var=target_std, 
                                        window=cusums_parameters['variance_cusum']['window'], 
                                        k=k_estimated_variance, 
                                        h=h_estimated_variance,
                                        simulation=simulation,
                                        sim_length=clean_sim_length)

    for f in fault:
        cusum_stat_pos_fault, cusum_stat_neg_fault, detections_fault = variance_cusum(f, 
                                            target_var=target_std, 
                                            window=cusums_parameters['variance_cusum']['window'], 
                                            k=k_estimated_variance, 
                                            h=h_estimated_variance,
                                            simulation=simulation,
                                            sim_length=sim_length)
        
        detections_faults.append(detections_fault)

    cusum_detection_results['variance_cusum'] = {
                        'labels_clean': labels_clean,
                        'detections_clean': detections_clean,
                        'labels_fault': labels_fault,
                        'detections_fault': detections_faults, 
                        'threshold': h_estimated_variance
                    }
    # cleanup
    del  detections_clean, detections_fault, detections_faults

    return cusum_detection_results, dataset

# %%
# Function to run all CUSUMs on clean with noise.
def run_cusums_on_clean_with_noise(data,
                    dataset="", 
                    datasets_parameters = {},
                    models_parameters = {},
                    cusums_parameters = {},
                    run_on_residuals = False,
                    model = None,
                    classic_threshold = False,
                    START = 0,
                    noise = [0, 0, 0],
                    outliers = [0, 0, 0]):
    """
    Function to run all CUSUMs on clean with noise and injected outliers.
    - Set the parameters in the cusums_parameters dictionary
    - Set the parameters in the datasets_parameters dictionary
    - Set the parameters in the models_parameters dictionary
    - Feel free to add remove datasets, CUSUMs and parameters
    Arguments:
        data: data dictionary
        dataset: dataset name
        datasets_parameters: datasets parameters dictionary
        models_parameters: model parameters dictionary
        cusums_parameters: CUSUMs parameters dictionary
        run_on_residuals: True to run the CUSUMs on the residuals
        model: model object (keras)
        classic_threshold: True to use the classic threshold
    Returns:
        cusum_detection_results: CUSUMs detection results dict
            contains: labels, detections on clean data
    """
    
    if run_on_residuals == True:
        if model is None:
            raise Exception("Model is required when running on residuals")
        if models_parameters == {}:
            raise Exception("Models parameters are required when running on residuals")

    # Params.
    param_estimation_size = datasets_parameters['param_estimation_size']
    max_length = datasets_parameters['max_length']
    variable = datasets_parameters['variable']
    dropped_columns = datasets_parameters['dropped_columns']

    simulation = datasets_parameters['simulation']
    sim_length = datasets_parameters['sim_length'] if datasets_parameters['simulation'] is True else 0
    clean_sim_length = datasets_parameters['clean_sim_length'] if datasets_parameters['simulation'] is True else 0

    # Get Clean and Fault Data
    if run_on_residuals == False:
        if datasets_parameters['files'] is None:
            files = [datasets_parameters['default_clean_file'], 
                                                 datasets_parameters['default_fault_file']]
        else:
            files = datasets_parameters['files']
        
        clean, _, labels_clean, _ = \
                        get_clean_fault_data(dataset = dataset, 
                                            data = data, 
                                            param_estimation_size = param_estimation_size, 
                                            max_length = max_length,
                                            files = files,
                                            dropped_columns = dropped_columns,
                                            start = START)
    else:
        clean, _, labels_clean, _, _ = \
                        get_clean_fault_residuals_data(dataset = dataset, 
                                            data = data, 
                                            datasets_parameters = datasets_parameters,
                                            model = model,
                                            models_parameters = models_parameters,
                                            start = START)
        START = 0   
        
    # The Clean Data and Param Estimation Data
    if isinstance(clean, list):
        clean_data = [np.array(c[START:, variable], dtype=float) for c in clean]
    else:
        clean = np.array(clean)
        if clean.ndim == 1:
            clean_data = clean[START:].astype(float)
        else:
            clean_data = clean[START:, variable].astype(float)
       
    param_estimation = np.array(clean_data[:param_estimation_size])
    clean = np.array(clean_data[param_estimation_size:])


    # ADD NOISE to the clean data
    # Noise = [0 - normal, 1 - uniform, Mean (or MIN), STD or (MAX)]
    # As data is not normalized for the raw signals verios, 
    # the noise is added as percentage not as absolute values (RELATIVE NOISE!)

    noise_mean_or_min = noise[1]
    noise_std_or_max = noise[2] * np.std(clean)

    if noise != [0, 0, 0]:

        if noise[0] == 0:
            noise = np.random.normal(noise_mean_or_min, noise_std_or_max, size = clean.shape)
        elif noise[0] == 1:
            noise = np.random.uniform(noise_mean_or_min, noise_std_or_max, size = clean.shape)

        clean = clean + noise

    # Randomly add a percentage of outliers to the clean data
    # The percentage is given by outliers variable, at random positions.
    # Outliers are largers than the data itself

    if outliers != [0, 0, 0]:
        outliers_percentage = int(outliers[0] * clean.shape[0])
        outliers_min = outliers[1] * clean.min()
        outliers_max = outliers[2] * clean.max()

        outliers_positions = np.random.choice(clean.shape[0], size = outliers_percentage, replace = False)
        outliers_positions = np.sort(outliers_positions)

        # Random outliers, positive or negative
        for idx in outliers_positions:
            #sign = np.sign(clean[idx])
            sign = np.random.choice([-1, 1])
            magnitude = np.random.uniform(outliers_min, outliers_max)
            clean[idx] = sign * magnitude 

        # outliers_values = np.random.uniform(outliers_min, outliers_max, size = outliers_percentage)
        # clean[outliers_positions] = outliers_values

   #######################################################################################
    # Estimate Parameters for CUSUMs

    estimated_hs, estimated_ks, target_mean_std = \
                    estimate_cusums_parameters(param_estimation,
                                            classic_threshold = classic_threshold,
                                            cusums_parameters = cusums_parameters)
    
    target_mean = target_mean_std['all'][0]
    target_std = target_mean_std['all'][1]

    #######################################################################################

    # Detection Results    
    cusum_detection_results = { }
    # CUSUMS Detections on Clean Noisy Data

    # High Order CUSUMs
    h_estimated_ho = estimated_hs['high_order']
    k_estimated_ho = estimated_ks['high_order']
    exp_x = target_mean_std['high_order']

    cusum_stat_pos, cusum_stat_neg, _, detections_clean = high_order_cusum(clean, 
                                            window = cusums_parameters['high_order']['window'], 
                                            alpha = cusums_parameters['high_order']['alpha'],
                                            exp_x=exp_x,
                                            k=k_estimated_ho, 
                                            h=h_estimated_ho,
                                            simulation=simulation,
                                            sim_length=clean_sim_length)
    
    cusum_detection_results['high_order'] = {
                        'labels_clean': labels_clean,
                        'detections_clean': detections_clean,
                        'threshold': h_estimated_ho}
    # cleanup
    gc.collect()
    del detections_clean

    # Classical CUSUMs
    h_estimated_classical = estimated_hs['classical']
    k_estimated_classical = estimated_ks['classical']

    pos_clean, neg_clean, detections_clean = classical_cusum(clean, 
                                       target_mean=target_mean, 
                                       std_dev=target_std, 
                                       k=k_estimated_classical, 
                                       h=h_estimated_classical, 
                                       simulation=simulation,
                                       sim_length=clean_sim_length)
    
    cusum_detection_results['classical'] = {
                        'labels_clean': labels_clean,
                        'detections_clean': detections_clean,
                        'threshold': h_estimated_classical}
    # cleanup
    gc.collect()
    del detections_clean

    # One CUSUM Scheme
    h_estimated_one = estimated_hs['one_cusum_scheme']
    k_estimated_one = estimated_ks['one_cusum_scheme']

    cusum_stat_clean, detections_clean = one_cusum_scheme(clean, 
                                          target_mean=target_mean, 
                                          k=k_estimated_one, 
                                          h=h_estimated_one, 
                                          lamb=cusums_parameters['one_cusum_scheme']['lamb'],
                                          simulation=simulation, 
                                          sim_length=clean_sim_length) 

    cusum_detection_results['one_cusum_scheme'] = {
                        'labels_clean': labels_clean,
                        'detections_clean': detections_clean,
                        'threshold': h_estimated_one}
    
    # cleanup
    gc.collect()
    del detections_clean

    # Hampel CUSUMs
    h_estimated_hampel = estimated_hs['hampel_acusum']
    k_estimated_hampel = estimated_ks['hampel_acusum']
    cusum_stat_pos_clean, cusum_stat_neg_clean, detections_clean = \
                                    hampel_acusum(clean, 
                                       a=cusums_parameters['hampel_acusum']['a'], 
                                       b=cusums_parameters['hampel_acusum']['b'], 
                                       r=cusums_parameters['hampel_acusum']['r'], 
                                       gamma=cusums_parameters['hampel_acusum']['gamma'], 
                                       h=h_estimated_hampel, 
                                       k_plus=k_estimated_hampel, 
                                       k_minus=k_estimated_hampel,
                                       simulation=simulation,
                                       sim_length=clean_sim_length)

    cusum_detection_results['hampel'] = {
                        'labels_clean': labels_clean,
                        'detections_clean': detections_clean,
                        'threshold': h_estimated_hampel}
    
    gc.collect()
    del detections_clean

    # UCUSUM
    h_estimated_ucusum = estimated_hs['UCUSUM']

    cusum_stat_clean, detections_clean = UCUSUM(clean, 
                                        target_mean=target_mean, 
                                        h=h_estimated_ucusum)
    
    cusum_detection_results['UCUSUM'] = {
                        'labels_clean': labels_clean,
                        'detections_clean': detections_clean,
                        'threshold': h_estimated_ucusum}
    gc.collect()
    del detections_clean

    # Variance CUSUM
    h_estimated_variance = estimated_hs['variance_cusum']
    k_estimated_variance = estimated_ks['variance_cusum']
    
    cusum_stat_pos_clean, cusum_stat_neg_clean, detections_clean = variance_cusum(clean, 
                                        target_var=target_std, 
                                        window=cusums_parameters['variance_cusum']['window'], 
                                        k=k_estimated_variance, 
                                        h=h_estimated_variance, 
                                        simulation=simulation,
                                        sim_length=clean_sim_length)
    
    cusum_detection_results['variance_cusum'] = {
                        'labels_clean': labels_clean,
                        'detections_clean': detections_clean,
                        'threshold': h_estimated_variance}
    
    return cusum_detection_results

# %%
# Function to run all CUSUMs on fault for resilience
def run_cusums_for_resilience(data,
                    dataset="", 
                    datasets_parameters = {},
                    models_parameters = {},
                    cusums_parameters = {},
                    run_on_residuals = False,
                    model = None,
                    classic_threshold = False,
                    start = 0):
    """
    Function to run all CUSUMs on clean with noise and injected outliers.
    - Set the parameters in the cusums_parameters dictionary
    - Set the parameters in the datasets_parameters dictionary
    - Set the parameters in the models_parameters dictionary
    - Feel free to add remove datasets, CUSUMs and parameters
    Parameters
    ----------
    data : pandas.DataFrame
        Dataframe with the data
    dataset : str
        Dataset name
    datasets_parameters : dict
        Dictionary with the parameters for the datasets
    models_parameters : dict
        Dictionary with the parameters for the models
    cusums_parameters : dict
        Dictionary with the parameters for the CUSUMs
    run_on_residuals : bool
        True to run the CUSUMs on the residuals
    model : keras.Model
        Model to use
    classic_threshold : bool
        True to use the classic threshold
    START : int
        Start index for the data
    Returns
    -------
    cusum_detection_results : dict
        Dictionary with the CUSUM detection results
    """

    if run_on_residuals:
        if model is None:
            raise Exception("Model is required to run CUSUMs on residuals")
        if models_parameters is None:
            raise Exception("Models parameters are required to run CUSUMs on residuals")
        
    param_estimation_size = datasets_parameters['param_estimation_size']
    max_length = datasets_parameters['max_length']
    variable = datasets_parameters['variable']
    dropped_columns = datasets_parameters['dropped_columns']

    simulation = datasets_parameters['simulation']
    sim_length = datasets_parameters['sim_length'] if datasets_parameters['simulation'] is True else 0
    clean_sim_length = datasets_parameters['clean_sim_length']
    
    # Get Clean and Fault Data
    residuals_text = "residuals_" if run_on_residuals else ""

    resilience_data_file = "datasets/resilience_data_" + \
                        str(max_length) + "_" + \
                        str(param_estimation_size) + "_" +\
                        str(variable) + "_" + \
                        str(residuals_text) + "_" + \
                        dataset + ".pkl"
    
    # If any data is saved, load it
    if os.path.exists(resilience_data_file):
       resilience_data = load_pickle(resilience_data_file)

       param_estimation = resilience_data['param_estimation']
       fault = resilience_data['fault']
       labels_fault = resilience_data['labels_fault']

    else:
        if run_on_residuals == False:
            if datasets_parameters['files'] is None:
                files = [datasets_parameters['default_clean_file'], 
                                                    datasets_parameters['default_fault_file']]
            else:
                files = datasets_parameters['files']
            
            clean, fault, labels_clean, labels_fault = \
                            get_clean_fault_data(dataset = dataset, 
                                                data = data, 
                                                param_estimation_size = param_estimation_size, 
                                                max_length = max_length,
                                                files = files,
                                                dropped_columns = dropped_columns,
                                                start = start)
        else:
            clean, fault, labels_clean, labels_fault, _ = \
                            get_clean_fault_residuals_data(dataset = dataset, 
                                                data = data, 
                                                datasets_parameters = datasets_parameters,
                                                model = model,
                                                models_parameters = models_parameters,
                                                start = start)
            start = 0
        

        # The Clean Data and Param Estimation Data
        if isinstance(clean, list):
            clean_data = [np.array(c[start:, variable], dtype=float) for c in clean]
        else:
            clean = np.array(clean)
            if clean.ndim == 1:
                clean_data = clean[start:].astype(float)
            else:
                clean_data = clean[start:, variable].astype(float)
        
        param_estimation = np.array(clean_data[:param_estimation_size])
        clean = np.array(clean_data[param_estimation_size:])

        if not run_on_residuals:
            fault = [np.array(f[:, variable], dtype=float) for f in fault]

        # Resilience experiment. As such, we will concatenate the clean data afetr the faulty data.
        RESILIENCE_CLEAN_DATA_MULTIPLIER = datasets_parameters['RESILIENCE_CLEAN_DATA_MULTIPLIER']

        if simulation == True:
            
            clean_tmp = np.array(clean[0: RESILIENCE_CLEAN_DATA_MULTIPLIER * clean_sim_length], dtype=float)
            max_rows = fault[0].shape[0] - fault[0].shape[0] % sim_length
            num_simulations = fault[0].shape[0] // sim_length
            
            clean_rows = np.tile(clean_tmp, (num_simulations, 1))

            for i in range(len(fault)):
                # reshape to sim length as a 2D and add clean on each row

                fault_reshaped = fault[i][0:max_rows].reshape((num_simulations, sim_length))
                combined = np.concatenate((fault_reshaped, clean_rows), axis=1)
                fault[i] = combined.reshape(-1)

            # Same magic for labels
            labels_clean_tmp = np.zeros(RESILIENCE_CLEAN_DATA_MULTIPLIER * clean_sim_length)
            
            labels_fault_reshaped = labels_fault[0:max_rows].reshape((num_simulations, sim_length))
            labels_clean_rows = np.tile(labels_clean_tmp, (num_simulations, 1))
            
            combined = np.concatenate((labels_fault_reshaped, labels_clean_rows), axis=1)
            labels_fault = combined.reshape(-1)
                
        else:
            clean_tmp = np.array(clean[0: RESILIENCE_CLEAN_DATA_MULTIPLIER * clean_sim_length], dtype=float)
            for i in range(len(fault)):
                # Fault Data
                fault[i] = np.concatenate((fault[i], clean_tmp), axis=0)

            labels_clean_tmp = np.zeros(RESILIENCE_CLEAN_DATA_MULTIPLIER * clean_sim_length)
            if type(labels_fault) == list:
                for i in range(len(labels_fault)):
                    labels_fault[i] = np.concatenate((labels_fault[i], labels_clean), axis=0)
            else:
                labels_fault = np.concatenate((labels_fault, labels_clean), axis=0)
        
        resilience_data = {
            "param_estimation": param_estimation,
            "fault": fault,
            "labels_fault": labels_fault
        }

        save_pickle(resilience_data, resilience_data_file)

    # Data structures used from this point on:
    # param_estimation, fault, labels_clean, labels_fault

   #######################################################################################
    # Estimate Parameters for CUSUMs

    estimated_hs, estimated_ks, target_mean_std = \
                    estimate_cusums_parameters(param_estimation,
                                            classic_threshold = classic_threshold,
                                            cusums_parameters = cusums_parameters)
    
    target_mean = target_mean_std['all'][0]
    target_std = target_mean_std['all'][1]

    #######################################################################################
    # Detection Results    
    cusum_detection_results = { }

    # CUSUMS Detections on Clean Data and Faulty Data
    
    # High Order CUSUMs
    h_estimated_ho = estimated_hs['high_order']
    k_estimated_ho = estimated_ks['high_order']
    exp_x = target_mean_std['high_order']

    detections_faults = []
    cusums_stats_faults_pos = []
    cusums_stats_faults_neg = []

    for f in fault:
        cusum_stat_pos, cusum_stat_neg, _, detections_fault = high_order_cusum(f, 
                                                window = cusums_parameters['high_order']['window'],
                                                alpha = cusums_parameters['high_order']['alpha'],
                                                exp_x=exp_x,
                                                k=k_estimated_ho, 
                                                h=h_estimated_ho,
                                                simulation=simulation,
                                                sim_length=sim_length,
                                                resilience=True)
        
        detections_faults.append(detections_fault)
        cusums_stats_faults_pos.append(cusum_stat_pos)
        cusums_stats_faults_neg.append(cusum_stat_neg)

    cusum_detection_results['high_order'] = {
                        'labels_fault': labels_fault,
                        'cusum_stat_pos': cusums_stats_faults_pos,
                        'cusum_stat_neg': cusums_stats_faults_neg,
                        'detections_fault': detections_faults,
                        'threshold': h_estimated_ho}

    # cleanup
    gc.collect()
    del detections_fault, detections_faults, cusums_stats_faults_pos, cusums_stats_faults_neg

    # Classical CUSUMs
    h_estimated_classical = estimated_hs['classical']
    k_estimated_classical = estimated_ks['classical']

    detections_faults = []
    cusums_stats_faults_pos = []
    cusums_stats_faults_neg = []

    for f in fault:
        pos_fault, neg_fault, detections_fault = classical_cusum(f, 
                                                target_mean=target_mean, 
                                                std_dev=target_std, 
                                                k=k_estimated_classical, 
                                                h=h_estimated_classical,
                                                simulation=simulation,
                                                sim_length=sim_length,
                                                resilience=True)
        
        detections_faults.append(detections_fault)
        cusums_stats_faults_pos.append(pos_fault)
        cusums_stats_faults_neg.append(neg_fault)

    cusum_detection_results['classical'] = {
                        'labels_fault': labels_fault,
                        'cusum_stat_pos': cusums_stats_faults_pos,
                        'cusum_stat_neg': cusums_stats_faults_neg,
                        'detections_fault': detections_faults,
                        'threshold': h_estimated_classical
                    }

    # cleanup
    gc.collect()
    del detections_fault, detections_faults, cusums_stats_faults_pos, cusums_stats_faults_neg

    # One CUSUM Scheme
    h_estimated_one = estimated_hs['one_cusum_scheme']
    k_estimated_one = estimated_ks['one_cusum_scheme']

    detections_faults = []
    cusums_stats_faults_pos = []
    cusums_stats_faults_neg = []

    for f in fault:
        cusum_stat_fault, detections_fault = one_cusum_scheme(f, 
                                              target_mean=target_mean, 
                                              k=k_estimated_one, 
                                              h=h_estimated_one, 
                                              lamb=cusums_parameters['one_cusum_scheme']['lamb'],
                                              simulation=simulation,
                                              sim_length=sim_length,
                                              resilience=True) 
        
        detections_faults.append(detections_fault)
        cusums_stats_faults_neg.append(cusum_stat_fault)

    cusum_detection_results['one_cusum_scheme'] = {
                        'labels_fault': labels_fault,
                        'cusum_stat_pos': cusums_stats_faults_neg,
                        'cusum_stat_neg': None,
                        'detections_fault': detections_faults,
                        'threshold': h_estimated_one
                    }

    # cleanup
    gc.collect()
    del  detections_fault, detections_faults, cusums_stats_faults_neg

    # Hampel CUSUMs
    h_estimated_hampel = estimated_hs['hampel_acusum']
    k_estimated_hampel = estimated_ks['hampel_acusum']

    detections_faults = []
    cusums_stats_faults_pos = []
    cusums_stats_faults_neg = []

    for f in fault:
        cusum_stat_pos_fault, cusum_stat_neg_fault, detections_fault = \
                                        hampel_acusum(f, 
                                            a=cusums_parameters['hampel_acusum']['a'], 
                                            b=cusums_parameters['hampel_acusum']['b'], 
                                            r=cusums_parameters['hampel_acusum']['r'], 
                                            gamma=cusums_parameters['hampel_acusum']['gamma'], 
                                            h=h_estimated_hampel, 
                                            k_plus=k_estimated_hampel, 
                                            k_minus=k_estimated_hampel,
                                            simulation=simulation,
                                            sim_length=sim_length,
                                            resilience=True)
        
        #cusum_stat_fault = np.maximum(cusum_stat_pos_fault, cusum_stat_neg_fault)
        detections_faults.append(detections_fault)
        cusums_stats_faults_pos.append(cusum_stat_pos_fault)
        cusums_stats_faults_neg.append(cusum_stat_neg_fault)

    cusum_detection_results['hampel'] = {
                        'labels_fault': labels_fault,
                        'cusum_stat_pos': cusums_stats_faults_pos,
                        'cusum_stat_neg': cusums_stats_faults_neg,
                        'detections_fault': detections_faults,
                        'threshold': h_estimated_hampel}
    # cleanup
    gc.collect()
    del detections_fault, detections_faults, cusums_stats_faults_pos, cusums_stats_faults_neg

    cusum_stat_pos_fault = np.maximum(cusum_stat_pos_fault, cusum_stat_neg_fault)

    # UCUSUM Mean Shift
    
    h_estimated_ucusum = estimated_hs['UCUSUM']

    detections_faults = []
    cusums_stats_faults_pos = []
    cusums_stats_faults_neg = []

    for f in fault:
        cusum_stat_fault, detections_fault = UCUSUM(f,
                                            target_mean=target_mean, 
                                            h=h_estimated_ucusum,
                                            simulation=simulation,
                                            sim_length=sim_length,
                                            resilience=True)
        
        detections_faults.append(detections_fault)
        cusums_stats_faults_pos.append(cusum_stat_fault)

    cusum_detection_results['UCUSUM'] = {
                        'labels_fault': labels_fault,
                        'cusum_stat_pos': cusums_stats_faults_pos,
                        'cusum_stat_neg': None,
                        'detections_fault': detections_faults,
                        'threshold': h_estimated_ucusum
                    }

    # cleanup
    gc.collect()
    del detections_fault, detections_faults, cusums_stats_faults_pos, cusums_stats_faults_neg

    # Variance CUSUM
    h_estimated_variance = estimated_hs['variance_cusum']
    k_estimated_variance = estimated_ks['variance_cusum']

    detections_faults = []
    cusums_stats_faults_pos = []
    cusums_stats_faults_neg = []

    for f in fault:
        cusum_stat_pos_fault, cusum_stat_neg_fault, detections_fault = variance_cusum(f, 
                                            target_var=target_std, 
                                            window=cusums_parameters['variance_cusum']['window'], 
                                            k=k_estimated_variance, 
                                            h=h_estimated_variance,
                                            simulation=simulation,
                                            sim_length=sim_length,
                                            resilience=True)
        
        detections_faults.append(detections_fault)
        cusums_stats_faults_pos.append(cusum_stat_pos_fault)
        cusums_stats_faults_neg.append(cusum_stat_neg_fault)

    cusum_detection_results['variance_cusum'] = {
                        'labels_fault': labels_fault,
                        'cusum_stat_pos': cusums_stats_faults_pos,
                        'cusum_stat_neg': cusums_stats_faults_neg,
                        'detections_fault': detections_faults, 
                        'threshold': h_estimated_variance
                    }
    # cleanup
    del detections_fault, detections_faults, cusums_stats_faults_pos, cusums_stats_faults_neg

    return cusum_detection_results

# %%
# Function to compute all results

def compute_results(cusum_detection_results = None, 
                    dataset = "TEP", 
                    mode = "standard",
                    simulation = False,
                    sim_length = 1000):
    """
    Compute all results for all CUSUMs

    Parameters
    ----------
    cusum_detection_results : list or np.array
        Data structure with all CUSUM detection results
    dataset : str
        Dataset name
    mode : str
        Mode of the experiment
            - standard: FPR, TPR, DD
            - robust or resilience: robustness or resilience
    """

    if cusum_detection_results is None:
        raise ValueError("CUSUM detection results is None")

    if mode not in ["standard", "robust", "resilience"]:
        raise ValueError(f"Mode {mode} is not supported \
                         - supported modes are: \
                         'standard', 'robust', 'resilience'")

    if mode == 'standard':
        # Compute FPR and TPR for each CUSUM method
        for csm, detection in cusum_detection_results.items():

            labels_clean = detection['labels_clean']
            detections_clean = detection['detections_clean']
            labels_clean = labels_clean[:len(detections_clean)]

            print(f"Results for {csm} CUSUM on {dataset} dataset:")
            print(f"Number of detections on clean data: {sum(detections_clean)}")
            fpr = sum(detections_clean) / len(detections_clean)
            print(f"FPR: {fpr}")

            labels_fault = detection['labels_fault']
            detections_fault = detection['detections_fault']
            
            TPRs, DDelay = [], []

            if type(labels_fault) != list and labels_fault.ndim == 1:
                labels_fault = labels_fault[:len(detections_fault[0])]
                for i, det_fault in enumerate(detections_fault):
                    # print(f"Fault number: {i}:")
                    # print(f"Number of detections on faulty data: {sum(det_fault)}")
                    maxlen = min(len(det_fault), len(labels_fault))
                    
                    d_fault = det_fault[:maxlen]
                    lbl_fault = labels_fault[:maxlen]

                    results = tpr_fpr_dd(lbl_fault, d_fault)
                    TPRs.append(results['TPR'])

                    if results['DD'] != -1:
                        # Only append delay if it is not -1
                        # which means that the delay was computed
                        # and the fault was detected
                        DDelay.append(results['DD'])
                    
                # Compute delay only for data that was actually detected
                print(f"TPR: {np.mean(TPRs)}, DD: {np.mean(DDelay)} \n")

                return np.mean(TPRs), np.mean(DDelay)
            else:
                for i, det_fault in enumerate(detections_fault):
                    lbl_fault = labels_fault[i][:len(detections_fault[i])]
                    # print(f"Fault number: {i}:")
                    # print(f"Number of detections on faulty data: {sum(det_fault)}")
                    maxlen = min(len(det_fault), len(lbl_fault))
                    
                    d_fault = det_fault[:maxlen]
                    lbl_fault = lbl_fault[:maxlen]
                    
                    results = tpr_fpr_dd(lbl_fault, d_fault)
                    TPRs.append(results['TPR'])
                    # FPRs.append(results['FPR'])
                    if results['DD'] != -1:
                        # Only append delay if it is not -1
                        # which means that the delay was computed
                        # and the fault was detected
                        DDelay.append(results['DD'])

                print(f"TPR: {np.mean(TPRs)}, DD: {np.mean(DDelay)} \n")
                return np.mean(TPRs), np.mean(DDelay)

    elif mode == 'robust':
        # Compute robustness metrics for each CUSUM method
        FARNs, SIs = [], []
        for csm, detection in cusum_detection_results.items():

            labels_clean = detection['labels_clean']
            detections_clean = detection['detections_clean']
            threshold = detection['threshold']

            print(f"Results for {csm} CUSUM on {dataset} dataset:")

            FAR_N, SI = robustness_metric(stat=detections_clean, 
                            threshold=threshold)
            
            print(f"FAR_N: {FAR_N}, SI: {SI}")
            FARNs.append(FAR_N)
            SIs.append(SI)

        return FARNs, SIs

    elif mode == "resilience":
        # Compute resilience metrics for each CUSUM method
        for csm, detection in cusum_detection_results.items():
            
            cusum_stat_pos = detection['cusum_stat_pos']
            cusum_stat_neg = detection['cusum_stat_neg']

            labels_fault = detection['labels_fault']
            detections_fault = detection['detections_fault']
            threshold = detection['threshold']

            print(f"Results for {csm} CUSUM on {dataset} dataset:")
            if simulation:
                labels_fault = np.array(labels_fault)
                padded = np.pad(labels_fault, (0, 1), mode='constant', constant_values=0)
                last_anomaly_in_data = np.where((padded[:-1] == 1) & (padded[1:] == 0))[0]
                last_anomaly_index = last_anomaly_in_data[0]
                last_anomaly_in_data = [last_anomaly_index] * len(cusum_stat_pos)

            else:
                if is_list_of_arrays(labels_fault):
                    last_anomaly_in_data = [np.where(labels_fault[i] == 1)[0][-1] for i in range(len(labels_fault))]
                else:
                    last_anomaly_in_data = np.where(labels_fault == 1)[0][-1]

            if is_list_of_arrays(cusum_stat_pos):

                recovery_times_list = []
                stability_times_list = []
                
                for i in range(len(cusum_stat_pos)):

                    stat_neg = cusum_stat_neg[i] if cusum_stat_neg is not None else None
                    last_anomaly_data = last_anomaly_in_data[i] if is_flat_list(last_anomaly_in_data) else last_anomaly_in_data

                    recovery_time, stability_time = resilience_metric(stat_pos=cusum_stat_pos[i],
                                                            stat_neg=stat_neg,
                                                            threshold=threshold,
                                                            last_anomaly_in_data=last_anomaly_data,
                                                            simulation=simulation,
                                                            sim_length=sim_length)

                    recovery_times_list.append(recovery_time)
                    stability_times_list.append(stability_time)

                unrecovered_RT = [rt for rt in recovery_times_list if rt == -1]
                unrecovered_ST = [st for st in stability_times_list if st == -1]
                
                # Calculate the mean of the recovery and stability times
                # Without unrecovered times
                if len(unrecovered_RT) > 0:
                    recovery_times_list = [rt for rt in recovery_times_list if rt != -1]
                
                if len(unrecovered_ST) > 0:
                    stability_times_list = [st for st in stability_times_list if st != -1]

                recovery_time = np.mean(recovery_times_list)
                stability_time = np.mean(stability_times_list)
                
            else:
                recovery_time, stability_time = resilience_metric(stat_pos=cusum_stat_pos,
                                                            stat_neg=cusum_stat_neg,
                                                            threshold=threshold,
                                                            last_anomaly_in_data=last_anomaly_data,
                                                            simulation=simulation,
                                                            sim_length=sim_length)

            print(f"Recovery Time: {recovery_time}, Stability Time: {stability_time}")
            print(f"Unrecovered Recovery Times: {len(unrecovered_RT)}, Unrecovered Stability Times: {len(unrecovered_ST)}")
            print()
            
            return recovery_time, stability_time, len(unrecovered_RT), len(unrecovered_ST)

# %%
# Function to run all CUSUMs for Time Measurement
def run_all_cusums_time_meas(data,
                        dataset="", 
                        datasets_parameters = {},
                        models_parameters = {},
                        cusums_parameters = {},
                        plots = False,
                        model = None,
                        run_on_residuals = False,
                        classic_threshold = False,
                        start = 0,
                        measure_time = False):
    """
        Function to run all CUSUMs
        - Set the parameters in the cusums_parameters dictionary
        - Set the parameters in the datasets_parameters dictionary
        - Set the parameters in the models_parameters dictionary
        - Feel free to add remove datasets, CUSUMs and parameters
        Arguments:
            data: data dictionary
            dataset: dataset name
            datasets_parameters: datasets parameters dictionary
            plots: True to plot the results
            run_on_residuals: True to run the CUSUMs on the residuals
            cusums_parameters: CUSUMs parameters dictionary
            model: model object (keras)
            models_parameters: model parameters dictionary
            classic_threshold: True to use the classic threshold
        Returns:
            cusum_detection_results: CUSUMs detection results dict
                contains: labels, detections on clean and fault data
            dataset: dataset name
    """
    # Params.
    param_estimation_size = datasets_parameters['param_estimation_size']
    max_length = datasets_parameters['max_length']
    variable = datasets_parameters['variable']
    dropped_columns = datasets_parameters['dropped_columns']
    simulation = datasets_parameters['simulation']
    sim_length = datasets_parameters['sim_length'] if datasets_parameters['simulation'] is True else 0

    # Get Clean and Fault Data
    if run_on_residuals == False:
        if datasets_parameters['files'] is None:
            files = [datasets_parameters['default_clean_file'], 
                                                 datasets_parameters['default_fault_file']]
        else:
            files = datasets_parameters['files']
        
        clean, fault, labels_clean, labels_fault = \
                        get_clean_fault_data(dataset = dataset, 
                                            data = data, 
                                            param_estimation_size = param_estimation_size, 
                                            max_length = max_length,
                                            files = files,
                                            dropped_columns = dropped_columns,
                                            start = start)
    else:
        clean, fault, _, _, results_model_time = \
                        get_clean_fault_residuals_data(dataset = dataset, 
                                            data = data, 
                                            datasets_parameters = datasets_parameters,
                                            model = model,
                                            models_parameters = models_parameters,
                                            start = start)
        start = 0

    # The Clean Data and Param Estimation Data
    if isinstance(clean, list):
        clean_data = [np.array(c[start:, variable], dtype=float) for c in clean]
    else:
        clean = np.array(clean)
        if clean.ndim == 1:
            clean_data = clean[start:].astype(float)
        else:
            clean_data = clean[start:, variable].astype(float)
       
    param_estimation = np.array(clean_data[:param_estimation_size])
    clean = np.array(clean_data[param_estimation_size:])

    if not run_on_residuals:
        fault = [np.array(f[:, variable], dtype=float) for f in fault]


    #######################################################################################
    # Estimate Parameters for CUSUMs

    estimated_hs, estimated_ks, target_mean_std = \
                    estimate_cusums_parameters(param_estimation,
                                            classic_threshold = classic_threshold,
                                            cusums_parameters = cusums_parameters)
    
    target_mean = target_mean_std['all'][0]
    target_std = target_mean_std['all'][1]

    #######################################################################################
    # Detection Results    
    time_results = {}

    h_estimated_ho = estimated_hs['high_order']
    k_estimated_ho = estimated_ks['high_order']
    exp_x = target_mean_std['high_order']

    start = time.process_time()
    _, _, _, _ = high_order_cusum(fault[0], 
                                    window = cusums_parameters['high_order']['window'],
                                    alpha = cusums_parameters['high_order']['alpha'],
                                    exp_x=exp_x,
                                    k=k_estimated_ho, 
                                    h=h_estimated_ho,
                                    simulation=simulation,
                                    sim_length=sim_length
                                    )
    end = time.process_time()
    time_results['high_order'] = end - start

    h_estimated_classical = estimated_hs['classical']
    k_estimated_classical = estimated_ks['classical']

    start = time.process_time()
    _, _, _ = classical_cusum(fault[0], 
                                target_mean=target_mean, 
                                std_dev=target_std, 
                                k=k_estimated_classical, 
                                h=h_estimated_classical,
                                simulation=simulation,
                                sim_length=sim_length)
    end = time.process_time()
    time_results['classical'] = end - start

    h_estimated_one = estimated_hs['one_cusum_scheme']
    k_estimated_one = estimated_ks['one_cusum_scheme']

    start = time.process_time()
    _, _ = one_cusum_scheme(fault[0], 
                            target_mean=target_mean, 
                            k=k_estimated_one, 
                            h=h_estimated_one, 
                            lamb=cusums_parameters['one_cusum_scheme']['lamb'],
                            simulation=simulation,
                            sim_length=sim_length) 
    end = time.process_time()
    time_results['one_cusum_scheme'] = end - start

    h_estimated_hampel = estimated_hs['hampel_acusum']
    k_estimated_hampel = estimated_ks['hampel_acusum']

    start = time.process_time()
    _, _, _ =  hampel_acusum(fault[0], 
                            a=cusums_parameters['hampel_acusum']['a'], 
                            b=cusums_parameters['hampel_acusum']['b'], 
                            r=cusums_parameters['hampel_acusum']['r'], 
                            gamma=cusums_parameters['hampel_acusum']['gamma'], 
                            h=h_estimated_hampel, 
                            k_plus=k_estimated_hampel, 
                            k_minus=k_estimated_hampel,
                            simulation=simulation,
                            sim_length=sim_length)
    end = time.process_time()
    time_results['hampel_acusum'] = end - start

    h_estimated_ucusum = estimated_hs['UCUSUM']

    start = time.process_time()
    _, _ = UCUSUM(fault[0],
                    target_mean=target_mean, 
                    h=h_estimated_ucusum,
                    simulation=simulation,
                    sim_length=sim_length)
    end = time.process_time()
    time_results['UCUSUM'] = end - start

    h_estimated_variance = estimated_hs['variance_cusum']
    k_estimated_variance = estimated_ks['variance_cusum']

    start = time.process_time()
    _, _, _ = variance_cusum(fault[0], 
                                    target_var=target_std, 
                                    window=cusums_parameters['variance_cusum']['window'], 
                                    k=k_estimated_variance, 
                                    h=h_estimated_variance,
                                    simulation=simulation,
                                    sim_length=sim_length)
    end = time.process_time()
    time_results['variance_cusum'] = end - start

    if run_on_residuals == False:
        results_model_time = None
    
    return time_results, results_model_time

# %% [markdown]
# #### **Parameters for the Experiments**

# %%
# Parameters - CUSUM
cusums_parameters = {
    'classical': {
        'h': 3, 
        'shift_size': 1
    },
    'one_cusum_scheme': {
        'h': 3,
        'lamb': 0.5,  # Smoothing factor
        'shift_size': 1
    },
    'hampel_acusum': {
        'a': 3,
        'b': 3.5, 
        'r': 3, 
        'gamma': 4.5, 
        'h': 3,
        'shift_size': 1
    },  
    'UCUSUM': {
        'h': 3, 
        'window': 30, 
        'target_mean': 0,  # Expected mean under normal conditions
    },
    'variance_cusum': {
        'h': 3,
        'window': 20,
        'target_var': 1,  # Expected variance under normal conditions
        'k': 1,  # Reference value
        'shift_size': 1
    },
    'high_order': {
        'h':3,  
        'alpha': 0.5,
        'window': 30, 
        'shift_size': 1
    }
}

# %%
# Parameters - Datasets

PARAM_ESTIMATION_SIZE = 8_000
MAX_LENGTH = 50_000

PARAM_ESTIMATION_SIZE = 500
MAX_LENGTH = 2500

PARAM_ESTIMATION_SIZE = 10_000
MAX_LENGTH = 100_000

datasets_parameters = {
    'TEP': {
        'variable': 6, 
        'param_estimation_size': PARAM_ESTIMATION_SIZE, 
        'max_length': MAX_LENGTH,
        'inputs': [0, 1, 2, 6, 9, 33],
        'outputs': [6],
        'default_clean_file': 'clean',
        'default_fault_file': 'FaultyTest_13.csv',
        'files': "all",
        'dropped_columns': [0, 1, 2],
        'simulation': True,
        'sim_length': 960,
        'clean_sim_length': 500,
        'RESILIENCE_CLEAN_DATA_MULTIPLIER':5
    },
    
    'LBNL': {
        'variable': 12, #8, 
        'param_estimation_size': PARAM_ESTIMATION_SIZE, 
        'max_length': MAX_LENGTH,   
        'inputs': [0, 1, 2, 3, 17, 18],
        'outputs': [12], # [8],
        'default_clean_file': 'clean',
        'default_fault_file': 'BoilerPlant_boiler_foul_095.csv',
        'files': "all",
        'dropped_columns': [0],
        'simulation': False,
        'RESILIENCE_CLEAN_DATA_MULTIPLIER':5,
        'clean_sim_length': 500
    },
    'SKAB': {
        'variable': 2, 
        'param_estimation_size': PARAM_ESTIMATION_SIZE, 
        'max_length': MAX_LENGTH,
        'inputs': [0, 1, 2, 4],
        'outputs': [2],
        'default_clean_file': 'clean',
        'default_fault_file': '1.csv',
        'files': "all",
        'dropped_columns': [0],
        'simulation': False,
        'RESILIENCE_CLEAN_DATA_MULTIPLIER':5,
        'clean_sim_length': 500
    },
    'RMFD': {
        'variable': 2, 
        'param_estimation_size': PARAM_ESTIMATION_SIZE, 
        'max_length': MAX_LENGTH,
        'inputs': [0, 1],
        'outputs': [2],
        'default_clean_file': 'H1.mat',
        'default_fault_file': 'F1.mat',
        'files': "all",
        'dropped_columns': None,
        'simulation': False,
        'RESILIENCE_CLEAN_DATA_MULTIPLIER':5,
        'clean_sim_length': 500
    },
    'VSD': {
        'variable': 0, 
        'param_estimation_size': PARAM_ESTIMATION_SIZE, 
        'max_length': MAX_LENGTH,
        'inputs': [0],
        'outputs': [0],
        'default_clean_file': 0,
        'default_fault_file': 0,
        'files': "all",
        'dropped_columns': None,
        'simulation': False,
        'RESILIENCE_CLEAN_DATA_MULTIPLIER':5,
        'clean_sim_length': 500
    }
}

# %%
# Parameters - ML Models
models_parameters = {
        'models': 'LSTM',
        'seq_len': 40,
        'num_layers': 1,
        'hidden_size': [32],
        'LR': 0.01,
        'batch_size': 16,
        'epochs': 100,
        'train_ratio': 0.5,
        'optimizer': 'Adam',
        'loss': 'MSE',
        'metrics': ['accuracy'],
        'seed': 42,
        'TF': True,
        'stateful': True
}

# To have the same data for raw and residuals
# When the models are trained, the training data will not be used for param estimation
# When raw signals are used, the training data is skipped...
# Just to have a fair comparison between raw and residuals

TRAINING_SIZE = int(MAX_LENGTH * models_parameters['train_ratio'])
START = TRAINING_SIZE

# %% [markdown]
# #### **TPR, FPR, DD Experiment Execution**

# %%
# Plot DATASETS COMPARISON

VARIABLES = {
    'TEP' : 8,
    'LBNL' : 8,
    'SKAB' : 2,
    'RMFD' :2,
    'VSD' : 0,
    'SIZE' : 1000
}
# Get all file names in the fault directory



clean = np.array(data['TEP']['clean']['clean'].values)
fault = np.array(data['TEP']['fault']['FaultyTest_13.csv'].values)


clean = clean[:, VARIABLES['TEP']]
fault = fault[:, VARIABLES['TEP']]

plot_data_comparison(clean=clean[0:VARIABLES['SIZE']], 
                    anomaly=fault[0:VARIABLES['SIZE']], 
                    plot_labels=["Clean Data", "Fault Data"],
                    dataset="Tennesse Eastman Process")

clean = data['LBNL']['clean'].values
fault = data['LBNL']['fault']['BoilerPlant_boiler_foul_095.csv'].values

clean = clean[:, VARIABLES['LBNL']]
fault = fault[:, VARIABLES['LBNL']]

plot_data_comparison(clean=clean[0:VARIABLES['SIZE']], 
                    anomaly=fault[0:VARIABLES['SIZE']], 
                    plot_labels=["Clean Data", "Fault Data"],
                    dataset="LBNL")

clean = data['SKAB']['clean'].values
fault = data['SKAB']['fault']['fault_1']['0.csv'].values

clean = clean[:, VARIABLES['SKAB']]
fault = fault[:, VARIABLES['SKAB']]

plot_data_comparison(clean=clean[0:VARIABLES['SIZE']], 
                    anomaly=fault[0:VARIABLES['SIZE']], 
                    plot_labels=["Clean Data", "Fault Data"],
                    dataset="SKAB")


clean = data['RMFD']['clean']['H1.mat'].values
fault = data['RMFD']['fault']['F1.mat'].values

clean = clean[:, VARIABLES['RMFD']]
fault = fault[:, VARIABLES['RMFD']]

plot_data_comparison(clean=clean[0:VARIABLES['SIZE']], 
                    anomaly=fault[0:VARIABLES['SIZE']], 
                    plot_labels=["Clean Data", "Fault Data"],
                    dataset="RMFD")

# clean = data['VSD']['clean']['datanormal10km']['vdata1B1.txt'].values
# clean = clean[1:, VARIABLES['VSD']].astype(float)

# fault = data['VSD']['fault']['dataAG10km']['vdata1B1.txt'].values
# fault = fault[1:, VARIABLES['VSD']].astype(float)

# plot_data_comparison(clean=clean[0:VARIABLES['SIZE']], 
#                     anomaly=fault[0:VARIABLES['SIZE']],  
#                     plot_labels=["Clean Data", "Fault Data"],
#                     dataset="VSD")

# %%
# Test [TPR, FPR, DD] CUSUMs on Raw Signals

"""
Test all CUSUMs on Raw signls
- Set the parameters in the cusums_parameters dictionary
- Set the parameters in the datasets_parameters dictionary
- Feel free to add remove datasets, CUSUMs and parameters
"""

# Run all CUSUMs on the selected dataset and variable
# Set to True to ONLY do only PLOTTING
ONLY_PLOTS = False  

START = TRAINING_SIZE

# Run on Raw Signals
datasets = ["TEP", "LBNL", "SKAB", "RMFD"]

for dataset_name in datasets:
    cusum_detection_results, dataset = run_all_cusums2(
        data, 
        dataset=dataset_name, 
        datasets_parameters=datasets_parameters[dataset_name],
        plots=ONLY_PLOTS,
        cusums_parameters=cusums_parameters,
        classic_threshold=False,
        start=START
    )

    compute_results(cusum_detection_results, dataset)

    del cusum_detection_results
    gc.collect()
# Out:
# Results for high_order CUSUM on SKAB dataset:
# Number of detections on clean data: 1523
# FPR: 0.7615
# TPR: 0.4170571841403241, DD: 95.88888888888889
#
# Results for classical CUSUM on SKAB dataset:
# Number of detections on clean data: 1322
# FPR: 0.661
# TPR: 0.8354637462000891, DD: 24.575757575757574
#
# Results for one_cusum_scheme CUSUM on SKAB dataset:
# Number of detections on clean data: 1502
# FPR: 0.751
# TPR: 0.37027655568294693, DD: 125.33333333333333
#
# Results for hampel CUSUM on SKAB dataset:
# Number of detections on clean data: 1502
# FPR: 0.751
# TPR: 0.38888286178806736, DD: 192.0
#
# Results for UCUSUM CUSUM on SKAB dataset:
# Number of detections on clean data: 60
# FPR: 0.03
# TPR: 0.038519322801016914, DD: 226.47368421052633
#
# Results for variance_cusum CUSUM on SKAB dataset:
# Number of detections on clean data: 1501
# FPR: 0.7505
# TPR: 0.3675164447039946, DD: 114.52941176470588
#
# Results for high_order CUSUM on RMFD dataset:
# Number of detections on clean data: 11
# FPR: 0.0055
# TPR: 0.00025982905982905983, DD: 477.5
#
# Results for classical CUSUM on RMFD dataset:
# Number of detections on clean data: 21
# FPR: 0.0105
# TPR: 0.005589743589743589, DD: 128.0
#
# Results for one_cusum_scheme CUSUM on RMFD dataset:
# Number of detections on clean data: 20
# FPR: 0.01
# TPR: 0.2483760683760684, DD: 1223.7252747252746
#
# Results for hampel CUSUM on RMFD dataset:
# Number of detections on clean data: 1
# FPR: 0.0005
# TPR: 0.0, DD: nan
#
# Results for UCUSUM CUSUM on RMFD dataset:
# Number of detections on clean data: 15
# FPR: 0.0075
# TPR: 0.0012444444444444443, DD: 960.4098360655738
#
# Results for variance_cusum CUSUM on RMFD dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.0, DD: nan
# /home/roland/cusum_exp/venv/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/roland/cusum_exp/venv/lib/python3.10/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 0

# %%
# Test [TPR, FPR, DD] CUSUMs on Model Prediction Residuals

"""
Test all CUSUMs on Model Prediction Residuals
- Set the parameters in the cusums_parameters dictionary
- Set the parameters in the datasets_parameters dictionary
- Feel free to add remove datasets, CUSUMs and parameters
"""
ONLY_PLOTS = False  

#Run on Model Residuals
datasets = ["TEP", "LBNL", "SKAB", "RMFD"]

for dataset_name in datasets:
    
    model = create_model(
        models_parameters,
        number_inputs=len(datasets_parameters[dataset_name]['inputs']),
        number_outputs=len(datasets_parameters[dataset_name]['outputs'])
    )

    cusum_detection_results, dataset = run_all_cusums2(
        data, 
        dataset=dataset_name, 
        datasets_parameters=datasets_parameters[dataset_name],
        plots=ONLY_PLOTS,
        run_on_residuals=True,
        model=model,
        models_parameters=models_parameters,
        cusums_parameters=cusums_parameters,
        classic_threshold=False,
        start=START
    )

    compute_results(cusum_detection_results, dataset, mode='standard')

    del cusum_detection_results, model
    gc.collect()
# Out:
# Results for high_order CUSUM on TEP dataset:
# Number of detections on clean data: 201
# FPR: 0.25769230769230766
# TPR: 0.24740625, DD: 227.6
#
# Results for classical CUSUM on TEP dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.51603125, DD: 202.06666666666666
#
# Results for one_cusum_scheme CUSUM on TEP dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.51253125, DD: 208.86666666666667
#
# Results for hampel CUSUM on TEP dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.64775, DD: 65.47058823529412
#
# Results for UCUSUM CUSUM on TEP dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.40981249999999997, DD: 136.1875
#
# Results for variance_cusum CUSUM on TEP dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.3973125, DD: 58.916666666666664
#
# Results for high_order CUSUM on LBNL dataset:
# Number of detections on clean data: 678
# FPR: 0.8692307692307693
# TPR: 0.8958658854166667, DD: 36.8125
#
# Results for classical CUSUM on LBNL dataset:
# Number of detections on clean data: 325
# FPR: 0.4166666666666667
# TPR: 0.99482421875, DD: 1.375
#
# Results for one_cusum_scheme CUSUM on LBNL dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.536328125, DD: 1.0625
#
# Results for hampel CUSUM on LBNL dataset:
# Number of detections on clean data: 125
# FPR: 0.16025641025641027
# TPR: 0.9994466145833334, DD: 1.0625
#
# Results for UCUSUM CUSUM on LBNL dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.19013671875, DD: 30.0
#
# Results for variance_cusum CUSUM on LBNL dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.021842447916666667, DD: 20.0
#
# Results for high_order CUSUM on SKAB dataset:
# Number of detections on clean data: 45
# FPR: 0.057692307692307696
# TPR: 0.15122605662473934, DD: 79.0
#
# Results for classical CUSUM on SKAB dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.35665092101084955, DD: 40.1578947368421
#
# Results for one_cusum_scheme CUSUM on SKAB dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.2685094791680499, DD: 45.0625
#
# Results for hampel CUSUM on SKAB dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.5124470078136684, DD: 35.5
#
# Results for UCUSUM CUSUM on SKAB dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.33308459022146497, DD: 41.26315789473684
#
# Results for variance_cusum CUSUM on SKAB dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.012495430625369166, DD: 27.0
#
# Results for high_order CUSUM on RMFD dataset:
# Number of detections on clean data: 330
# FPR: 0.4230769230769231
# TPR: 0.07859241452991453, DD: 237.30555555555554
#
# Results for classical CUSUM on RMFD dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.029211182336182338, DD: 427.1142857142857
#
# Results for one_cusum_scheme CUSUM on RMFD dataset:
# Number of detections on clean data: 1
# FPR: 0.001282051282051282
# TPR: 0.01169426638176638, DD: 457.0
#
# Results for hampel CUSUM on RMFD dataset:
# Number of detections on clean data: 144
# FPR: 0.18461538461538463
# TPR: 0.7663550569800569, DD: 448.54700854700855
#
# Results for UCUSUM CUSUM on RMFD dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.01891025641025641, DD: 565.3571428571429
#
# Results for variance_cusum CUSUM on RMFD dataset:
# Number of detections on clean data: 0
# FPR: 0.0
# TPR: 0.0, DD: nan
# /home/roland/cusum_exp/venv/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/roland/cusum_exp/venv/lib/python3.10/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 3653

# %% [markdown]
# #### **Robustness Experiment Execution**

# %%
# Test [Robustness] CUSUMS on Raw Signals With Noise and Outliers Injected

"""
Test all CUSUMs on Raw signls
- Set the parameters in the cusums_parameters dictionary
- Set the parameters in the datasets_parameters dictionary
- Feel free to add remove datasets, CUSUMs and parameters
- Add Noise and Outliers.
"""

OUTLIERS_MIN = 1.5
OUTLIERS_MAX = 2
datasets_list = ["TEP", "LBNL", "SKAB", "RMFD"]

results_dataset_noise_raw = {k: [] for k in datasets_list}
results_dataset_outliers_raw = {k: [] for k in datasets_list}

def run_and_store(dataset_name, noise, outliers, results_dict, mode="robust", tag="Noise"):
    cusum_detection_results = run_cusums_on_clean_with_noise(
        data,
        dataset=dataset_name,
        datasets_parameters=datasets_parameters[dataset_name],
        cusums_parameters=cusums_parameters,
        classic_threshold=False,
        noise=noise,
        outliers=outliers,
        START=START
    )

    FAR_N, SI = compute_results(cusum_detection_results, dataset_name, mode=mode)
    results_dict[dataset_name].append(f"{tag}: {noise if tag=='Noise' else outliers}, FAR_N: {FAR_N}, SI: {SI}")
    
    del cusum_detection_results
    gc.collect()


# --- Noise Experiments ---
OUTLIERS = [0, 0, 0]  

for noise_type in [0, 1]:
    for noise_level in np.arange(0, 3, 0.5):
        if noise_type == 1 and noise_level == 0:
            continue  

        NOISE = [noise_type, 0, noise_level] if noise_type == 0 else [noise_type, noise_level, 3]

        for dataset_name in datasets_list:
            run_and_store(dataset_name, NOISE, OUTLIERS, results_dataset_noise_raw, tag="Noise")


# --- Outliers Experiments ---
NOISE = [0, 0, 0]  

for outliers_percentage in np.arange(0, 1.1, 0.1):
    OUTLIERS = [outliers_percentage, OUTLIERS_MIN, OUTLIERS_MAX]

    for dataset_name in datasets_list:
        run_and_store(dataset_name, NOISE, OUTLIERS, results_dataset_outliers_raw, tag="Outliers")
# Out:
# Results for high_order CUSUM on TEP dataset:
# FAR_N: 0.428, SI: 0.0115
# Results for classical CUSUM on TEP dataset:
# FAR_N: 0.729, SI: 0.017
# Results for one_cusum_scheme CUSUM on TEP dataset:
# FAR_N: 0.542, SI: 0.007
# Results for hampel CUSUM on TEP dataset:
# FAR_N: 0.002, SI: 0.004
# Results for UCUSUM CUSUM on TEP dataset:
# FAR_N: 0.145, SI: 0.024
# Results for variance_cusum CUSUM on TEP dataset:
# FAR_N: 0.418, SI: 0.0055
# Results for high_order CUSUM on LBNL dataset:
# FAR_N: 0.297, SI: 0.007
# Results for classical CUSUM on LBNL dataset:
# FAR_N: 0.9965, SI: 0.001
# Results for one_cusum_scheme CUSUM on LBNL dataset:
# FAR_N: 0.9585, SI: 0.001
# Results for hampel CUSUM on LBNL dataset:
# FAR_N: 0.7465, SI: 0.001
# Results for UCUSUM CUSUM on LBNL dataset:
# FAR_N: 0.899, SI: 0.007
# Results for variance_cusum CUSUM on LBNL dataset:
# FAR_N: 0.99, SI: 0.001
# Results for high_order CUSUM on SKAB dataset:
# FAR_N: 0.8465, SI: 0.001
# Results for classical CUSUM on SKAB dataset:
# FAR_N: 0.9995, SI: 0.0005
# Results for one_cusum_scheme CUSUM on SKAB dataset:
# FAR_N: 0.9995, SI: 0.0005
# Results for hampel CUSUM on SKAB dataset:
# FAR_N: 0.8995, SI: 0.001
# Results for UCUSUM CUSUM on SKAB dataset:
# FAR_N: 0.955, SI: 0.005
# Results for variance_cusum CUSUM on SKAB dataset:
# FAR_N: 0.99, SI: 0.001
# Results for high_order CUSUM on RMFD dataset:
# FAR_N: 0.0, SI: 0.0
# Results for classical CUSUM on RMFD dataset:
# FAR_N: 0.8725, SI: 0.0455
# Results for one_cusum_scheme CUSUM on RMFD dataset:
# FAR_N: 0.9775, SI: 0.001
# Results for hampel CUSUM on RMFD dataset:
# FAR_N: 0.9805, SI: 0.001
# Results for UCUSUM CUSUM on RMFD dataset:
# FAR_N: 0.967, SI: 0.025
# Results for variance_cusum CUSUM on RMFD dataset:
# FAR_N: 0.0, SI: 0.0
# 0

# %%
# Test [Robustness] CUSUMS on Prediction Residuals With Noise and Outliers Injected

"""
Test all CUSUMs on Residuals
- Set the parameters in the cusums_parameters dictionary
- Set the parameters in the datasets_parameters dictionary
- Feel free to add remove datasets, CUSUMs and parameters
- Add Noise and Outliers.
"""

# NOISE: [Val1, Val2, Val3]
# First value: Type [0 - Gaussian Noise, 1 - Uniform Noise]
# Second value: Minimum or Mean
# Third value: Maximum or STD

# OUTLIERS: [Val1, Val2, Val3]
# First value: Percentage of outliers
# Second value: Minimum percentage of the max value from data
# Third value: Maximum percentage of the max value from data

def evaluate_on_datasets(results_dict, datasets, noise, outliers, mode_label):
    for dataset_name in datasets:

        model = create_model(models_parameters, 
                             number_inputs=len(datasets_parameters[dataset_name]['inputs']),
                             number_outputs=len(datasets_parameters[dataset_name]['outputs']))

        cusum_results = run_cusums_on_clean_with_noise(
            data=data,
            dataset=dataset_name,
            datasets_parameters=datasets_parameters[dataset_name],
            cusums_parameters=cusums_parameters,
            classic_threshold=False,
            run_on_residuals=True,
            model=model,
            models_parameters=models_parameters,
            noise=noise,
            outliers=outliers,
            START=START
        )

        FAR_N, SI = compute_results(cusum_results, dataset_name, mode="robust")

        results_dict[dataset_name].append(
            f"{mode_label}: {noise if 'Noise' in mode_label else outliers}, FAR_N: {FAR_N}, SI: {SI}"
        )

        del cusum_results, model, FAR_N, SI
        gc.collect()

# Datasets to run
datasets = ["TEP", "LBNL", "SKAB", "RMFD"]


# Noise Experiments
results_dataset_noise_residuals = {name: [] for name in datasets}

OUTLIERS = [0, 0, 0]  # No outliers during noise experiments

for noise_type in [0, 1]:
    for noise_level in np.arange(0, 3, 0.5):
        if noise_type == 0:
            NOISE = [0, 0, noise_level]
        elif noise_type == 1:
            if noise_level == 0:
                continue
            NOISE = [1, noise_level, 3]
        
        evaluate_on_datasets(results_dataset_noise_residuals, datasets, noise=NOISE, outliers=OUTLIERS, mode_label="Noise")


# Outliers Experiments
results_dataset_outliers_residuals = {name: [] for name in datasets}

NOISE = [0, 0, 0]  # No noise during outlier experiments
OUTLIERS_MIN = 1.5
OUTLIERS_MAX = 2

for outliers_percentage in np.arange(0, 1.1, 0.1):
    OUTLIERS = [outliers_percentage, OUTLIERS_MIN, OUTLIERS_MAX]
    evaluate_on_datasets(results_dataset_outliers_residuals, datasets, noise=NOISE, outliers=OUTLIERS, mode_label="Outliers")
# Out:
# Results for high_order CUSUM on TEP dataset:
# FAR_N: 0.25769230769230766, SI: 0.015384615384615385
# Results for classical CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for one_cusum_scheme CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for hampel CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for UCUSUM CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7fa2dd292650>>
# Traceback (most recent call last):
#   File "/home/roland/cusum_exp/venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# Results for high_order CUSUM on LBNL dataset:
# FAR_N: 0.8692307692307693, SI: 0.002564102564102564
# Results for classical CUSUM on LBNL dataset:
# FAR_N: 0.4166666666666667, SI: 0.010256410256410256
# Results for one_cusum_scheme CUSUM on LBNL dataset:
# FAR_N: 0.0, SI: 0.0
# Results for hampel CUSUM on LBNL dataset:
# FAR_N: 0.16025641025641027, SI: 0.002564102564102564
# Results for UCUSUM CUSUM on LBNL dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on LBNL dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on SKAB dataset:
# FAR_N: 0.057692307692307696, SI: 0.005128205128205128
# Results for classical CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for one_cusum_scheme CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for hampel CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for UCUSUM CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on RMFD dataset:
# FAR_N: 0.4230769230769231, SI: 0.017948717948717947
# Results for classical CUSUM on RMFD dataset:
# FAR_N: 0.0, SI: 0.0
# Results for one_cusum_scheme CUSUM on RMFD dataset:
# FAR_N: 0.001282051282051282, SI: 0.0038461538461538464
# Results for hampel CUSUM on RMFD dataset:
# FAR_N: 0.18461538461538463, SI: 0.00641025641025641
# Results for UCUSUM CUSUM on RMFD dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on RMFD dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on TEP dataset:
# FAR_N: 0.04487179487179487, SI: 0.005128205128205128
# Results for classical CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for one_cusum_scheme CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for hampel CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for UCUSUM CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on LBNL dataset:
# FAR_N: 0.021794871794871794, SI: 0.005128205128205128
# Results for classical CUSUM on LBNL dataset:
# FAR_N: 0.40897435897435896, SI: 0.010256410256410256
# Results for one_cusum_scheme CUSUM on LBNL dataset:
# FAR_N: 0.0, SI: 0.0
# Results for hampel CUSUM on LBNL dataset:
# FAR_N: 0.1576923076923077, SI: 0.002564102564102564
# Results for UCUSUM CUSUM on LBNL dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on LBNL dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for classical CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for one_cusum_scheme CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for hampel CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for UCUSUM CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on RMFD dataset:
# FAR_N: 0.017948717948717947, SI: 0.005128205128205128
# Results for classical CUSUM on RMFD dataset:
# FAR_N: 0.002564102564102564, SI: 0.007692307692307693
# Results for one_cusum_scheme CUSUM on RMFD dataset:
# FAR_N: 0.002564102564102564, SI: 0.007692307692307693
# Results for hampel CUSUM on RMFD dataset:
# FAR_N: 0.25769230769230766, SI: 0.00641025641025641
# Results for UCUSUM CUSUM on RMFD dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on RMFD dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for classical CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for one_cusum_scheme CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for hampel CUSUM on TEP dataset:
# FAR_N: 0.10128205128205128, SI: 0.005128205128205128
# Results for UCUSUM CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7fa2dd292650>>
# Traceback (most recent call last):
#   File "/home/roland/cusum_exp/venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# Results for high_order CUSUM on LBNL dataset:
# FAR_N: 0.019230769230769232, SI: 0.005128205128205128
# Results for classical CUSUM on LBNL dataset:
# FAR_N: 0.441025641025641, SI: 0.029487179487179487
# Results for one_cusum_scheme CUSUM on LBNL dataset:
# FAR_N: 0.0, SI: 0.0
# Results for hampel CUSUM on LBNL dataset:
# FAR_N: 0.31025641025641026, SI: 0.002564102564102564
# Results for UCUSUM CUSUM on LBNL dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on LBNL dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for classical CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for one_cusum_scheme CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for hampel CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for UCUSUM CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on RMFD dataset:
# FAR_N: 0.0, SI: 0.0
# Results for classical CUSUM on RMFD dataset:
# FAR_N: 0.16025641025641027, SI: 0.20256410256410257
# Results for one_cusum_scheme CUSUM on RMFD dataset:
# FAR_N: 0.03205128205128205, SI: 0.052564102564102565
# Results for hampel CUSUM on RMFD dataset:
# FAR_N: 0.5076923076923077, SI: 0.010256410256410256
# Results for UCUSUM CUSUM on RMFD dataset:
# FAR_N: 0.00641025641025641, SI: 0.005128205128205128
# Results for variance_cusum CUSUM on RMFD dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on TEP dataset:
# FAR_N: 0.25769230769230766, SI: 0.015384615384615385
# Results for classical CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for one_cusum_scheme CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for hampel CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for UCUSUM CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on LBNL dataset:
# FAR_N: 0.8692307692307693, SI: 0.002564102564102564
# Results for classical CUSUM on LBNL dataset:
# FAR_N: 0.4166666666666667, SI: 0.010256410256410256
# Results for one_cusum_scheme CUSUM on LBNL dataset:
# FAR_N: 0.0, SI: 0.0
# Results for hampel CUSUM on LBNL dataset:
# FAR_N: 0.16025641025641027, SI: 0.002564102564102564
# Results for UCUSUM CUSUM on LBNL dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on LBNL dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on SKAB dataset:
# FAR_N: 0.057692307692307696, SI: 0.005128205128205128
# Results for classical CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for one_cusum_scheme CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for hampel CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for UCUSUM CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on RMFD dataset:
# FAR_N: 0.4230769230769231, SI: 0.017948717948717947
# Results for classical CUSUM on RMFD dataset:
# FAR_N: 0.0, SI: 0.0
# Results for one_cusum_scheme CUSUM on RMFD dataset:
# FAR_N: 0.001282051282051282, SI: 0.0038461538461538464
# Results for hampel CUSUM on RMFD dataset:
# FAR_N: 0.18461538461538463, SI: 0.00641025641025641
# Results for UCUSUM CUSUM on RMFD dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on RMFD dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on TEP dataset:
# FAR_N: 0.16153846153846155, SI: 0.010256410256410256
# Results for classical CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for one_cusum_scheme CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for hampel CUSUM on TEP dataset:
# FAR_N: 0.21794871794871795, SI: 0.005128205128205128
# Results for UCUSUM CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on TEP dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on LBNL dataset:
# FAR_N: 0.07948717948717948, SI: 0.005128205128205128
# Results for classical CUSUM on LBNL dataset:
# FAR_N: 0.3423076923076923, SI: 0.002564102564102564
# Results for one_cusum_scheme CUSUM on LBNL dataset:
# FAR_N: 0.2717948717948718, SI: 0.002564102564102564
# Results for hampel CUSUM on LBNL dataset:
# FAR_N: 0.308974358974359, SI: 0.002564102564102564
# Results for UCUSUM CUSUM on LBNL dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on LBNL dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for classical CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for one_cusum_scheme CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for hampel CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for UCUSUM CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for variance_cusum CUSUM on SKAB dataset:
# FAR_N: 0.0, SI: 0.0
# Results for high_order CUSUM on RMFD dataset:
# FAR_N: 0.34102564102564104, SI: 0.017948717948717947
# Results for classical CUSUM on RMFD dataset:
# FAR_N: 0.11282051282051282, SI: 0.047435897435897434
# Results for one_cusum_scheme CUSUM on RMFD dataset:
# FAR_N: 0.005128205128205128, SI: 0.01282051282051282
# Results for hampel CUSUM on RMFD dataset:
# FAR_N: 0.5923076923076923, SI: 0.00641025641025641
# Results for UCUSUM CUSUM on RMFD dataset:
# FAR_N: 0.1564102564102564, SI: 0.057692307692307696
# Results for variance_cusum CUSUM on RMFD dataset:
# FAR_N: 0.0, SI: 0.0

# %% [markdown]
# #### **Resilience Experiment Execution**

# %%
# Test [Resilience] CUSUMS on Raw Signals

"""
Test all CUSUMs on Raw signls
The input data consists of fault data concatenated with clean data
The reasoning is to test the resilience of the CUSUMs (e.g., recovery rates and stability)
For the simulation based datasets:
    - After each fault simulation the dataset is repeated RESILIENCE_CLEAN_DATA_MULTIPLIER times
    - for each fault type.
    - sim length variable is initially set in the datasets_parameters
    - sim length is extended with the number of repetitions of the clean data
    
- Set the parameters in the cusums_parameters dictionary
- Set the parameters in the datasets_parameters dictionary
- Feel free to add remove datasets, CUSUMs and parameters
"""

# Run on Raw Signals
def evaluate_resilience_on_datasets(datasets):

    for dataset_name in datasets:
        
        cusum_results = run_cusums_for_resilience(
            data=data,
            dataset=dataset_name,
            datasets_parameters=datasets_parameters[dataset_name],
            cusums_parameters=cusums_parameters,
            classic_threshold=False,
            start=START
        )

        # Only TEP requires sim_length passed explicitly
        if dataset_name == "TEP":
            sim_length = datasets_parameters["TEP"]["sim_length"] + \
                         datasets_parameters["TEP"]["clean_sim_length"] * \
                         datasets_parameters["TEP"]["RESILIENCE_CLEAN_DATA_MULTIPLIER"]

            compute_results(
                cusum_results, dataset_name,
                mode="resilience",
                simulation=True,
                sim_length=sim_length
            )
        else:
            compute_results(cusum_results, dataset_name, mode="resilience")

        del cusum_results
        gc.collect()

# Run on all datasets
datasets = ["TEP", "LBNL", "SKAB", "RMFD"]
evaluate_resilience_on_datasets(datasets=datasets)
# Out:
# Results for high_order CUSUM on TEP dataset:
# Recovery Time: 2.5, Stability Time: 3.7
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for classical CUSUM on TEP dataset:
# Recovery Time: 192.23529411764707, Stability Time: 192.23529411764707
# Unrecovered Recovery Times: 3, Unrecovered Stability Times: 3
#
# Results for one_cusum_scheme CUSUM on TEP dataset:
# Recovery Time: nan, Stability Time: nan
# Unrecovered Recovery Times: 20, Unrecovered Stability Times: 20
#
# Results for hampel CUSUM on TEP dataset:
# Recovery Time: nan, Stability Time: nan
# Unrecovered Recovery Times: 20, Unrecovered Stability Times: 20
#
# Results for UCUSUM CUSUM on TEP dataset:
# Recovery Time: 4.55, Stability Time: 4.55
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for variance_cusum CUSUM on TEP dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 11, Unrecovered Stability Times: 11
# /home/roland/cusum_exp/venv/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/roland/cusum_exp/venv/lib/python3.10/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Results for high_order CUSUM on LBNL dataset:
# Recovery Time: 973.2666666666667, Stability Time: 1046.4
# Unrecovered Recovery Times: 1, Unrecovered Stability Times: 1
#
# Results for classical CUSUM on LBNL dataset:
# Recovery Time: nan, Stability Time: nan
# Unrecovered Recovery Times: 16, Unrecovered Stability Times: 16
#
# Results for one_cusum_scheme CUSUM on LBNL dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 2, Unrecovered Stability Times: 2
#
# Results for hampel CUSUM on LBNL dataset:
# Recovery Time: nan, Stability Time: nan
# Unrecovered Recovery Times: 16, Unrecovered Stability Times: 16
#
# Results for UCUSUM CUSUM on LBNL dataset:
# Recovery Time: 2.6875, Stability Time: 2.6875
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for variance_cusum CUSUM on LBNL dataset:
# Recovery Time: 1.0, Stability Time: 370.875
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for high_order CUSUM on SKAB dataset:
# Recovery Time: 146.5, Stability Time: 125.68
# Unrecovered Recovery Times: 8, Unrecovered Stability Times: 9
#
# Results for classical CUSUM on SKAB dataset:
# Recovery Time: 689.5, Stability Time: 588.8888888888889
# Unrecovered Recovery Times: 24, Unrecovered Stability Times: 25
#
# Results for one_cusum_scheme CUSUM on SKAB dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 16, Unrecovered Stability Times: 16
#
# Results for hampel CUSUM on SKAB dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 18, Unrecovered Stability Times: 18
#
# Results for UCUSUM CUSUM on SKAB dataset:
# Recovery Time: 1.7941176470588236, Stability Time: 1.7941176470588236
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for variance_cusum CUSUM on SKAB dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 16, Unrecovered Stability Times: 16
#
# Results for high_order CUSUM on RMFD dataset:
# Recovery Time: 1.0, Stability Time: 1.3076923076923077
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for classical CUSUM on RMFD dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for one_cusum_scheme CUSUM on RMFD dataset:
# Recovery Time: 179.5607476635514, Stability Time: 205.34579439252337
# Unrecovered Recovery Times: 10, Unrecovered Stability Times: 10
#
# Results for hampel CUSUM on RMFD dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for UCUSUM CUSUM on RMFD dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for variance_cusum CUSUM on RMFD dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
# 0

# %%
# Test [Resilience] CUSUMS on Prediction Residuals

"""
Test all CUSUMs on Residuals
- Set the parameters in the cusums_parameters dictionary
- Set the parameters in the datasets_parameters dictionary
- Feel free to add remove datasets, CUSUMs and parameters
"""

datasets = ['TEP', 'LBNL', 'SKAB', 'RMFD']

for dataset_name in datasets:

    params = datasets_parameters[dataset_name]
    
    model = create_model(models_parameters, 
                         number_inputs=len(params['inputs']),
                         number_outputs=len(params['outputs']))
    
    cusum_detection_results = run_cusums_for_resilience(data,
                                                       dataset=dataset_name,
                                                       datasets_parameters=params,
                                                       cusums_parameters=cusums_parameters,
                                                       models_parameters=models_parameters,
                                                       model=model,
                                                       classic_threshold=False,
                                                       run_on_residuals=True,
                                                       start=START)
    
    if dataset_name == 'TEP':

        sim_length = params['sim_length'] + params['clean_sim_length'] * params['RESILIENCE_CLEAN_DATA_MULTIPLIER']
        
        compute_results(cusum_detection_results, dataset_name, mode="resilience", simulation=True, sim_length=sim_length)
    
    else:

        compute_results(cusum_detection_results, dataset_name, mode="resilience")
    
    del cusum_detection_results, model
    gc.collect()
# Out:
# Results for high_order CUSUM on TEP dataset:
# Recovery Time: 47.0, Stability Time: 47.0
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for classical CUSUM on TEP dataset:
# Recovery Time: 92.8, Stability Time: 92.8
# Unrecovered Recovery Times: 10, Unrecovered Stability Times: 10
#
# Results for one_cusum_scheme CUSUM on TEP dataset:
# Recovery Time: 41.5, Stability Time: 41.5
# Unrecovered Recovery Times: 10, Unrecovered Stability Times: 10
#
# Results for hampel CUSUM on TEP dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 17, Unrecovered Stability Times: 17
#
# Results for UCUSUM CUSUM on TEP dataset:
# Recovery Time: 9.95, Stability Time: 9.95
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for variance_cusum CUSUM on TEP dataset:
# Recovery Time: nan, Stability Time: nan
# Unrecovered Recovery Times: 20, Unrecovered Stability Times: 20
#
# Results for high_order CUSUM on LBNL dataset:
# Recovery Time: nan, Stability Time: nan
# Unrecovered Recovery Times: 16, Unrecovered Stability Times: 16
#
# Results for classical CUSUM on LBNL dataset:
# Recovery Time: 69.0, Stability Time: 75.0
# Unrecovered Recovery Times: 12, Unrecovered Stability Times: 12
#
# Results for one_cusum_scheme CUSUM on LBNL dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 4, Unrecovered Stability Times: 4
#
# Results for hampel CUSUM on LBNL dataset:
# Recovery Time: nan, Stability Time: nan
# Unrecovered Recovery Times: 16, Unrecovered Stability Times: 16
#
# Results for UCUSUM CUSUM on LBNL dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for variance_cusum CUSUM on LBNL dataset:
# Recovery Time: nan, Stability Time: nan
# Unrecovered Recovery Times: 16, Unrecovered Stability Times: 16
#
# Results for high_order CUSUM on SKAB dataset:
# Recovery Time: 3.3823529411764706, Stability Time: 3.3823529411764706
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for classical CUSUM on SKAB dataset:
# Recovery Time: 35.34375, Stability Time: 35.34375
# Unrecovered Recovery Times: 2, Unrecovered Stability Times: 2
#
# Results for one_cusum_scheme CUSUM on SKAB dataset:
# Recovery Time: 5.5588235294117645, Stability Time: 5.5588235294117645
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for hampel CUSUM on SKAB dataset:
# Recovery Time: 63.13636363636363, Stability Time: 63.13636363636363
# Unrecovered Recovery Times: 12, Unrecovered Stability Times: 12
#
# Results for UCUSUM CUSUM on SKAB dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for variance_cusum CUSUM on SKAB dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for high_order CUSUM on RMFD dataset:
# Recovery Time: 82.0, Stability Time: 82.0
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for classical CUSUM on RMFD dataset:
# Recovery Time: 1.3675213675213675, Stability Time: 1.4017094017094016
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for one_cusum_scheme CUSUM on RMFD dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for hampel CUSUM on RMFD dataset:
# Recovery Time: nan, Stability Time: nan
# Unrecovered Recovery Times: 117, Unrecovered Stability Times: 117
#
# Results for UCUSUM CUSUM on RMFD dataset:
# Recovery Time: 1.0, Stability Time: 1.0
# Unrecovered Recovery Times: 0, Unrecovered Stability Times: 0
#
# Results for variance_cusum CUSUM on RMFD dataset:
# Recovery Time: nan, Stability Time: nan
# Unrecovered Recovery Times: 117, Unrecovered Stability Times: 117
# 0

# %% [markdown]
# #### **Resources Experiment Execution**

# %%
# Test [Resources] CUSUMs Running Times

# Run all CUSUMs on the selected dataset and variable
# Measure for both raw and residuals

print("Start CUSUMs Running Time Measurement")

results_raw, results_residual, results_model = {}, {}, {}

ds = 'TEP'

model = create_model(models_parameters, 
                        number_inputs = len(datasets_parameters[ds]['inputs']),
                        number_outputs = len(datasets_parameters[ds]['outputs']))

param_size = PARAM_ESTIMATION_SIZE
ml = datasets_parameters[ds]['max_length']

PARAM_ESTIMATION_SIZE = 1000
datasets_parameters[ds]['param_estimation_size'] = PARAM_ESTIMATION_SIZE

cusum_list = ['high_order', 'classical', 'one_cusum_scheme',
             'hampel_acusum', 'UCUSUM', 'variance_cusum']

model_measure_list = ['train', 'test']

# Test different max_lengths from 1000 to 100000
MAX_LENGTHS = np.arange(1000, 500_001, 10_000).tolist()

# MAX_LENGTHS = [1000, 2000, 5000, 10000, 50000, 100000]

for max_length in MAX_LENGTHS:
    print("Testing dataset: {}, max_length: {}".format(ds, max_length))

    max_length = max_length + PARAM_ESTIMATION_SIZE
    datasets_parameters[ds]['max_length'] = max_length
    
    START = int(max_length * models_parameters['train_ratio'])

    # Run on Raw Signals
    time_results_raw = run_all_cusums_time_meas(data, 
                                        dataset=ds, 
                                        datasets_parameters=datasets_parameters[ds],
                                        cusums_parameters=cusums_parameters,
                                        classic_threshold=False,
                                        start=START,
                                        measure_time=True)  
    
    results_raw[max_length - PARAM_ESTIMATION_SIZE] = time_results_raw
 
    time_results_residual, time_results_model = run_all_cusums_time_meas(data, 
                                            dataset=ds, 
                                            datasets_parameters=datasets_parameters[ds],
                                            run_on_residuals=True,
                                            model=model,
                                            models_parameters=models_parameters,
                                            cusums_parameters=cusums_parameters,
                                            classic_threshold=False,
                                            start=START,
                                            measure_time=True)  
    
    results_residual[max_length - PARAM_ESTIMATION_SIZE] = time_results_residual
    results_model[max_length - PARAM_ESTIMATION_SIZE] = time_results_model

    # Clean up
    del time_results_raw, time_results_residual, time_results_model
    gc.collect()
    
# Restore values
PARAM_ESTIMATION_SIZE = param_size
datasets_parameters[ds]['max_length'] = ml

# Compute averages for each CUSUM for each max_length

results_raw_f = {
  'high_order': [],
   'classical': [],
   'one_cusum_scheme': [],
   'hampel_acusum': [],
   'UCUSUM': [],
   'variance_cusum': []
}

results_residual_f = {
  'high_order': [],
   'classical': [],
   'one_cusum_scheme': [],
   'hampel_acusum': [],
   'UCUSUM': [],
   'variance_cusum': []
}

results_model_f = {
  'train': [],
  'test': [],
}

for max_len, results in results_raw.items():
  for cusum in cusum_list:
      results_raw_f[cusum].append(results[0][cusum])

for max_len, results in results_residual.items():
      for cusum in cusum_list:
        results_residual_f[cusum].append(results[cusum])

for max_len, results in results_model.items():
      for measure in model_measure_list:
        results_model_f[measure].append(np.mean(results[measure]))

# Plot the results

font_main = 16
font_title = 18
font_legend = 14
linewidth = 3

plt.rcParams.update({
    # Font sizes
    'font.size': font_main,
    'axes.labelsize': font_main,
    'xtick.labelsize': font_main,
    'ytick.labelsize': font_main,
    'legend.fontsize': font_legend,
    'axes.titlesize': font_title,
    'figure.titlesize': font_main,
    
    # Axis & grid styling
    'axes.grid': True,
    'axes.grid.which': 'major',
    'axes.linewidth': 0.8, 

    # Line widths
    'lines.linewidth': linewidth
})


# Plot CUSUMs CPU Usage
plt.figure(figsize=(12, 8))
plt.title("Running Time for CUSUMs on Raw Signals")
plt.xlabel("Max Length")
plt.ylabel("Running Time (seconds)")
plt.grid(True)

for cusum in cusum_list:
    plt.plot(MAX_LENGTHS, results_raw_f[cusum], label="Raw - {}".format(cusum))
plt.yscale('log')
plt.legend()
plt.savefig(program_parameters["plot_path"] + "raw_time.pdf", format='pdf')
# plt.show()


# Plot CUSUMs CPU Usage on Residuals
plt.figure(figsize=(12, 8))
plt.title("Running Time for CUSUMs on Residuals")
plt.xlabel("Max Length")
plt.ylabel("Running Time (seconds)")
for cusum in cusum_list:
    plt.plot(MAX_LENGTHS, results_residual_f[cusum], label="Residuals - {}".format(cusum))
plt.yscale('log')
plt.legend()
plt.savefig(program_parameters["plot_path"] + "residual_time.pdf", format='pdf')
# plt.show()

# Plot Model CPU Usage
plt.figure(figsize=(12, 8))
plt.title("Model Training and Testing Time")
plt.xlabel("Max Length")
plt.ylabel("Running Time (seconds)")
for meas in model_measure_list:
    plt.plot(MAX_LENGTHS, results_model_f[meas], label="Model - {}".format(meas))
plt.yscale('log')
plt.legend()
plt.savefig(program_parameters["plot_path"] + "model_time.pdf", format='pdf')
# plt.show()
# Out:
# Start CUSUMs Running Time Measurement
# Testing dataset: TEP, max_length: 1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[290], line 41
#      38 START = int(max_length * models_parameters['train_ratio'])
#      40 # Run on Raw Signals
# ---> 41 time_results_raw = run_all_cusums_time_meas(data,
#      42                                     dataset=ds,
#      43                                     datasets_parameters=datasets_parameters[ds],
#      44                                     cusums_parameters=cusums_parameters,
#      45                                     classic_threshold=False,
#      46                                     start=START,
#      47                                     measure_time=True)
#      49 results_raw[max_length - PARAM_ESTIMATION_SIZE] = time_results_raw
#      51 time_results_residual, time_results_model = run_all_cusums_time_meas(data,
#      52                                         dataset=ds,
#      53                                         datasets_parameters=datasets_parameters[ds],
#    (...)
#      59                                         start=START,
#      60                                         measure_time=True)
#
# Cell In[223], line 51, in run_all_cusums_time_meas(data, dataset, datasets_parameters, models_parameters, cusums_parameters, plots, model, run_on_residuals, classic_threshold, start, measure_time)
#      47     else:
#      48         files = datasets_parameters['files']
#      50     clean, fault, labels_clean, labels_fault = \
# ---> 51                     get_clean_fault_data(dataset = dataset,
#      52                                         data = data,
#      53                                         param_estimation_size = param_estimation_size,
#      54                                         max_length = max_length,
#      55                                         files = files,
#      56                                         dropped_columns = dropped_columns,
#      57                                         start = start)
#      58 else:
#      59     clean, fault, _, _, results_model_time = \
#      60                     get_clean_fault_residuals_data(dataset = dataset,
#      61                                         data = data,
#    (...)
#      64                                         models_parameters = models_parameters,
#      65                                         start = start)
#
# Cell In[286], line 174, in get_clean_fault_data(dataset, data, param_estimation_size, max_length, files, dropped_columns, start)
#     172         clean = np.delete(clean, dropped_columns, axis=1)
#     173         for i in range(len(fault)):
# --> 174             fault[i] = np.delete(fault[i], dropped_columns, axis=1)
#     176 #Truncate Data
#     177 if max_length != 0:
#
# File ~/cusum_exp/venv/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:5424, in delete(arr, obj, axis)
#    5421     slobj[axis] = keep
#    5422     new = arr[tuple(slobj)]
# -> 5424 return conv.wrap(new, to_scalar=False)
#
# KeyboardInterrupt:

# %%
# Plot the results

font_main = 17
font_title = 19
font_legend = 15
linewidth = 3

plt.rcParams.update({
    # Font sizes
    'font.size': font_main,
    'axes.labelsize': font_main,
    'xtick.labelsize': font_main,
    'ytick.labelsize': font_main,
    'legend.fontsize': font_legend,
    'axes.titlesize': font_title,
    'figure.titlesize': font_main,
    
    # Axis & grid styling
    'axes.grid': True,
    'axes.grid.which': 'major',
    'axes.linewidth': 0.8, 

    # Line widths
    'lines.linewidth': linewidth
})


# Plot CUSUMs CPU Usage
plt.figure(figsize=(12, 8))
plt.title("Running Time for CUSUMs on Raw Signals")
plt.xlabel("Max Length")
plt.ylabel("Running Time (seconds)")
plt.grid(True)

for cusum in cusum_list:
    plt.plot(MAX_LENGTHS, results_raw_f[cusum], label="Raw - {}".format(cusum))
plt.yscale('log')
plt.legend()
plt.tight_layout()
plt.savefig(program_parameters["plot_path"] + "raw_time.pdf", format='pdf')
# plt.show()


# Plot CUSUMs CPU Usage on Residuals
plt.figure(figsize=(12, 8))
plt.title("Running Time for CUSUMs on Residuals")
plt.xlabel("Max Length")
plt.ylabel("Running Time (seconds)")
for cusum in cusum_list:
    plt.plot(MAX_LENGTHS, results_residual_f[cusum], label="Residuals - {}".format(cusum))
plt.yscale('log')
plt.legend()
plt.tight_layout()
plt.savefig(program_parameters["plot_path"] + "residual_time.pdf", format='pdf')
# plt.show()

# Plot Model CPU Usage
plt.figure(figsize=(12, 8))
plt.title("Model Training and Testing Time")
plt.xlabel("Max Length")
plt.ylabel("Running Time (seconds)")
for meas in model_measure_list:
    plt.plot(MAX_LENGTHS, results_model_f[meas], label="Model - {}".format(meas))
plt.yscale('log')
plt.legend()
plt.tight_layout()
plt.savefig(program_parameters["plot_path"] + "model_time.pdf", format='pdf')

# %% [markdown]
# #### **Comparison Experiment Execution**

# %%
# STUMPY Algorithm
def detect_stumpy_discords(data, window_size=30, top_k=10):
    
    """
    Detects top_k discord subsequences (anomalies) using STUMPY Matrix Profile.

    Parameters:
    - data: 1D np.ndarray (should be z-normalized or detrended if needed)
    - window_size: size of sliding window
    - top_k: number of anomalous subsequences to flag

    Returns:
    - labels: np.ndarray of shape (len(data),), 1 = anomaly
    - profile: matrix profile values
    """

    mp = stumpy.stump(data, m=window_size)
    profile = mp[:, 0]
    anomaly_indices = np.argsort(profile)[-top_k:]

    labels = np.zeros(len(data))
    for idx in anomaly_indices:
        labels[idx:idx + window_size] = 1

    return labels.astype(int), profile

# %%
# Test [Comparissons] CUSUMs vs LSTM Threshold and STUMPY

PARAM_ESTIMATION_SIZE = 500
MAX_LENGTH = 5000

WINDOW_SIZE = 30

TRAINING_SIZE = int(MAX_LENGTH * models_parameters['train_ratio'])
START = TRAINING_SIZE

dataset = 'TEP'  # Change to the dataset you want to test
# Get data and labels

# Params.
param_estimation_size = datasets_parameters[dataset]['param_estimation_size']
max_length = datasets_parameters[dataset]['max_length']
variable = datasets_parameters[dataset]['variable']
dropped_columns = datasets_parameters[dataset]['dropped_columns']
simulation = datasets_parameters[dataset]['simulation']

# Get Clean and Fault Data
files = datasets_parameters[dataset]['files']

model = create_model(models_parameters, 
                     number_inputs = len(datasets_parameters['TEP']['inputs']),
                     number_outputs = len(datasets_parameters['TEP']['outputs']))

clean_raw, fault_raw, labels_clean_raw, labels_fault_raw = \
                get_clean_fault_data(dataset = dataset, 
                                    data = data, 
                                    param_estimation_size = param_estimation_size, 
                                    max_length = max_length,
                                    files = files,
                                    dropped_columns = dropped_columns,
                                    start = START)

clean_raw = np.array(clean_raw[START:, variable],dtype=float) 

for i in range(len(fault_raw)): 
    fault_raw[i] = np.array(fault_raw[i][:, variable], dtype=float)


clean_res, fault_res, labels_clean_res, labels_fault_res, _ = \
                        get_clean_fault_residuals_data(dataset = dataset, 
                                            data = data, 
                                            datasets_parameters = datasets_parameters[dataset],
                                            model = model,
                                            models_parameters = models_parameters,
                                            start = START)

# LSTM Detection

# Threshold estimation
threshold_res = max(clean_res[0:param_estimation_size])
threshold_res = np.mean(clean_res[0:param_estimation_size]) + 3 * np.std(clean_res[0:param_estimation_size])

# Detection on clean data residuals
clean_detections = []
clean_labels = (clean_res[param_estimation_size:] >= threshold_res).astype(int)
FPRs = np.sum(clean_labels) / len(clean_labels)

# Detection on fault data residuals
detection_labels = []
for res in fault_res:
    labels = (res >= threshold_res).astype(int)
    detection_labels.append(labels)

# Compute detection results
detection_results = []
for res in detection_labels:
    detection_results.append(tpr_fpr_dd(labels=labels_fault_res[0:len(res)], detections=res))

TPRs = [result['TPR'] for result in detection_results]
DDs = [result['DD'] for result in detection_results]

print("TPR: {}, FPR: {}, DD: {}".format(np.mean(TPRs), FPRs, np.mean(DDs)))

# STUMPY Detection
stumpy_labels, stumpy_profile = detect_stumpy_discords(data=clean_raw, 
                                                       window_size=WINDOW_SIZE, 
                                                       top_k=10)
stumpy_labels = stumpy_labels.astype(int)
FPRs = np.sum(stumpy_labels) / len(stumpy_labels)

stumpy_labels_faults = []
for fault in fault_raw:
    stumpy_labels_fault, _ = detect_stumpy_discords(data=np.concatenate([ clean_raw, fault ]), 
                                                    window_size=10, 
                                                    top_k=50)
    
    stumpy_labels_faults.append(stumpy_labels_fault.astype(int))

# Compute metrics: TPR, FPR, DD for STUMPY
detection_results = []
for label_fault in stumpy_labels_faults:
    detection_results.append(tpr_fpr_dd(labels=np.concatenate([labels_clean_raw[:len(clean_raw)], labels_fault_raw]), detections=label_fault))


TPRs_stumpy = [result['TPR'] for result in detection_results]
DDs_stumpy = [result['DD'] for result in detection_results]

print("TPR: {}, FPR: {}, DD: {}".format(np.mean(TPRs_stumpy), FPRs, np.mean(DDs_stumpy)))
# Out:
# TPR: 0.30800625, FPR: 0.016216216216216217, DD: 4.3
# TPR: 0.01596480582524272, FPR: 0.016933333333333335, DD: 599.55

# %%
# Test [Comparissons] CUSUMs vs LOF and IF (Not in the paper)
# After running them I realised thaat the results are not comparable
# It does not make sense to use LOF and IF in the same context.
# Especially on time series data, with clean and fault data
"""
    Compare CUSUMs with other methods
    - Set the parameters in the cusums_parameters dictionary
    - Set the parameters in the datasets_parameters dictionary
    - Feel free to add remove datasets, CUSUMs and parameters

    Compare the performance of CUSUMs with other anomaly detection methods
    - Local Outlier Factor (LOF)
    - Isolation Forest (IF)

    This paper is about CUSUMs, so we will not compare with other methods
    - Autoencoders, LSTM, etc. (Future Work)
"""

PARAM_ESTIMATION_SIZE = 500
MAX_LENGTH = 5000

WINDOW_SIZE = 30
CONTAMINATION = 0.5
NEIGHBORS = 20

TRAINING_SIZE = int(MAX_LENGTH * models_parameters['train_ratio'])
START = TRAINING_SIZE

dataset = 'TEP'  # Change to the dataset you want to test
# Get data and labels

# Params.
param_estimation_size = datasets_parameters[dataset]['param_estimation_size']
max_length = datasets_parameters[dataset]['max_length']
variable = datasets_parameters[dataset]['variable']
dropped_columns = datasets_parameters[dataset]['dropped_columns']
simulation = datasets_parameters[dataset]['simulation']

# Get Clean and Fault Data
files = datasets_parameters[dataset]['files']

clean_raw, fault_raw, labels_clean_raw, labels_fault_raw = \
                get_clean_fault_data(dataset = dataset, 
                                    data = data, 
                                    param_estimation_size = param_estimation_size, 
                                    max_length = max_length,
                                    files = files,
                                    dropped_columns = dropped_columns,
                                    start = START)

clean_res, fault_res, labels_clean_res, labels_fault_res, _ = \
                get_clean_fault_residuals_data(dataset = dataset, 
                                    data = data, 
                                    datasets_parameters = datasets_parameters[dataset],
                                    model = model,
                                    models_parameters = models_parameters,
                                    start = START)

for i in range(len(fault_raw)):
    fault_raw[i] = np.array(fault_raw[i][:, variable], dtype=float)

# Create sliding windows for the data
X_windows_raw = []
X_windows_res = []

for fault_file in fault_raw:
    X_windows_raw.append(create_sliding_windows(data = fault_file, 
                                                window_size = WINDOW_SIZE))

for fault_file in fault_res:
    X_windows_res.append(create_sliding_windows(data = fault_file, 
                                                window_size = WINDOW_SIZE))
    
# Run Local Outlier Factor (LOF) and Isolation Forest (IF) on Raw Signals
lof_labels_raw, lof_scores_raw  = [], []
iso_labels_raw, iso_scores_raw = [], []

for win_data in X_windows_raw:
    lof_labels, lof_scores = run_lof(data = win_data,
                                     n_neighbors = NEIGHBORS, 
                                     contamination = CONTAMINATION)
    
    lof_labels = np.pad(lof_labels, (WINDOW_SIZE-1, 0), constant_values=0)
    lof_labels_raw.append(lof_labels)
    lof_scores_raw.append(lof_scores)

    iso_labels, iso_scores = run_isolation_forest(data = win_data, 
                                                  contamination = CONTAMINATION)
    
    iso_labels = np.pad(iso_labels, (WINDOW_SIZE-1, 0), constant_values=0)
    iso_labels_raw.append(iso_labels)
    iso_scores_raw.append(iso_scores)

# Run Local Outlier Factor (LOF) and Isolation Forest (IF) on Residuals
lof_labels_res, lof_scores_res  = [], []
iso_labels_res, iso_scores_res = [], []

for win_data in X_windows_res:
    lof_labels, lof_scores = run_lof(data = win_data,
                                     n_neighbors = NEIGHBORS, 
                                     contamination = CONTAMINATION)
    
    lof_labels = np.pad(lof_labels, (WINDOW_SIZE-1, 0), constant_values=0)
    lof_labels_res.append(lof_labels)
    lof_scores_res.append(lof_scores)

    iso_labels, iso_scores = run_isolation_forest(data = win_data, 
                                                  contamination = CONTAMINATION)
    
    iso_labels = np.pad(iso_labels, (WINDOW_SIZE-1, 0), constant_values=0)
    iso_labels_res.append(iso_labels)
    iso_scores_res.append(iso_scores)


metrics_raw_lof, metrics_res_lof = [], []
metrics_raw_iso, metrics_res_iso = [], []

# Compute metrics: TPR, FPR, DD
for i in range(len(lof_labels_raw)):
    metrics_raw_lof.append(tpr_fpr_dd(labels=labels_fault_raw, detections=lof_labels_raw[i]))
    metrics_res_lof.append(tpr_fpr_dd(labels=labels_fault_res[:len(lof_labels_res[i])], detections=lof_labels_res[i]))


    metrics_raw_iso.append(tpr_fpr_dd(labels=labels_fault_raw, detections=iso_labels_raw[i]))
    metrics_res_iso.append(tpr_fpr_dd(labels=labels_fault_res[:len(iso_labels_res[i])], detections=iso_labels_res[i]))

# %% [markdown]
# #### **Parameters Optimizations/Analysis Experiment SETUP**

# %%
# Classical CUSUM Optimization

def optimize_classical_cusum(data = None, 
                             data_fault = None, 
                             labels = None, 
                             window_size = 30, 
                             oracle = False,
                             sim_len = None,
                             classic_threshold = False,
                             max_threshold = False):
    """" 
    Optimize the parameters of the classical CUSUM
        - h, shift size.
    """

    results = pd.DataFrame(columns=['h', 'shift', 'FPR', 'TPR'])

    # Use X% of the data for parameter estimation
    param_est  = data[:int(len(data) * 0.2)]
    test = data[int(len(data) * 0.2):]
    
    target_mean = estimate_target_mean(param_est)
    target_std = np.std(param_est)

    rows, run_once = [], 0

    if classic_threshold:
        # Max-based Threshsold Optimization
        for shift_size in np.linspace(0.5, 10, 100):
            shift_size = round(shift_size, 2)
            run_once = 0
            for h in np.linspace(0.5, 10, 100):
                h = round(h, 2)

                if max_threshold and run_once == 0:
                    run_once = 1
                elif max_threshold and run_once == 1:
                    continue

                k_estimated_classical = estimate_k_from_shift(std_dev=target_std, 
                                shift_size=shift_size)
                
                h_estimated_classical = estimate_cusum_threshold(clean_data=param_est, 
                                        h= h,
                                        max_threshold = max_threshold)

                _, _, detections_clean = classical_cusum(test, 
                                            target_mean=target_mean, 
                                            std_dev=target_std, 
                                            k=k_estimated_classical, 
                                            h=h_estimated_classical,
                                            simulation=simulation,
                                            sim_length=sim_len)
                    
                FPR = sum(detections_clean) / len(detections_clean)

                if oracle:
                    _, _, detections_fault = classical_cusum(data_fault, 
                                            target_mean=target_mean, 
                                            std_dev=target_std, 
                                            k=k_estimated_classical, 
                                            h=h_estimated_classical,
                                            simulation=simulation,
                                            sim_length=sim_len)
                    
                    TPR = np.sum(detections_fault[labels == 1]) / np.sum(labels == 1)

                    rows.append({'h': h, 'shift': shift_size, 'FPR': FPR, 'TPR': TPR})
                else:
                    rows.append({'h': h, 'shift': shift_size, 'FPR': FPR})
    else:
        # Mean/std-based Threshold Optimization
        for shift_size in np.linspace(0.5, 10, 100):
            shift_size = round(shift_size, 2)
            run_once = 0
            for h in np.linspace(0.5, 10, 100):
                h = round(h, 2)

                if max_threshold and run_once == 0:
                    run_once = 1

                elif max_threshold and run_once == 1:
                    continue
            
                k_estimated_classical = estimate_k_from_shift(std_dev=target_std, 
                            shift_size=shift_size)

                pos_clean, neg_clean, _ = classical_cusum(param_est, 
                                        target_mean=target_mean, 
                                        std_dev=target_std, 
                                        k=k_estimated_classical, 
                                        h=0)

                pos_clean = np.maximum(abs(pos_clean), abs(neg_clean))

                h_estimated_classical = estimate_cusum_threshold(cusum_stats_pos=pos_clean,
                                                                 h = h,
                                                                 max_threshold=max_threshold)

                _, _, detections_clean = classical_cusum(test, 
                                        target_mean=target_mean, 
                                        std_dev=target_std, 
                                        k=k_estimated_classical, 
                                        h=h_estimated_classical,
                                        simulation=simulation,
                                        sim_length=sim_len)
                
                FPR = sum(detections_clean) / len(detections_clean)

                if oracle:
                    _, _, detections_fault = classical_cusum(data_fault, 
                                            target_mean=target_mean, 
                                            std_dev=target_std, 
                                            k=k_estimated_classical, 
                                            h=h_estimated_classical,
                                            simulation=simulation,
                                            sim_length=sim_len)
                    
                    TPR = np.sum(detections_fault[labels == 1]) / np.sum(labels == 1)

                    rows.append({'h': h, 'shift': shift_size, 'FPR': FPR, 'TPR': TPR})
                else:
                    rows.append({'h': h, 'shift': shift_size, 'FPR': FPR})

    results = pd.DataFrame(rows)
    return results

# %%
# One-CUSUM CUSUM Optimization

def optimize_one_cusum(data = None, 
                             data_fault = None, 
                             labels = None, 
                             window_size = 30, 
                             oracle = False,
                             sim_len = None,
                             classic_threshold = False,
                             max_threshold = False):
    """" 
    Optimize the parameters of the ONE CUSUM
        One CUSUM Scheme: h, k, lambda
    """

    results = pd.DataFrame(columns=['h', 'shift', 'lambda', 'FPR', 'TPR'])

    # Use X% of the data for parameter estimation
    param_est  = data[:int(len(data) * 0.2)]
    test = data[int(len(data) * 0.2):]
    
    target_mean = estimate_target_mean(param_est)
    target_std = np.std(param_est)

    rows, run_once = [], 0

    if classic_threshold:
        # Max-based Threshsold Optimization
        for Lambda in np.linspace(0.0, 1, 10):

            for shift_size in np.linspace(0.5, 10, 100):
                shift_size = round(shift_size, 2)
                run_once = 0

                for h in np.linspace(0.5, 10, 100):
                    h = round(h, 2)

                    if max_threshold and run_once == 0:
                        run_once = 1
                    elif max_threshold and run_once == 1:
                        continue

                    k_estimated_one = estimate_k_from_shift(std_dev=target_std, 
                                    shift_size=shift_size)
                    
                    h_estimated_one = estimate_cusum_threshold(clean_data=param_est, 
                                            h= h,
                                            max_threshold = max_threshold)

                    _, detections_clean = one_cusum_scheme(test, 
                                          target_mean=target_mean, 
                                          k=k_estimated_one, 
                                          h=h_estimated_one, 
                                          lamb=Lambda, 
                                          simulation=simulation, 
                                          sim_length=sim_len) 
                        
                    FPR = sum(detections_clean) / len(detections_clean)

                    if oracle:
                        _, detections_fault = one_cusum_scheme(data_fault, 
                                          target_mean=target_mean, 
                                          k=k_estimated_one, 
                                          h=h_estimated_one, 
                                          lamb=Lambda, 
                                          simulation=simulation, 
                                          sim_length=sim_len) 
                        
                        TPR = np.sum(detections_fault[labels == 1]) / np.sum(labels == 1)

                        rows.append({'h': h, 'shift': shift_size, 'lambda': Lambda, 'FPR': FPR, 'TPR': TPR})
                    else:
                        rows.append({'h': h, 'shift': shift_size, 'lambda': Lambda, 'FPR': FPR})
    else:
        # Mean/std-based Threshold Optimization
        for Lambda in np.linspace(0.0, 1, 10):

            for shift_size in np.linspace(0.5, 10, 100):
                shift_size = round(shift_size, 2)
                run_once = 0

                for h in np.linspace(0.5, 10, 100):
                    h = round(h, 2)

                    if max_threshold and run_once == 0:
                        run_once = 1

                    elif max_threshold and run_once == 1:
                        continue
                
                    k_estimated_one = estimate_k_from_shift(std_dev=target_std, 
                                shift_size=shift_size)
                    
                    pos_clean, _ = one_cusum_scheme(param_est, 
                                          target_mean=target_mean, 
                                          k=k_estimated_one, 
                                          h=0, 
                                          lamb=Lambda) 


                    h_estimated_one = estimate_cusum_threshold(cusum_stats_pos=pos_clean,
                                                                    h = h,
                                                                    max_threshold=max_threshold)

                    _, detections_clean = one_cusum_scheme(test, 
                                          target_mean=target_mean, 
                                          k=k_estimated_one, 
                                          h=h_estimated_one, 
                                          lamb=Lambda,
                                          simulation=simulation, 
                                          sim_length=sim_len) 
                    
                    FPR = sum(detections_clean) / len(detections_clean)

                    if oracle:
                        _, detections_fault = one_cusum_scheme(test, 
                                          target_mean=target_mean, 
                                          k=k_estimated_one, 
                                          h=h_estimated_one, 
                                          lamb=Lambda, 
                                          simulation=simulation, 
                                          sim_length=sim_len) 
                        
                        TPR = np.sum(detections_fault[labels == 1]) / np.sum(labels == 1)

                        rows.append({'h': h, 'shift': shift_size, 'lambda': Lambda, 'FPR': FPR, 'TPR': TPR})
                    else:
                        rows.append({'h': h, 'shift': shift_size, 'lambda': Lambda, 'FPR': FPR})
                    

    results = pd.DataFrame(rows)
    return results

# %%
# Hampel CUSUM Optimization

def optimize_hampel_acusum(data = None,
                            data_fault = None, 
                            labels = None, 
                            window_size = 30, 
                            oracle = False,
                            sim_len = None,
                            classic_threshold = False,
                            max_threshold = False):
    """" 
    Optimize the parameters of the Hampel CUSUM
        - a,b,r,gamma, h
    """

    results = pd.DataFrame(columns=['h', 'a', 'b', 'r', 'gamma', 'FPR', 'TPR'])

    # Use X% of the data for parameter estimation
    param_est  = data[:int(len(data) * 0.2)]
    test = data[int(len(data) * 0.2):]
    
    target_mean = estimate_target_mean(param_est)
    target_std = np.std(param_est)

    rows, run_once = [], 0

    if classic_threshold:
        for a in np.linspace(3, 11, 17):
            a = round(a, 2)
            for b in np.linspace(3.5, 11.5, 17):
                b = round(b, 2)
                for r in np.linspace(3, 11, 17):
                    r = round(r, 2)
                    for gamma in np.linspace(4, 12, 17):
                        gamma = round(gamma, 2)
                        run_once = 0
                        for h in np.linspace(0.5, 10, 100):
                            h = round(h, 2)

                            if max_threshold and run_once == 0:
                                run_once = 1
                            elif max_threshold and run_once == 1:
                                continue
                            
                            k_estimated_hampel = estimate_k_from_shift(std_dev=target_std, 
                                            shift_size=cusums_parameters['hampel_acusum']['shift_size'])
                                
                            h_estimated_hampel = estimate_cusum_threshold(clean_data=param_est, 
                                                    h= h,
                                                    max_threshold = max_threshold)

                            _, _, detections_clean = \
                                    hampel_acusum(test, 
                                       a=a, 
                                       b=b, 
                                       r=r, 
                                       gamma=gamma, 
                                       h=h_estimated_hampel, 
                                       k_plus=k_estimated_hampel, 
                                       k_minus=k_estimated_hampel,
                                       simulation=simulation,
                                        sim_length=sim_len)
                                
                            FPR = sum(detections_clean) / len(detections_clean)


                            # run on faulty data as well
                            if oracle:
                                _, _, detections_fault = \
                                    hampel_acusum(data_fault, 
                                       a=a, 
                                       b=b, 
                                       r=r, 
                                       gamma=gamma, 
                                       h=h_estimated_hampel, 
                                       k_plus=k_estimated_hampel, 
                                       k_minus=k_estimated_hampel,
                                       simulation=simulation,
                                        sim_length=sim_len)
                                
                                TPR = np.sum(detections_fault[labels == 1]) / np.sum(labels == 1)

                                rows.append({'h': h, 'a': a, 'b': b, 'r': r, 'gamma': gamma, 'FPR': FPR, 'TPR': TPR})
                            else:
                                rows.append({'h': h, 'a': a, 'b': b, 'r': r, 'gamma': gamma, 'FPR': FPR})
    else:
        # Mean/std-based Threshold Optimization
        for a in np.linspace(3, 11, 17):
            a = round(a, 2)
            for b in np.linspace(3.5, 11.5, 17):
                b = round(b, 2)
                for r in np.linspace(3, 11, 17):
                    r = round(r, 2)
                    for gamma in np.linspace(4, 12, 17):
                        gamma = round(gamma, 2)
                        run_once = 0
                        for h in np.linspace(0.5, 10, 100):
                            h = round(h, 2)

                            if max_threshold and run_once == 0:
                                run_once = 1

                            elif max_threshold and run_once == 1:
                                continue
                        
                            k_estimated_hampel = estimate_k_from_shift(std_dev=target_std, 
                                            shift_size=cusums_parameters['hampel_acusum']['shift_size'])


                            pos_clean, neg_clean, _ = hampel_acusum(param_est, 
                                       a=a, 
                                       b=b, 
                                       r=r, 
                                       gamma=gamma, 
                                       h=0, 
                                       k_plus=k_estimated_hampel, 
                                       k_minus=k_estimated_hampel)
        
                            pos_clean = np.maximum(abs(pos_clean), abs(neg_clean))

                            h_estimated_hampel = estimate_cusum_threshold(cusum_stats_pos=pos_clean,
                                                                            h = h,
                                                                            max_threshold=max_threshold)
                            _, _, detections_clean = \
                                    hampel_acusum(test, 
                                       a=a, 
                                       b=b, 
                                       r=r, 
                                       gamma=gamma, 
                                       h=h_estimated_hampel, 
                                       k_plus=k_estimated_hampel, 
                                       k_minus=k_estimated_hampel,
                                       simulation=simulation,
                                       sim_length=sim_len)
                            
                            FPR = sum(detections_clean) / len(detections_clean)

                            # run on faulty data as well
                            if oracle:
                                _, _, detections_fault = \
                                    hampel_acusum(data_fault, 
                                       a=a, 
                                       b=b, 
                                       r=r, 
                                       gamma=gamma, 
                                       h=h_estimated_hampel, 
                                       k_plus=k_estimated_hampel, 
                                       k_minus=k_estimated_hampel,
                                       simulation=simulation,
                                        sim_length=sim_len)
                                
                                TPR = np.sum(detections_fault[labels == 1]) / np.sum(labels == 1)
                                
                                rows.append({'h': h, 'a': a, 'b': b, 'r': r, 'gamma': gamma, 'FPR': FPR, 'TPR': TPR})
                            else:
                                rows.append({'h': h, 'a': a, 'b': b, 'r': r, 'gamma': gamma, 'FPR': FPR})

    results = pd.DataFrame(rows)
    return results

# %%
# UCUSUM Optimization

def optimize_ucusum(data = None, 
                        data_fault = None, 
                        labels = None, 
                        window_size = 30, 
                        oracle = False,
                        sim_len = None,
                        classic_threshold = False,
                        max_threshold = False):
    """" 
    Optimize the parameters of the UCUSUM
        - h.
    """

    results = pd.DataFrame(columns=['h',  'FPR', 'TPR'])

    # Use X% of the data for parameter estimation
    param_est  = data[:int(len(data) * 0.2)]
    test = data[int(len(data) * 0.2):]
    
    target_mean = estimate_target_mean(param_est)

    rows, run_once = [], 0

    if classic_threshold:
        # Max-based Threshsold Optimization
        run_once = 0
        for h in np.linspace(0.5, 10, 100):
            h = round(h, 2)

            if max_threshold and run_once == 0:
                run_once = 1
            elif max_threshold and run_once == 1:
                continue
            
            h_estimated_ucusum = estimate_cusum_threshold(clean_data=param_est, 
                                    h= h,
                                    max_threshold = max_threshold)

            _, detections_clean = UCUSUM(test, 
                                        target_mean=target_mean, 
                                        h=h_estimated_ucusum,
                                        simulation=simulation,
                                        sim_length=sim_len)
                
            FPR = sum(detections_clean) / len(detections_clean)

            if oracle:
                _, detections_fault = UCUSUM(data_fault, 
                                        target_mean=target_mean, 
                                        h=h_estimated_ucusum,
                                        simulation=simulation,
                                        sim_length=sim_len)
                
                TPR = np.sum(detections_fault[labels == 1]) / np.sum(labels == 1)

                rows.append({'h': h,  'FPR': FPR, 'TPR': TPR})
            else:
                rows.append({'h': h,  'FPR': FPR})
    else:
        # Mean/std-based Threshold Optimization
        run_once = 0
        for h in np.linspace(0.5, 10, 100):
            h = round(h, 2)

            if max_threshold and run_once == 0:
                run_once = 1

            elif max_threshold and run_once == 1:
                continue
        
            pos_clean, _ =  UCUSUM(param_est, 
                            target_mean=target_mean, 
                            h= 0)
                
            h_estimated_ucusum = estimate_cusum_threshold(cusum_stats_pos=pos_clean,
                                                            h = h,
                                                            max_threshold=max_threshold)

            _, detections_clean = UCUSUM(test, 
                                        target_mean=target_mean, 
                                        h=h_estimated_ucusum,
                                        simulation=simulation,
                                        sim_length=sim_len)
            
            FPR = sum(detections_clean) / len(detections_clean)

            if oracle:
                _, detections_fault = UCUSUM(data_fault, 
                                        target_mean=target_mean, 
                                        h=h_estimated_ucusum,
                                        simulation=simulation,
                                        sim_length=sim_len)
                
                TPR = np.sum(detections_fault[labels == 1]) / np.sum(labels == 1)

                rows.append({'h': h,  'FPR': FPR, 'TPR': TPR})
            else:
                rows.append({'h': h,  'FPR': FPR})
            
    results = pd.DataFrame(rows)
    return results

# %%
# Variance CUSUM Optimization

def optimize_variance_cusum(data = None, 
                             data_fault = None, 
                             labels = None, 
                             window_size = 30, 
                             oracle = False,
                             sim_len = None,
                             classic_threshold = False,
                             max_threshold = False):
                             
    """" 
    Optimize the parameters of the Variance Cusum
        - h, k, window
    """
    results = pd.DataFrame(columns=['h', 'shift', 'window', 'FPR', 'TPR'])

    # Use X% of the data for parameter estimation
    param_est  = data[:int(len(data) * 0.2)]
    test = data[int(len(data) * 0.2):]
    
    target_mean = estimate_target_mean(param_est)
    target_std = np.std(param_est)

    rows, run_once = [], 0

    if classic_threshold:
        # Max-based Threshsold Optimization
        for window in np.linspace(10, 100, 90):

            for shift_size in np.linspace(0.5, 10, 100):
                shift_size = round(shift_size, 2)
                run_once = 0

                for h in np.linspace(0.5, 10, 100):
                    h = round(h, 2)

                    if max_threshold and run_once == 0:
                        run_once = 1
                    elif max_threshold and run_once == 1:
                        continue

                    k_estimated_variance = estimate_k_from_shift(std_dev=target_std, 
                                    shift_size=shift_size)
                    
                    h_estimated_variance = estimate_cusum_threshold(clean_data=param_est, 
                                            h= h,
                                            max_threshold = max_threshold)

                    _, _, detections_clean = variance_cusum(test, 
                                    target_var=target_std, 
                                    window=window, 
                                    k=k_estimated_variance, 
                                    h=h_estimated_variance,
                                    simulation=simulation,
                                    sim_length=sim_len)
                        
                    FPR = sum(detections_clean) / len(detections_clean)

                    if oracle:
                        _, _, detections_fault = variance_cusum(data_fault, 
                                    target_var=target_std, 
                                    window=window, 
                                    k=k_estimated_variance, 
                                    h=h_estimated_variance,
                                    simulation=simulation,
                                    sim_length=sim_len)
                        
                        TPR = np.sum(detections_fault[labels == 1]) / np.sum(labels == 1)

                        rows.append({'h': h, 'shift': shift_size, 'window': window, 'FPR': FPR, 'TPR': TPR})
                    else:
                        rows.append({'h': h, 'shift': shift_size, 'window': window, 'FPR': FPR})
    else:
        for window in np.linspace(10, 100, 90):
            # Mean/std-based Threshold Optimization
            for shift_size in np.linspace(0.5, 10, 100):
                shift_size = round(shift_size, 2)
                run_once = 0
                for h in np.linspace(0.5, 10, 100):
                    h = round(h, 2)

                    if max_threshold and run_once == 0:
                        run_once = 1

                    elif max_threshold and run_once == 1:
                        continue
                
                    k_estimated_variance = estimate_k_from_shift(std_dev=target_std, 
                                shift_size=shift_size)


                    pos_clean, neg_clean, _  = variance_cusum(param_est, 
                                    target_var=target_std, 
                                    window=window, 
                                    k=k_estimated_variance, 
                                    h=0)
                    
                    pos_clean = np.maximum(abs(pos_clean), abs(neg_clean))

                    h_estimated_variance = estimate_cusum_threshold(cusum_stats_pos=pos_clean,
                                                                    h = h,
                                                                    max_threshold=max_threshold)

                    _, _, detections_clean = variance_cusum(test, 
                                    target_var=target_std, 
                                    window=window, 
                                    k=k_estimated_variance, 
                                    h=h_estimated_variance,
                                    simulation=simulation,
                                    sim_length=sim_len)
                    
                    FPR = sum(detections_clean) / len(detections_clean)

                    if oracle:
                        _, _, detections_fault = variance_cusum(data_fault, 
                                    target_var=target_std, 
                                    window=window, 
                                    k=k_estimated_variance, 
                                    h=h_estimated_variance,
                                    simulation=simulation,
                                    sim_length=sim_len)
                        
                        TPR = np.sum(detections_fault[labels == 1]) / np.sum(labels == 1)

                        rows.append({'h': h, 'shift': shift_size, 'window': window, 'FPR': FPR, 'TPR': TPR})
                    else:
                        rows.append({'h': h, 'shift': shift_size, 'window': window, 'FPR': FPR})

    results = pd.DataFrame(rows)
    return results

# %%
# High Order CUSUM Optimization

def optimize_high_order_cusum(data = None, 
                             data_fault = None, 
                             labels = None, 
                             window_size = 30, 
                             oracle = False,
                             sim_len = None,
                             classic_threshold = False,
                             max_threshold = False):
                             
    """" 
    Optimize the parameters of the High Order Cusum
        - h, alpha, window
    """
    results = pd.DataFrame(columns=['h', 'alpha', 'window', 'FPR', 'TPR'])

    # Use X% of the data for parameter estimation
    param_est  = data[:int(len(data) * 0.2)]
    test = data[int(len(data) * 0.2):]
    
    rows, run_once = [], 0

    if classic_threshold:
        # Max-based Threshsold Optimization
        for window in np.linspace(10, 100, 90):

            for alpha in np.linspace(0.0, 1, 10):
                alpha = round(alpha, 2)
                run_once = 0

                for h in np.linspace(0.5, 10, 100):
                    h = round(h, 2)

                    if max_threshold and run_once == 0:
                        run_once = 1
                    elif max_threshold and run_once == 1:
                        continue


                    exp_x, k_estimated_ho = np.abs(estimate_k_from_stats(data = param_est, 
                                                         alpha=alpha,
                                                         window=window))
                    
                    h_estimated_ho = estimate_cusum_threshold(clean_data=param_est, 
                                                                h = h,
                                                                max_threshold = max_threshold)

                    _, _, _ , detections_clean = high_order_cusum(test, 
                                            window = window, 
                                            alpha = alpha,
                                            exp_x=exp_x,
                                            k=k_estimated_ho, 
                                            h=h_estimated_ho,
                                            simulation=simulation,
                                            sim_length=sim_len)
                        
                    FPR = sum(detections_clean) / len(detections_clean)

                    if oracle:
                        _, _, _ , detections_fault = high_order_cusum(data_fault, 
                                                        window = window, 
                                                        alpha = alpha,
                                                        exp_x=exp_x,
                                                        k=k_estimated_ho, 
                                                        h=h_estimated_ho,
                                                        simulation=simulation,
                                                        sim_length=sim_len)
                            
                        TPR = np.sum(detections_fault[labels == 1]) / np.sum(labels == 1)

                        rows.append({'h': h, 'alpha': alpha, 'window': window, 'FPR': FPR, 'TPR': TPR})
                    else:
                        rows.append({'h': h, 'alpha': alpha, 'window': window, 'FPR': FPR})
    else:
        for window in np.linspace(10, 100, 90):
            window = round(window, 2)
            # Mean/std-based Threshold Optimization
            for alpha in np.linspace(0.0, 1, 10):
                alpha = round(alpha, 2)

                run_once = 0
                
                for h in np.linspace(0.5, 10, 100):
                    h = round(h, 2)

                    if max_threshold and run_once == 0:
                        run_once = 1

                    elif max_threshold and run_once == 1:
                        continue
                
                    exp_x, k_estimated_ho = np.abs(estimate_k_from_stats(data = param_est, 
                                                         alpha=alpha,
                                                         window=window))

                    pos_clean, neg_clean, _, _ = high_order_cusum(param_est, 
                                            window = window, 
                                            alpha = alpha,
                                            exp_x=exp_x,
                                            k=k_estimated_ho)
                    
                    pos_clean = np.maximum(abs(pos_clean), abs(neg_clean))

                    h_estimated_ho = estimate_cusum_threshold(cusum_stats_pos=pos_clean, 
                                            cusum_stats_neg=neg_clean,
                                            clean_data=param_est, 
                                            h=h, 
                                            csm_type="high_order",
                                            window=window,
                                            alpha=alpha,
                                            max_threshold=max_threshold)
                    
                    _, _, _ , detections_clean = high_order_cusum(test, 
                                            window = window, 
                                            alpha = alpha,
                                            exp_x=exp_x,
                                            k=k_estimated_ho, 
                                            h=h_estimated_ho,
                                            simulation=simulation,
                                            sim_length=sim_len)
                    
                    FPR = sum(detections_clean) / len(detections_clean)

                    if oracle:
                        _, _, _ , detections_fault = high_order_cusum(data_fault, 
                                                        window = window, 
                                                        alpha = alpha,
                                                        exp_x=exp_x,
                                                        k=k_estimated_ho, 
                                                        h=h_estimated_ho,
                                                        simulation=simulation,
                                                        sim_length=sim_len)
                            
                        TPR = np.sum(detections_fault[labels == 1]) / np.sum(labels == 1)

                        rows.append({'h': h, 'alpha': alpha, 'window': window, 'FPR': FPR, 'TPR': TPR})
                    else:
                        rows.append({'h': h, 'alpha': alpha, 'window': window, 'FPR': FPR})

    results = pd.DataFrame(rows)
    return results

# %% [markdown]
# #### **Parameters Optimizations/Analysis Experiment Execution**

# %%
# Run over all CUSUMs and parameters
# There will be to much redundant code, for all the cusum functions....
# I will fix this later, or just leave it like this, it works.

def optimize_cusum_parameters(data = None, 
                              data_fault = None, 
                              labels = None, 
                              window_size = 30, 
                              cusum = 'classic',
                              oracle = False,
                              sim_len = None,
                              classic_threshold = False,
                              max_threshold = False,
                              simulation = False):
    if data is None:
        raise ValueError("Data must be provided")
    if labels is None:
        raise ValueError("Labels must be provided")
    if oracle is True and data_fault is None:
        raise ValueError("Data fault must be provided for oracle mode")

    if cusum == 'classic':
        return optimize_classical_cusum(data = data, 
                                        data_fault = data_fault,
                                        labels = labels, 
                                        window_size = window_size,
                                        oracle = oracle,
                                        sim_len = sim_len,
                                        classic_threshold = classic_threshold,
                                        max_threshold = max_threshold,
                                        simulation = simulation)
    elif cusum == 'one_cusum':
        return optimize_one_cusum(data = data, 
                                    data_fault = data_fault,
                                    labels = labels, 
                                    window_size = window_size,
                                    oracle = oracle,
                                    sim_len = sim_len,
                                    classic_threshold = classic_threshold,
                                    max_threshold = max_threshold,
                                    simulation = simulation)

    elif cusum == 'hampel_acusum':
        return optimize_hampel_acusum(data = data, 
                                    data_fault = data_fault,
                                    labels = labels, 
                                    window_size = window_size,
                                    oracle = oracle,
                                    sim_len = sim_len,
                                    classic_threshold = classic_threshold,
                                    max_threshold = max_threshold,
                                    simulation = simulation)
    elif cusum == 'UCUSUM':
        return optimize_ucusum(data = data, 
                                    data_fault = data_fault,
                                    labels = labels, 
                                    window_size = window_size,
                                    oracle = oracle,
                                    sim_len = sim_len,
                                    classic_threshold = classic_threshold,
                                    max_threshold = max_threshold,
                                    simulation = simulation)
    elif cusum == 'variance':
        return optimize_variance_cusum(data = data, 
                                    data_fault = data_fault,
                                    labels = labels, 
                                    window_size = window_size,
                                    oracle = oracle,
                                    sim_len = sim_len,
                                    classic_threshold = classic_threshold,
                                    max_threshold = max_threshold,
                                    simulation = simulation)

    elif cusum == 'high_order':
        return optimize_high_order_cusum(data = data, 
                                    data_fault = data_fault,
                                    labels = labels, 
                                    window_size = window_size,
                                    oracle = oracle,
                                    sim_len = sim_len,
                                    classic_threshold = classic_threshold,
                                    max_threshold = max_threshold,
                                    simulation = simulation)

# %%
# Test [Parameters Optimization] of CUSUMs
from collections import defaultdict

def test_optimize_cusum_parameters(dataset="TEP", 
                                   cusum = 'classic', 
                                   MAX_LENGTH = 50_000,
                                   PARAM_ESTIMATION_SIZE = 10_000,
                                   WINDOW_SIZE = 30,
                                   START = 0):
    
    """ 
        Try to optimize the parameters on clean data only.
        In real life scenarios, clean data is easier to obtain compared to faulty data 
        that covers all possible scenarios

        Parameters for CUSUMs to be optimized:
            Classical CUSUM: h, k
            One CUSUM Scheme: h, k, lambda
            Hampel CUSUM: a,b,r,gamma, h
            UCUSUM: h, window
            variance cusum: h, k, window
            High Order CUSUM: h, alpha, window
    """

    # Load the dataset and load the parameters

    TRAINING_SIZE = int(MAX_LENGTH * models_parameters['train_ratio'])
    START = TRAINING_SIZE

    # dataset = 'TEP'  # Change to the dataset you want to test
    # Get data and labels

    # Params.
    datasets_parameters[dataset]['param_estimation_size'] = PARAM_ESTIMATION_SIZE
    datasets_parameters[dataset]['max_length'] = MAX_LENGTH

    variable = datasets_parameters[dataset]['variable']
    dropped_columns = datasets_parameters[dataset]['dropped_columns']
    simulation = datasets_parameters[dataset]['simulation']

    if simulation:
        sim_len = datasets_parameters[dataset]['sim_length']
    else:
        sim_len = 0

    # Get Clean and Fault Data
    files = datasets_parameters[dataset]['files']

    model = create_model(models_parameters, 
                        number_inputs = len(datasets_parameters['TEP']['inputs']),
                        number_outputs = len(datasets_parameters['TEP']['outputs']))

    clean_raw, _, labels_clean_raw, _ = \
                    get_clean_fault_data(dataset = dataset, 
                                        data = data, 
                                        param_estimation_size = PARAM_ESTIMATION_SIZE, 
                                        max_length = MAX_LENGTH,
                                        files = files,
                                        dropped_columns = dropped_columns,
                                        start = START)

    clean_raw = np.array(clean_raw[START:, variable],dtype=float) 

    clean_res, _, labels_clean_res, _, _ = \
                            get_clean_fault_residuals_data(dataset = dataset, 
                                                data = data, 
                                                datasets_parameters = datasets_parameters[dataset],
                                                model = model,
                                                models_parameters = models_parameters,
                                                start = START)

    # Threshold based on signal value (h*std)
    results_raw_clas_thresh_no_max = optimize_cusum_parameters(data = clean_raw, 
                                data_fault = None, 
                                labels = labels_clean_raw, 
                                window_size = WINDOW_SIZE, 
                                cusum = cusum,
                                oracle = False,
                                sim_len = sim_len,
                                classic_threshold = True,
                                simulation = simulation)

    # Threshold based on cusum over param est data (mean + std of the cusum)
    results_raw_csm_thresh_no_max = optimize_cusum_parameters(data = clean_raw, 
                                data_fault = None, 
                                labels = labels_clean_raw, 
                                window_size = WINDOW_SIZE, 
                                cusum = cusum,
                                oracle = False,
                                sim_len = sim_len,
                                classic_threshold = False,
                                simulation = simulation
                                )

    # Threshold based on residual value (h*std))
    results_res_clas_thresh_no_max = optimize_cusum_parameters(data = clean_res, 
                                data_fault = None, 
                                labels = labels_clean_res, 
                                window_size = WINDOW_SIZE, 
                                cusum = cusum,
                                oracle = False,
                                sim_len = sim_len,
                                classic_threshold = True,
                                simulation = simulation)

    # Threshold based on cusum over param est residual data (mean + std of the cusum)
    results_res_csm_thresh_no_max = optimize_cusum_parameters(data = clean_res, 
                                data_fault = None, 
                                labels = labels_clean_res, 
                                window_size = WINDOW_SIZE, 
                                cusum = cusum,
                                oracle = False,
                                sim_len = sim_len,
                                classic_threshold = False,
                                simulation = simulation
                                )

    results_raw_csm_thresh_max = optimize_cusum_parameters(data = clean_raw, 
                                data_fault = None, 
                                labels = labels_clean_raw, 
                                window_size = WINDOW_SIZE, 
                                cusum = cusum,
                                oracle = False,
                                sim_len = sim_len,
                                max_threshold = True,
                                simulation = simulation)

    results_res_csm_thresh_max = optimize_cusum_parameters(data = clean_res, 
                                data_fault = None, 
                                labels = labels_clean_res, 
                                window_size = WINDOW_SIZE, 
                                cusum = cusum,
                                oracle = False,
                                sim_len = sim_len,
                                max_threshold = True,
                                simulation = simulation)

    return results_raw_clas_thresh_no_max, \
                results_raw_csm_thresh_no_max, \
                results_res_clas_thresh_no_max, \
                results_res_csm_thresh_no_max, \
                results_raw_csm_thresh_max, \
                results_res_csm_thresh_max

####################################################

MAX_LENGTH = 50_000
PARAM_ESTIMATION_SIZE = 10_000
WINDOW_SIZE = 30

file = "results/results_cusum_opt_no_oracle.pkl"

if not os.path.exists('results'):
    os.makedirs('results')

if os.path.exists(file):
    results_no_oracle = load_pickle(file)
else:

    # results[dataset][cusum_model][result_type] = data
    results_no_oracle = defaultdict(lambda: defaultdict(dict))

    datasets = ['TEP', 'LBNL', 'SKAB', 'RMFD']
    datasets = ['TEP']

    cusums = [
        'high_order',
        'classic',
        'one_cusum',
        'hampel_acusum',
        'UCUSUM',
        'variance'
    ]

    for dataset in datasets:
        for csm in cusums:
            r1, r2, r3, r4, r5, r6 = test_optimize_cusum_parameters(
                dataset=dataset, 
                cusum=csm,  
                oracle=False,
                MAX_LENGTH=MAX_LENGTH,
                PARAM_ESTIMATION_SIZE=PARAM_ESTIMATION_SIZE,
                WINDOW_SIZE=WINDOW_SIZE
            )

            results_no_oracle[dataset][csm]['raw_clas_thresh_no_max'] = r1
            results_no_oracle[dataset][csm]['raw_csm_thresh_no_max'] = r2
            results_no_oracle[dataset][csm]['res_clas_thresh_no_max'] = r3
            results_no_oracle[dataset][csm]['res_csm_thresh_no_max'] = r4
            results_no_oracle[dataset][csm]['raw_csm_thresh_max'] = r5
            results_no_oracle[dataset][csm]['res_csm_thresh_max'] = r6

    save_pickle(results_no_oracle, file)

# %%
# Plot [Parameters Optimization] of CUSUMs Results
# (not sure if it is actual optimization)

# Well, we are doing a grid seach approach, so it might be.
# Maybe just call it parameter estimation and analysis in the final paper.
# We are going to plot the results for the raw data and the residual data
# Who is we? I am writing this code alone, I think I am at a few thousand lines of code by now.
# Lock in! Doing the grind boiii!

from mpl_toolkits.mplot3d import Axes3D

def plot3D_cusum(data, title, figname, save = True):

    h_vals = data['h'].values
    shift_vals = data['shift'].values
    fpr_vals = data['FPR'].values

    H = np.unique(h_vals)
    S = np.unique(shift_vals)
    H_grid, S_grid = np.meshgrid(H, S)

    FPR_grid = fpr_vals.reshape(len(S), len(H))

    fig = plt.figure(figsize=(9, 8))
    ax = fig.add_subplot(111, projection='3d')

    surf = ax.plot_surface(H_grid, S_grid, FPR_grid, cmap='viridis')
    ax.set_xlabel('Threshold h', labelpad=10)
    ax.set_ylabel('Shift Size', labelpad=10)
    ax.set_zlabel('FPR', labelpad = 15)
    ax.view_init(elev=25, azim=45)
    ax.zaxis.set_tick_params(pad=8)
    ax.set_zlim(0, 1)

    plt.title(title,  pad=5)

    if save:
        plt.savefig(f'{figname}.png', format='png')
    else:
        plt.show()

    return fig

def plot2D_cusum(data, title, figname, save = True):

    shift_vals = data['shift'].values
    fpr_vals = data['FPR'].values

    fig = plt.figure(figsize=(13, 7))

    plt.scatter(shift_vals, fpr_vals)
    plt.xlabel('Shift Size')
    plt.ylabel('FPR')
    plt.title(title)
    plt.ylim(0, 0.02)

    if save:
        plt.savefig(f'{figname}.png', format='png')
    else:
        plt.show()

    return fig


file = 'results/results_cusum_opt_no_oracle.pkl'

if not os.path.exists(file):
    raise ValueError(f"{file} does not exist! Run test_optimize_cusum_parameters first!")

else:
    results_no_oracle = load_pickle(file)

    for dataset, cusum_dict in results_no_oracle.items():
        for cusum_model, result_dict in cusum_dict.items():

            print(f"{dataset} | {cusum_model} ")

            r1, r2, r3, r4, r5, r6 = result_dict.values()

            plot3D_cusum(r1, 
                        title = f"{cusum_model} on raw signals with STD threshold", 
                        figname = f"{cusum_model}_{dataset}_fpr_raw_tep_clas_thresh", 
                        save = True)


            plot3D_cusum(r2, 
                        title = f"{cusum_model} on raw signals with CSM threshold", 
                        figname = f"{cusum_model}_{dataset}_raw_csm_thresh", 
                        save = True)


            plot3D_cusum(r3, 
                        title = f"{cusum_model} on residuals with STD threshold", 
                        figname = f"{cusum_model}_{dataset}_res_clas_thresh", 
                        save = True)

            plot3D_cusum(r4, 
                        title = f"{cusum_model} on residuals with STD threshold", 
                        figname = f"{cusum_model}_{dataset}_res_csm_thresh", 
                        save = True)


            plot2D_cusum(r5, 
                        title = f"{cusum_model} on raw signals with max threshold", 
                        figname = f"{cusum_model}_{dataset}_raw_tep_max", 
                        save = True)

            plot2D_cusum(r6, 
                        title = f"{cusum_model} on residuals with max threshold", 
                        figname = f"{cusum_model}_{dataset}_res_max", 
                        save = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[330], line 56
#      53 file = 'results/results_cusum_opt_no_oracle.pkl'
#      55 if not os.path.exists(file):
# ---> 56     raise ValueError(f"{file} does not exist! Run test_optimize_cusum_parameters first!")
#      58 else:
#      59     results_no_oracle = load_pickle(file)
#
# ValueError: results/results_cusum_opt_no_oracle.pkl does not exist! Run test_optimize_cusum_parameters first!

# %%
# Test [Oracle-based Parameters Optimization] of CUSUMs

from collections import defaultdict

def test_optimize_cusum_parameters_oracle(dataset="TEP", 
                                   cusum = 'classic', 
                                   oracle = True,
                                   MAX_LENGTH = 50_000,
                                   PARAM_ESTIMATION_SIZE = 10_000,
                                   WINDOW_SIZE = 30,
                                   START = 0):
    """ 
        Try to optimize the parameters on clean and some faulty data.
        This experiment functions under the assumpation that some faulty data is available
        and the parameters are optimized based on the available data.
        Nonetheless, if we were to use all faulty data, the problem would be trivial.
        Let classifiers take care of this issue (which is unrealistic in real world scenarios).
        This experiment tests the extreme caases and is not recommended for real world applications.
        However, if one wants to publish high performance results (99-100 detection all the time), 
        this is the way to go. 

    """
    # Load the dataset and load the parameters

    TRAINING_SIZE = int(MAX_LENGTH * models_parameters['train_ratio'])
    START = TRAINING_SIZE

    # dataset = 'TEP'  # Change to the dataset you want to test
    # Get data and labels

    # Params.
    datasets_parameters[dataset]['param_estimation_size'] = PARAM_ESTIMATION_SIZE
    datasets_parameters[dataset]['max_length'] = MAX_LENGTH

    variable = datasets_parameters[dataset]['variable']
    dropped_columns = datasets_parameters[dataset]['dropped_columns']
    simulation = datasets_parameters[dataset]['simulation']

    if simulation:
        sim_len = datasets_parameters[dataset]['sim_length']
    else:
        sim_len = 0

    # Get Clean and Fault Data
    files = datasets_parameters[dataset]['files']

    model = create_model(models_parameters, 
                        number_inputs = len(datasets_parameters['TEP']['inputs']),
                        number_outputs = len(datasets_parameters['TEP']['outputs']))

    clean_raw, fault_raw, labels_clean_raw, labels_fault_raw = \
                    get_clean_fault_data(dataset = dataset, 
                                        data = data, 
                                        param_estimation_size = PARAM_ESTIMATION_SIZE, 
                                        max_length = MAX_LENGTH,
                                        files = files,
                                        dropped_columns = dropped_columns,
                                        start = START)

    clean_raw = np.array(clean_raw[START:, variable],dtype=float) 

    for i in range(len(fault_raw)): 
        fault_raw[i] = np.array(fault_raw[i][:, variable], dtype=float)

    clean_res, fault_res, labels_clean_res, labels_fault_res, _ = \
                            get_clean_fault_residuals_data(dataset = dataset, 
                                                data = data, 
                                                datasets_parameters = datasets_parameters[dataset],
                                                model = model,
                                                models_parameters = models_parameters,
                                                start = START)


    # Threshold based on signal value (h*std)
    results_raw_clas_thresh_no_max = optimize_cusum_parameters(data = clean_raw, 
                                data_fault = fault_res, 
                                labels = labels_clean_raw,
                                labels_fault = labels_fault_raw, 
                                window_size = WINDOW_SIZE, 
                                cusum = cusum,
                                oracle = oracle,
                                sim_len = sim_len,
                                classic_threshold = True,
                                simulation = simulation)

    # Threshold based on cusum over param est data (mean + std of the cusum)
    results_raw_csm_thresh_no_max = optimize_cusum_parameters(data = clean_raw, 
                                data_fault = fault_raw, 
                                labels = labels_clean_raw, 
                                labels_fault = labels_fault_raw,
                                window_size = WINDOW_SIZE, 
                                cusum = cusum,
                                oracle = oracle,
                                sim_len = sim_len,
                                classic_threshold = True,
                                simulation = simulation)

    # Threshold based on residual value (h*std))
    results_res_clas_thresh_no_max = optimize_cusum_parameters(data = clean_res, 
                                data_fault = fault_res, 
                                labels = labels_clean_res, 
                                labels_fault = labels_fault_res,
                                window_size = WINDOW_SIZE, 
                                cusum = cusum,
                                oracle = oracle,
                                sim_len = sim_len,
                                classic_threshold = True,
                                simulation = simulation)

    # Threshold based on cusum over param est residual data (mean + std of the cusum)
    results_res_csm_thresh_no_max = optimize_cusum_parameters(data = clean_res, 
                                data_fault = fault_res, 
                                labels = labels_clean_res, 
                                labels_fault = labels_fault_res,
                                window_size = WINDOW_SIZE, 
                                cusum = cusum,
                                oracle = oracle,
                                sim_len = sim_len,
                                classic_threshold = True,
                                simulation = simulation)

    results_raw_csm_thresh_max = optimize_cusum_parameters(data = clean_raw, 
                                data_fault = fault_raw, 
                                labels = labels_clean_raw, 
                                labels_fault = labels_fault_raw,
                                window_size = WINDOW_SIZE, 
                                cusum = cusum,
                                oracle = oracle,
                                sim_len = sim_len,
                                classic_threshold = True,
                                simulation = simulation)

    results_res_csm_thresh_max = optimize_cusum_parameters(data = clean_res, 
                                data_fault = fault_res, 
                                labels = labels_clean_res, 
                                labels_fault = labels_fault_res,
                                window_size = WINDOW_SIZE, 
                                cusum = cusum,
                                oracle = oracle,
                                sim_len = sim_len,
                                classic_threshold = True,
                                simulation = simulation)

    return results_raw_clas_thresh_no_max, \
                results_raw_csm_thresh_no_max, \
                results_res_clas_thresh_no_max, \
                results_res_csm_thresh_no_max, \
                results_raw_csm_thresh_max, \
                results_res_csm_thresh_max



####################################################

MAX_LENGTH = 50_000
PARAM_ESTIMATION_SIZE = 10_000
WINDOW_SIZE = 30

file = "results/results_cusum_opt_oracle.pkl"

if not os.path.exists('results'):
    os.makedirs('results')

if os.path.exists(file):
    results_oracle = load_pickle(file)
else:

    # results[dataset][cusum_model][result_type] = data
    results_oracle = defaultdict(lambda: defaultdict(dict))

    datasets = ['TEP', 'LBNL', 'SKAB', 'RMFD']
    datasets = ['TEP']
    
    cusums = [
        'high_order',
        'classical',
        'one_cusum_scheme',
        'hampel_acusum',
        'UCUSUM',
        'variance_cusum'
    ]

    for dataset in datasets:
        for csm in cusums:
            r1, r2, r3, r4, r5, r6 = test_optimize_cusum_parameters(
                dataset=dataset, 
                cusum=csm,  
                oracle=True,
                MAX_LENGTH=MAX_LENGTH,
                PARAM_ESTIMATION_SIZE=PARAM_ESTIMATION_SIZE,
                WINDOW_SIZE=WINDOW_SIZE
            )

            results_oracle[dataset][csm]['raw_clas_thresh_no_max'] = r1
            results_oracle[dataset][csm]['raw_csm_thresh_no_max'] = r2
            results_oracle[dataset][csm]['res_clas_thresh_no_max'] = r3
            results_oracle[dataset][csm]['res_csm_thresh_no_max'] = r4
            results_oracle[dataset][csm]['raw_csm_thresh_max'] = r5
            results_oracle[dataset][csm]['res_csm_thresh_max'] = r6

    save_pickle(results_oracle, file)
